# %% [markdown]
# # Simulated PIK statistics
#
# Here we inspect the accuracy and characteristics of the PIKs assigned,
# leveraging our knowledge of ground truth from pseudopeople.
#
# It wouldn't be possible to do the ground truth part with the real PVS, but
# Layne, Wagner, and Rothhaas did something similar by redacting SSN from real records,
# sending them through PVS without the SSN, and then using the true SSN
# as ground truth.
# The health care records they used are probably quite different from a CUF,
# but they found a **very** good overall PIK accuracy (see cell below).

# %%
# Query planning is now on by default, but it has some rough edges.
# See https://github.com/dask/dask/issues/10995 for general discussion
# and https://github.com/dask/dask-expr/issues/1060 for the particular
# issue I ran into.
import dask
dask.config.set({"dataframe.query-planning": False})

# %%
import datetime, os

from vivarium_research_prl import distributed_compute, utils
from IPython.display import display

# %%
print(datetime.datetime.now())
# Out:
# 2024-05-15 23:43:59.852198

# %%
# DO NOT EDIT if this notebook is not called ground_truth_accuracy.ipynb!
# This notebook is designed to be run with papermill; this cell is tagged 'parameters'
data_to_use = 'small_sample'
simulated_data_output_dir = 'output/generate_simulated_data'
case_study_output_dir = 'output'

# The "compute engine" is what we use on the Python side
# for our case-study-specific operations,
# as opposed to the Splink engine
compute_engine = 'pandas'
# Only matter if using a distributed compute engine
compute_engine_num_jobs = 3
compute_engine_cpus_per_job = 2
compute_engine_memory_per_job = "5GB"
queue = "long.q"
local_directory = f"/tmp/{os.environ['USER']}_dask"

# %%
# Parameters
data_to_use = "ri"
simulated_data_output_dir = "/ihme/scratch/users/zmbc/person_linkage_case_study/generate_simulated_data/"
case_study_output_dir = "/ihme/scratch/users/zmbc/person_linkage_case_study/results/"
compute_engine = "dask"
compute_engine_num_jobs = 20
compute_engine_memory_per_job = "30GB"
compute_engine_cpus_per_job = 2

# %%
# Parameters for a USA run
# data_to_use = "usa"
# simulated_data_output_dir = "/ihme/scratch/users/zmbc/person_linkage_case_study/generate_simulated_data"
# case_study_output_dir = "/ihme/scratch/users/zmbc/person_linkage_case_study/person_linkage_case_study"

# compute_engine = 'dask'
# compute_engine_num_jobs = 50
# compute_engine_memory_per_job = "120GB"
# compute_engine_cpus_per_job = 2

# %%
case_study_output_dir = f'{case_study_output_dir}/{data_to_use}'
simulated_data_output_dir = f'{simulated_data_output_dir}/{data_to_use}'

# %%
df_ops, pd = distributed_compute.start_compute_engine(
    compute_engine,
    num_jobs=compute_engine_num_jobs,
    cpus_per_job=compute_engine_cpus_per_job,
    memory_per_job=compute_engine_memory_per_job,
    queue=queue,
    local_directory=local_directory,
)
# Out:
# <Client: 'tcp://10.158.111.9:43605' processes=20 threads=20, memory=558.80 GiB>

# %%
census_2030_piked = df_ops.read_parquet(f'{case_study_output_dir}/census_2030_piked.parquet')
confirmed_piks_with_ground_truth = df_ops.read_parquet(f'{case_study_output_dir}/confirmed_piks.parquet')
# Out:
# Imbalanced dataframe: too_few=False, too_many=True, too_large=False
# count       291.000000
# mean     935161.642612
# std       16261.028538
# min      889812.000000
# 25%      923722.000000
# 50%      934268.000000
# 75%      946355.000000
# max      987218.000000
# dtype: float64
# Creating partitions of 100MB

# %%
piked_proportion = df_ops.compute(census_2030_piked.pik.notnull().mean())
# Compare with 90.28% of input records PIKed in the 2010 CUF,
# as reported in Wagner and Layne, Table 2, p. 18 
print(f'{piked_proportion:.2%} of the input records were PIKed')
# Out:
# 89.41% of the input records were PIKed

# %%
# Multiple Census rows assigned the same PIK, indicating the model thinks they are duplicates in Census
pik_sizes = df_ops.persist(df_ops.groupby_agg_small_groups(census_2030_piked, by='pik', agg_func=lambda x: x.size()))
df_ops.compute(pik_sizes.value_counts())
# Out:
# 1    981164
# 2       563
# Name: count, dtype: int64

# %%
# Interesting: in pseudopeople, sometimes siblings are assigned the same (common) first name, making them almost identical.
# The only giveaway is their age and DOB.
# Presumably, this tends not to happen in real life.
duplicate_piks = pik_sizes.rename('pik_size').reset_index().pipe(lambda df: df[df.pik_size > 1])

df_ops.head(census_2030_piked.merge(duplicate_piks, on="pik").sort_values('pik'))
# Out:
#     household_id first_name middle_initial  last_name   age date_of_birth  \
# 63    6118_93687     Ximena              A  Silverman     7    03/01/2023
# 200   6118_93687       Mary           <NA>  Silverman    36    03/01/2023
# 227  1282_275198       Jack              A     Solano     7    09/02/1996
# 348  1282_275198      Jacob              D     Solano    33    09/02/1996
# 4     465_115899      Diane              R     Miller    83    12/07/2012
# 78    465_115899      Kaiya              R     Miller    17    12/07/2012
# 139  1777_111062        Mia              P   Coronado    18    01/18/2012
# 309  1777_111062      Caleb           <NA>   Coronado  <NA>    01/18/2012
# 59    6191_23892       Amin              M       Cole    11    12/04/2018
# 168   6191_23892    Eleanor              M       Cole     2    12/04/2018
#
#     street_number         street_name unit_number             city state  \
# 63            191  east loudon avenue        <NA>  nort smithfield    RI
# 200           191  east loudon avenue        <NA>  nort smithfield    RI
# 227           429         e arrow hwy        <NA>         coventry    RI
# 348           429         e arrow hwy        <NA>         coventry    RI
# 4             906          vandre ave        <NA>        providenc    RI
# 78            906          vandre ave        <NA>       providence    RI
# 139            71        hyde park ct        <NA>      wst warwick    RI
# 309            61        hyde park ct        <NA>      wst warwick    RI
# 59        239 1 2       southern arty        <NA>   east greenwich    RI
# 168       239 1 2       southern arty        <NA>   east greenwich    RI
#
#     zipcode housing_type relationship_to_reference_person     sex  \
# 63    02857    Household                 Biological child  Female
# 200   02857    Household                 Reference person  Female
# 227   02907    Household                       Grandchild    Male
# 348    <NA>    Household                 Biological child    Male
# 4     02881    Household                 Reference person  Female
# 78    02881    Household                       Grandchild  Female
# 139   02904    Household                 Biological child  Female
# 309   02904    Household                 Biological child    Male
# 59    02905    Household                          Sibling    Male
# 168   02905    Household                              NaN  Female
#
#            race_ethnicity  year                       record_id       pik  \
# 63                  Black  2030  simulated_census_2030_1_237810  2_100394
# 200                 Black  2030  simulated_census_2030_1_235731  2_100394
# 227                Latino  2030  simulated_census_2030_0_157495  2_102403
# 348                Latino  2030  simulated_census_2030_0_156697  2_102403
# 4                   White  2030   simulated_census_2030_0_62176  2_103729
# 78                  White  2030   simulated_census_2030_0_62177  2_103729
# 139                Latino  2030  simulated_census_2030_0_228366  2_103873
# 309                Latino  2030  simulated_census_2030_0_228365  2_103873
# 59                 Latino  2030  simulated_census_2030_1_244226  2_110635
# 168  Multiracial or Other  2030  simulated_census_2030_1_246982  2_110635
#
#      pik_size
# 63          2
# 200         2
# 227         2
# 348         2
# 4           2
# 78          2
# 139         2
# 309         2
# 59          2
# 168         2

# %% [markdown]
# ## Ground truth statistics

# %%
census_2030_ground_truth = df_ops.persist(
    df_ops.read_parquet(f'{simulated_data_output_dir}/simulated_census_2030_ground_truth.parquet')
)
# Out:
# Imbalanced dataframe: too_few=True, too_many=False, too_large=False
# count    3.000000e+00
# mean     2.368708e+07
# std      1.133272e+07
# min      1.060119e+07
# 25%      2.040891e+07
# 50%      3.021663e+07
# 75%      3.023002e+07
# max      3.024342e+07
# dtype: float64

# %%
# In this version of pseudopeople, there are no actual duplicates in Census,
# which means all of the duplicates identified above are wrong.
assert len(census_2030_ground_truth) == len(df_ops.drop_duplicates(census_2030_ground_truth))
# Out:
# Imbalanced dataframe: too_few=True, too_many=False, too_large=False
# count    6.000000e+00
# mean     1.037869e+07
# std      1.299027e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      4.642370e+06
# 75%      2.217716e+07
# max      2.651276e+07
# dtype: float64

# %%
reference_files_ground_truth = df_ops.persist(df_ops.concat([
    df_ops.read_parquet(f'{simulated_data_output_dir}/simulated_geobase_reference_file_ground_truth.parquet').drop(columns=['n_unique_simulants']),
    df_ops.read_parquet(f'{simulated_data_output_dir}/simulated_name_dob_reference_file_ground_truth.parquet').drop(columns=['n_unique_simulants']),
], ignore_index=True))
# Out:
# Imbalanced dataframe: too_few=True, too_many=False, too_large=False
# count    2.000000e+00
# mean     7.610524e+07
# std      4.820347e+03
# min      7.610183e+07
# 25%      7.610353e+07
# 50%      7.610524e+07
# 75%      7.610694e+07
# max      7.610864e+07
# dtype: float64

# %%
# However, there can be reference file records that correspond to multiple simulants,
# due to errors in the reference file construction by SSN
n_unique_simulants = df_ops.persist(df_ops.groupby_agg_small_groups(reference_files_ground_truth, by='record_id', agg_func=lambda x: x.simulant_id.nunique()).rename('n_unique_simulants').reset_index())
df_ops.compute(n_unique_simulants.n_unique_simulants.value_counts())
# Out:
# n_unique_simulants
# 1    4427601
# 2     119327
# 3       5586
# 4        300
# 5         14
# 6          3
# Name: count, dtype: int64

# %%
reference_files_ground_truth = df_ops.persist(reference_files_ground_truth.merge(
    n_unique_simulants,
    on='record_id',
    how='left',
))
reference_files_ground_truth.head(n=100)
# Out:
#                                     record_id   simulant_id  \
# 0    simulated_geobase_reference_file_0_12823   7645_262150
# 1     simulated_geobase_reference_file_0_1633   5072_308353
# 2     simulated_geobase_reference_file_0_1633   5072_197339
# 3    simulated_geobase_reference_file_0_18938    107_193795
# 4    simulated_geobase_reference_file_0_23431   3305_405686
# ..                                        ...           ...
# 95  simulated_geobase_reference_file_16_32886   3568_452390
# 96  simulated_geobase_reference_file_16_38477   7589_324805
# 97  simulated_geobase_reference_file_16_39367     40_658775
# 98  simulated_geobase_reference_file_16_42612  3454_1000174
# 99  simulated_geobase_reference_file_16_45806  3947_1080555
#
#     n_unique_simulants
# 0                    1
# 1                    2
# 2                    2
# 3                    1
# 4                    1
# ..                 ...
# 95                   1
# 96                   1
# 97                   1
# 98                   1
# 99                   1
#
# [100 rows x 3 columns]

# %%
df_ops.head(reference_files_ground_truth[reference_files_ground_truth.n_unique_simulants == df_ops.compute(reference_files_ground_truth.n_unique_simulants.max())])
# Out:
#                                        record_id   simulant_id  \
# 25339  simulated_geobase_reference_file_21_35463   7125_711460
# 25340  simulated_geobase_reference_file_21_35463   7125_711458
# 25341  simulated_geobase_reference_file_21_35463   7125_711454
# 25342  simulated_geobase_reference_file_21_35463   7125_711463
# 25343  simulated_geobase_reference_file_21_35463   7125_711462
# 25344  simulated_geobase_reference_file_21_35463   7125_624129
# 25142  simulated_geobase_reference_file_40_34229   6991_559426
# 25143  simulated_geobase_reference_file_40_34229  6991_1067323
# 25144  simulated_geobase_reference_file_40_34229   6991_559425
# 25145  simulated_geobase_reference_file_40_34229   6991_559427
#
#        n_unique_simulants
# 25339                   6
# 25340                   6
# 25341                   6
# 25342                   6
# 25343                   6
# 25344                   6
# 25142                   6
# 25143                   6
# 25144                   6
# 25145                   6

# %%
census_2030_ground_truth = df_ops.persist(census_2030_ground_truth.merge(
    df_ops.drop_duplicates(reference_files_ground_truth[['simulant_id']]).assign(possible_to_pik=1),
    on='simulant_id',
    how='left',
).assign(possible_to_pik=lambda df: df.possible_to_pik.fillna(0)))
possible_to_pik_proportion = df_ops.compute(census_2030_ground_truth.possible_to_pik.mean())
print(
    f'{(1 - possible_to_pik_proportion):.2%} of the input records are '
    'impossible to PIK correctly, since they are not in any reference files'
)
# Out:
# 0.51% of the input records are impossible to PIK correctly, since they are not in any reference files

# %%
print(
    f'Assigned PIKs to {(piked_proportion / possible_to_pik_proportion):.2%} of PIK-able records'
)
# Out:
# Assigned PIKs to 89.86% of PIK-able records

# %%
reference_file = df_ops.concat([
    df_ops.read_parquet(
        f'{simulated_data_output_dir}/simulated_geobase_reference_file.parquet',
    ),
    df_ops.read_parquet(
        f'{simulated_data_output_dir}/simulated_name_dob_reference_file.parquet',
    ),
], ignore_index=True)

# %%
reference_file_piks = df_ops.persist(reference_file[['record_id', 'pik']])
reference_file_piks
# Out:
# Dask DataFrame Structure:
#                 record_id     pik
# npartitions=120
#                    string  string
#                       ...     ...
# ...                   ...     ...
#                       ...     ...
#                       ...     ...
# Dask Name: getitem, 1 graph layer

# %%
assert len(reference_file_piks) == len(df_ops.drop_duplicates(reference_file_piks[['record_id']]))

# %%
pik_simulant_pairs = df_ops.persist(df_ops.drop_duplicates(reference_files_ground_truth.merge(reference_file_piks, on='record_id')[['pik', 'simulant_id']]))

# %%
# However, there can be PIKs that correspond to multiple simulants,
# due to errors in the reference file construction by SSN
n_unique_simulants = df_ops.persist(df_ops.groupby_agg_small_groups(pik_simulant_pairs, by='pik', agg_func=lambda x: x.simulant_id.nunique()).rename('n_unique_simulants').reset_index())
df_ops.compute(n_unique_simulants.n_unique_simulants.value_counts())
# Out:
# n_unique_simulants
# 1    1618046
# 2     103567
# 3       6328
# 4        360
# 5         22
# 6          4
# Name: count, dtype: int64

# %%
pik_simulant_pairs = df_ops.persist(pik_simulant_pairs.merge(
    n_unique_simulants,
    on='pik',
    how='left',
))
pik_simulant_pairs
# Out:
# Dask DataFrame Structure:
#                     pik simulant_id n_unique_simulants
# npartitions=240
#                  string      string              int64
#                     ...         ...                ...
# ...                 ...         ...                ...
#                     ...         ...                ...
#                     ...         ...                ...
# Dask Name: hash-join, 1 graph layer

# %%
df_ops.head(pik_simulant_pairs[pik_simulant_pairs.n_unique_simulants == df_ops.compute(pik_simulant_pairs.n_unique_simulants.max())])
# Out:
#            pik  simulant_id  n_unique_simulants
# 1942  2_490201   7870_98971                   6
# 1943  2_490201  656_1135113                   6
# 1944  2_490201   2721_36160                   6
# 1945  2_490201   5950_76911                   6
# 1946  2_490201   8133_83126                   6
# 1947  2_490201  8501_630145                   6
# 3870   3_13632  4743_515490                   6
# 3871   3_13632   4743_76318                   6
# 3872   3_13632  4743_515492                   6
# 3873   3_13632  4743_515489                   6

# %% [markdown]
# ## Definitions of accuracy
#
# 1. (most strict) Assigning any PIK with multiple simulants is incorrect
# 2. Assigning a PIK with multiple simulants is neither incorrect nor correct (excluded from denominator)
# 3. (most lenient) Assigning a PIK with multiple simulants is correct, as long as at least one of those simulants matches the truth

# %%
# All modules, Medicare database, calculated from Layne, Wagner, and Rothhaas Table 1 (p. 15)
real_life_pvs_accuracy = 1 - (2_585 + 60_709 + 129_480 + 89_094) / (52_406_981 + 5_170_924 + 49_374_794 + 50_327_034)
f'{real_life_pvs_accuracy:.5%}'
# Out:
# '99.82079%'

# %% [markdown]
# ### Definition 1

# %%
piks_assigned = df_ops.compute(census_2030_piked.pik.notnull().sum())
piks_assigned
# Out:
# 982290

# %%
df_ops.head(pik_simulant_pairs[pik_simulant_pairs.n_unique_simulants > 1])
# Out:
#          pik   simulant_id  n_unique_simulants
# 0   2_100151   9159_624504                   2
# 1   2_100151   9159_692077                   2
# 2   2_100284  6442_1037247                   2
# 3   2_100284   6442_310430                   2
# 32  2_107130    446_862382                   2
# 33  2_107130    446_211850                   2
# 47  2_109530  6520_1136974                   2
# 48  2_109530   6520_620122                   2
# 62  2_113631  4203_1060381                   2
# 63  2_113631  4203_1060383                   2

# %%
single_sim_piks_correct = df_ops.compute(
    census_2030_piked[['record_id', 'pik']].merge(pik_simulant_pairs, on='pik').merge(census_2030_ground_truth, on='record_id')
        .pipe(lambda df: (df.simulant_id_x == df.simulant_id_y) & (df.n_unique_simulants == 1))
        .sum()
)
single_sim_piks_correct
# Out:
# 910434

# %%
# Overall accuracy, treating it as a black box
(
    single_sim_piks_correct / piks_assigned
)
# Out:
# 0.9268484866994472

# %%
assert len(confirmed_piks_with_ground_truth) == piks_assigned

# %%
df_ops.head(census_2030_ground_truth.rename(columns={'record_id': 'record_id_census_2030'}))
# Out:
#           record_id_census_2030 simulant_id  possible_to_pik
# 0     simulated_census_2030_0_2     28_1143              1.0
# 1   simulated_census_2030_0_303   28_114415              1.0
# 2   simulated_census_2030_0_319   28_117645              1.0
# 3   simulated_census_2030_0_529   28_210376              1.0
# 4  simulated_census_2030_0_1202   28_482019              1.0
# 5  simulated_census_2030_0_1412   28_557182              1.0
# 6  simulated_census_2030_0_1606   28_637973              1.0
# 7  simulated_census_2030_0_1679   28_672216              1.0
# 8  simulated_census_2030_0_1996   28_795711              1.0
# 9  simulated_census_2030_0_2041   28_815800              1.0

# %%
# Looking at whether the exact *record* linked was from the same simulant
single_sim_record_links_correct = df_ops.compute(
    confirmed_piks_with_ground_truth
        .merge(
            census_2030_ground_truth.rename(columns={'record_id': 'record_id_raw_input_file'}),
            on='record_id_raw_input_file',
        )
        .merge(
            reference_files_ground_truth.rename(columns={'record_id': 'record_id_reference_file'}),
            on='record_id_reference_file',
        )
        .pipe(lambda df: (df.simulant_id_x == df.simulant_id_y) & (df.n_unique_simulants == 1))
        .sum()
)
single_sim_record_links_correct
# Out:
# 917968

# %%
(
    single_sim_record_links_correct / piks_assigned
)
# Out:
# 0.9345183194372334

# %% [markdown]
# ### Definition 2

# %%
single_sim_piks_assigned = len(census_2030_piked[['record_id', 'pik']].merge(pik_simulant_pairs[pik_simulant_pairs.n_unique_simulants == 1][['pik', 'simulant_id']]))
single_sim_piks_assigned
# Out:
# 911011

# %%
# Overall accuracy, treating it as a black box
(
    single_sim_piks_correct / single_sim_piks_assigned
)
# Out:
# 0.9993666377244622

# %%
# Looking at whether the exact *record* linked was from the same simulant
single_sim_record_links_assigned = df_ops.compute(
    (confirmed_piks_with_ground_truth
        .merge(
            reference_files_ground_truth.rename(columns={'record_id': 'record_id_reference_file'}),
            on='record_id_reference_file',
        )
        .n_unique_simulants == 1).sum()
)
single_sim_record_links_assigned
# Out:
# 918549

# %%
(
    single_sim_record_links_correct / single_sim_record_links_assigned
)
# Out:
# 0.9993674806678795

# %% [markdown]
# ### Definition 3

# %%
pik_simulant_pairs
# Out:
# Dask DataFrame Structure:
#                     pik simulant_id n_unique_simulants
# npartitions=240
#                  string      string              int64
#                     ...         ...                ...
# ...                 ...         ...                ...
#                     ...         ...                ...
#                     ...         ...                ...
# Dask Name: hash-join, 1 graph layer

# %%
piks_at_least_partially_correct = df_ops.persist(
    census_2030_piked[['record_id', 'pik']].merge(pik_simulant_pairs, on='pik').merge(census_2030_ground_truth, on='record_id')
        .pipe(df_ops.drop_duplicates)
        .assign(correct=lambda df: df.simulant_id_x == df.simulant_id_y)
        .pipe(df_ops.groupby_agg_small_groups, by=["record_id", "pik"], agg_func=lambda x: x.correct.any())
        .reset_index()
)
piks_at_least_partially_correct
# Out:
# Imbalanced dataframe: too_few=False, too_many=True, too_large=False
# count    4.800000e+02
# mean     2.371846e+05
# std      3.398717e+05
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      8.286500e+03
# 75%      3.188702e+05
# max      1.777656e+06
# dtype: float64
# Creating partitions of 100MB
# Dask DataFrame Structure:
#               record_id     pik        correct
# npartitions=2
#                  string  string  bool[pyarrow]
#                     ...     ...            ...
#                     ...     ...            ...
# Dask Name: reset_index, 1 graph layer

# %%
# Overall accuracy, treating it as a black box
piks_correct_proportion = (df_ops.compute(piks_at_least_partially_correct.correct.sum()) / piks_assigned)
piks_correct_proportion
# Out:
# 0.9993759480397846

# %%
print(f'{piks_correct_proportion:.5%} of the PIKs assigned were correct; compare with {real_life_pvs_accuracy:.5%} in real life')
# Out:
# 99.93759% of the PIKs assigned were correct; compare with 99.82079% in real life

# %%
# Looking at whether the exact *record* linked was from the same simulant
sim_record_links_at_least_partially_correct = df_ops.persist(
    confirmed_piks_with_ground_truth
        .merge(
            census_2030_ground_truth.rename(columns={'record_id': 'record_id_raw_input_file'}),
            on='record_id_raw_input_file',
        )
        .merge(
            reference_files_ground_truth.rename(columns={'record_id': 'record_id_reference_file'}),
            on='record_id_reference_file',
        )
        .assign(correct=lambda df: df.simulant_id_x == df.simulant_id_y)
        .pipe(df_ops.groupby_agg_small_groups, by=["record_id_raw_input_file", "record_id_reference_file", "pik", "module_name", "pass_name"], agg_func=lambda x: x.correct.any())
        .reset_index()
)
sim_record_links_at_least_partially_correct
# Out:
# Dask DataFrame Structure:
#                 record_id_raw_input_file record_id_reference_file     pik module_name pass_name        correct
# npartitions=196
#                                   string                   string  string      string    string  bool[pyarrow]
#                                      ...                      ...     ...         ...       ...            ...
# ...                                  ...                      ...     ...         ...       ...            ...
#                                      ...                      ...     ...         ...       ...            ...
#                                      ...                      ...     ...         ...       ...            ...
# Dask Name: reset_index, 1 graph layer

# %%
len(sim_record_links_at_least_partially_correct)
# Out:
# 982290

# %%
len(df_ops.drop_duplicates(sim_record_links_at_least_partially_correct[['record_id_raw_input_file', 'record_id_reference_file']]))
# Out:
# 982290

# %%
(
    df_ops.compute(sim_record_links_at_least_partially_correct.correct.sum()) / piks_assigned
)
# Out:
# 0.9993759480397846

# %%
assert df_ops.compute((df_ops.groupby_agg_small_groups(confirmed_piks_with_ground_truth, by='record_id_raw_input_file', agg_func=lambda x: x.record_id_reference_file.nunique()) <= 1).all())

# %%
# Using definition 3 -- at the PIK level
piks_at_least_partially_correct = df_ops.persist(
    piks_at_least_partially_correct
        .rename(columns={'record_id': 'record_id_raw_input_file'})
        .merge(confirmed_piks_with_ground_truth[['record_id_raw_input_file', 'module_name', 'pass_name']], on='record_id_raw_input_file')
)
piks_at_least_partially_correct
# Out:
# Dask DataFrame Structure:
#                 record_id_raw_input_file     pik        correct module_name pass_name
# npartitions=196
#                                   string  string  bool[pyarrow]      string    string
#                                      ...     ...            ...         ...       ...
# ...                                  ...     ...            ...         ...       ...
#                                      ...     ...            ...         ...       ...
#                                      ...     ...            ...         ...       ...
# Dask Name: bcast-join, 1 graph layer

# %%
# Accuracy by module -- note that this shows the opposite pattern (with the sample data)
# relative to the results of Layne et al., who found GeoSearch was much *more* accurate
df_ops.compute(piks_at_least_partially_correct.groupby("module_name").correct.agg(["mean", "size"]).sort_values("mean"))
# Out:
#                   mean    size
# module_name
# hhcompsearch  0.997934    3873
# dobsearch     0.998982     982
# geosearch     0.999376  937419
# namesearch    0.999525   40016

# %%
# Accuracy by pass -- could be used to tune pass-specific cutoffs, but
# this might not be too informative while we are still using the sample data.
df_ops.compute(piks_at_least_partially_correct.groupby(["module_name", "pass_name"]).correct.agg(["mean", "size"]).sort_values("mean"))
# Out:
#                                                                      mean  \
# module_name  pass_name
# namesearch   year of birth and first two characters of name      0.986842
# hhcompsearch year of birth                                        0.99658
# geosearch    geokey name switch                                  0.998187
# dobsearch    initials name switch                                0.998249
# namesearch   DOB and initials                                    0.998347
# geosearch    geokey                                              0.999257
# hhcompsearch initials                                            0.999452
# namesearch   DOB and NYSIIS of name                              0.999627
# geosearch    house number and street name Soundex                0.999643
#              some name and DOB information                       0.999985
#              house number and street name Soundex name switch         1.0
# dobsearch    reverse Soundex of name                                  1.0
#              first two characters of first name and year of ...       1.0
#
#                                                                    size
# module_name  pass_name
# namesearch   year of birth and first two characters of name          76
# hhcompsearch year of birth                                         2047
# geosearch    geokey name switch                                    2758
# dobsearch    initials name switch                                   571
# namesearch   DOB and initials                                      2420
# geosearch    geokey                                              756087
# hhcompsearch initials                                              1826
# namesearch   DOB and NYSIIS of name                               37520
# geosearch    house number and street name Soundex                 44851
#              some name and DOB information                       133570
#              house number and street name Soundex name switch       153
# dobsearch    reverse Soundex of name                                242
#              first two characters of first name and year of ...     169

# %%
# Using definition 3 -- at the link level
df_ops.compute(sim_record_links_at_least_partially_correct.groupby("module_name").correct.agg(["mean", "size"]).sort_values("mean"))
# Out:
#                   mean    size
# module_name
# hhcompsearch  0.997934    3873
# dobsearch     0.998982     982
# geosearch     0.999376  937419
# namesearch    0.999525   40016

# %%
df_ops.compute(sim_record_links_at_least_partially_correct.groupby(["module_name", "pass_name"]).correct.agg(["mean", "size"]).sort_values("mean"))
# Out:
#                                                                      mean  \
# module_name  pass_name
# namesearch   year of birth and first two characters of name      0.986842
# hhcompsearch year of birth                                        0.99658
# geosearch    geokey name switch                                  0.998187
# dobsearch    initials name switch                                0.998249
# namesearch   DOB and initials                                    0.998347
# geosearch    geokey                                              0.999257
# hhcompsearch initials                                            0.999452
# namesearch   DOB and NYSIIS of name                              0.999627
# geosearch    house number and street name Soundex                0.999643
#              some name and DOB information                       0.999985
# dobsearch    reverse Soundex of name                                  1.0
# geosearch    house number and street name Soundex name switch         1.0
# dobsearch    first two characters of first name and year of ...       1.0
#
#                                                                    size
# module_name  pass_name
# namesearch   year of birth and first two characters of name          76
# hhcompsearch year of birth                                         2047
# geosearch    geokey name switch                                    2758
# dobsearch    initials name switch                                   571
# namesearch   DOB and initials                                      2420
# geosearch    geokey                                              756087
# hhcompsearch initials                                              1826
# namesearch   DOB and NYSIIS of name                               37520
# geosearch    house number and street name Soundex                 44851
#              some name and DOB information                       133570
# dobsearch    reverse Soundex of name                                242
# geosearch    house number and street name Soundex name switch       153
# dobsearch    first two characters of first name and year of ...     169

# %%
df_ops.compute(sim_record_links_at_least_partially_correct[~sim_record_links_at_least_partially_correct.correct].groupby(["module_name", "pass_name"]).size()).sort_values()
# Out:
# module_name   pass_name
# dobsearch     initials name switch                                1
# hhcompsearch  initials                                            1
# namesearch    year of birth and first two characters of name      1
# geosearch     some name and DOB information                       2
# namesearch    DOB and initials                                    4
# geosearch     geokey name switch                                  5
# hhcompsearch  year of birth                                       7
# namesearch    DOB and NYSIIS of name                             14
# geosearch     house number and street name Soundex               16
#               geokey                                            562
# dtype: int64

# %% [markdown]
# ### Incorrect and missed PIKs

# %%
incorrectly_linked_pairs = df_ops.persist(df_ops.drop_duplicates(
    sim_record_links_at_least_partially_correct[~sim_record_links_at_least_partially_correct.correct]
        [["record_id_raw_input_file", "record_id_reference_file"]]
))
incorrectly_linked_pairs
# Out:
# Dask DataFrame Structure:
#                 record_id_raw_input_file record_id_reference_file
# npartitions=392
#                                   string                   string
#                                      ...                      ...
# ...                                  ...                      ...
#                                      ...                      ...
#                                      ...                      ...
# Dask Name: concat, 1 graph layer

# %%
len(incorrectly_linked_pairs)
# Out:
# 613

# %%
incorrect_links = df_ops.head(incorrectly_linked_pairs, n=100)
incorrect_links
# Out:
#           record_id_raw_input_file                   record_id_reference_file
# 0    simulated_census_2030_0_10141  simulated_geobase_reference_file_19_28111
# 1   simulated_census_2030_0_105524   simulated_geobase_reference_file_39_5682
# 0   simulated_census_2030_0_105915   simulated_geobase_reference_file_2_41002
# 1    simulated_census_2030_0_10709    simulated_geobase_reference_file_4_2883
# 2   simulated_census_2030_0_109733  simulated_geobase_reference_file_45_34511
# ..                             ...                                        ...
# 3   simulated_census_2030_0_231072  simulated_geobase_reference_file_42_18818
# 0   simulated_census_2030_0_233315  simulated_geobase_reference_file_10_27689
# 1   simulated_census_2030_0_233497  simulated_geobase_reference_file_53_12651
# 0   simulated_census_2030_0_233575  simulated_geobase_reference_file_19_18641
# 1   simulated_census_2030_0_235668   simulated_geobase_reference_file_2_38532
#
# [100 rows x 2 columns]

# %%
# %xdel incorrectly_linked_pairs

# %%
comparison_cols = [
    "first_name",
    "middle_name",
    "last_name",
    "date_of_birth",
    "street_number",
    "street_name",
    "unit_number",
    "city",
    "state",
]

incorrect_links_detail = (
    incorrect_links
        .merge(
            df_ops.compute(census_2030_piked[census_2030_piked.record_id.isin(incorrect_links.record_id_raw_input_file)])
                .rename(columns={"record_id": "record_id_raw_input_file", "middle_initial": "middle_name"})
                [["record_id_raw_input_file"] + comparison_cols],
            on="record_id_raw_input_file",
            how="left",
        )
        .merge(
            df_ops.compute(reference_file[reference_file.record_id.isin(incorrect_links.record_id_reference_file)])
                .rename(columns={"record_id": "record_id_reference_file"})
                .rename(columns=lambda c: c.replace('mailing_address_', ''))
                [["record_id_reference_file"] + comparison_cols],
            on="record_id_reference_file",
            how="left",
            suffixes=("_census", "_reference_file"),
        )
)
def flatten(xss):
    return [x for xs in xss for x in xs]

incorrect_links_detail[flatten([(f'{c}_census', f'{c}_reference_file') for c in comparison_cols])]
# Out:
#    first_name_census first_name_reference_file middle_name_census  \
# 0               <NA>                      Carl                  J
# 1              Freya                     Sarah                  M
# 2           Scarlett                  Jennifer                  S
# 3               <NA>                   Jameson                  M
# 4              Sarah                  Brooklyn                  A
# ..               ...                       ...                ...
# 95           Garrett                      <NA>                  C
# 96            Colton                     Colin                  D
# 97            Millie                    Connie                  A
# 98              Lexi                   Vicente               <NA>
# 99            Camila                     Jacob                  K
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 0                      George             Rice                     Rice
# 1                      Marcia            Smith                    Smith
# 2                      Shayla            Boyle                    Boyle
# 3                      Sister           Martin                   Martin
# 4                      Audrey            Kirby                    Kirby
# ..                        ...              ...                      ...
# 95                     Rodney           Sivils                   Sivils
# 96                   Augustus        Rodriguez                Rodriguez
# 97                     Angela        Fulkerson                Fulkerson
# 98                    Ezekiel      Cushenberry              Cushenberry
# 99                     Kamden            Simon                    Simon
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 0            09/24/1941                     19410924                 4100
# 1            11/09/2028                     20281109                 1059
# 2            03/13/1992                     19920313                 1018
# 3            03/20/2008                     20080320                  648
# 4            04/04/2022                     20220404                 6905
# ..                  ...                          ...                  ...
# 95           03/16/1969                     19690316                 4744
# 96           07/08/2001                     20010708                   11
# 97           06/17/1966                     19660617                 8345
# 98           01/28/2025                     20250128                  310
# 99           08/30/2017                     20170830                   61
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 0                          4100           ne 19 st                   NE 19 ST
# 1                          1059         sw 15th st                 SW 15TH ST
# 2                          1018       heather mist               HEATHER MIST
# 3                           648       rosalind ave               ROSALIND AVE
# 4                          6905   godwin boulevard           GODWIN BOULEVARD
# ..                          ...                ...                        ...
# 95                         4744         liberty st                 LIBERTY ST
# 96                         <NA>         lowell cir                       <NA>
# 97                         8345       redd shop rd               REDD SHOP RD
# 98                          310       s muskego av               S MUSKEGO AV
# 99                           61    randolph avenue            RANDOLPH AVENUE
#
#    unit_number_census unit_number_reference_file       city_census  \
# 0                <NA>                       <NA>        middletown
# 1                <NA>                       <NA>            warren
# 2                <NA>                       <NA>         pawtucket
# 3                <NA>                       <NA>        smithfield
# 4                <NA>                       <NA>           warwick
# ..                ...                        ...               ...
# 95               <NA>                       <NA>        middletown
# 96               <NA>                       <NA>  north smithfield
# 97               <NA>                       <NA>        providence
# 98               ap 9                       AP 9        cumberland
# 99               <NA>                       <NA>         glocester
#
#    city_reference_file state_census state_reference_file
# 0           MIDDLETOWN           RI                   RI
# 1               WARREN           RI                   RI
# 2            PAWTUCKET           RI                   RI
# 3           SMITHFIELD           RI                   RI
# 4              WARWICK           RI                   RI
# ..                 ...          ...                  ...
# 95          MIDDLETOWN           RI                   RI
# 96             LINCOLN           RI                   RI
# 97          PROVIDENCE           RI                   RI
# 98          CUMBERLAND           RI                   RI
# 99           GLOCESTER           RI                   RI
#
# [100 rows x 18 columns]

# %%
missed_links = df_ops.persist(
    census_2030_piked[census_2030_piked.pik.isnull()][["record_id"]]
        .merge(census_2030_ground_truth, on="record_id")
        .merge(reference_files_ground_truth[reference_files_ground_truth.n_unique_simulants == 1], on="simulant_id", suffixes=("_census", "_reference_file"))
)

# %%
len(missed_links)
# Out:
# 285682

# %%
simulants_missed = df_ops.head(missed_links[['simulant_id']], n=100).simulant_id.unique()
simulants_missed
# Out:
# <ArrowStringArray>
# [  '446_413479',  '1219_176298',  '2863_430981',  '3298_854796',
#   '4561_608363',  '3528_397660',  '5812_765316',   '6991_86918',
#   '4344_401701',  '5188_162962',  '1832_850867',  '2277_153565',
#   '3357_333795',   '5628_98457',  '6520_109176',  '4621_579210',
#   '7817_985124', '9159_1174439',  '3723_959309', '4941_1189209',
#    '5628_60718', '6539_1178939',     '8305_416',     '99_73298',
#     '682_49973', '7179_1069048', '1597_1188844',  '3624_119898',
#   '7344_892187',  '9772_621190',  '2721_917949', '3298_1082703',
#   '9740_924180',  '5875_557972',  '9526_137552', '3621_1148314',
#  '4802_1177756', '8291_1049376',  '440_1076142']
# Length: 39, dtype: string

# %%
missed_pairs = df_ops.compute(missed_links[missed_links.simulant_id.isin(list(simulants_missed))])
missed_pairs
# Out:
#                    record_id_census  simulant_id  possible_to_pik  \
# 0     simulated_census_2030_0_49755   446_413479              1.0
# 1     simulated_census_2030_0_49755   446_413479              1.0
# 2     simulated_census_2030_0_49755   446_413479              1.0
# 3     simulated_census_2030_0_49755   446_413479              1.0
# 4    simulated_census_2030_0_134475  1219_176298              1.0
# ..                              ...          ...              ...
# 96    simulated_census_2030_0_44149  440_1076142              1.0
# 97    simulated_census_2030_0_44149  440_1076142              1.0
# 98    simulated_census_2030_0_44149  440_1076142              1.0
# 99    simulated_census_2030_0_44149  440_1076142              1.0
# 100   simulated_census_2030_0_44149  440_1076142              1.0
#
#                        record_id_reference_file  n_unique_simulants
# 0     simulated_geobase_reference_file_59_17351                   1
# 1    simulated_name_dob_reference_file_19_33351                   1
# 2     simulated_geobase_reference_file_59_17350                   1
# 3     simulated_geobase_reference_file_59_17352                   1
# 4      simulated_name_dob_reference_file_7_2918                   1
# ..                                          ...                 ...
# 96    simulated_geobase_reference_file_13_39804                   1
# 97    simulated_geobase_reference_file_13_39802                   1
# 98    simulated_geobase_reference_file_13_39801                   1
# 99    simulated_geobase_reference_file_13_39803                   1
# 100  simulated_name_dob_reference_file_33_35364                   1
#
# [101 rows x 5 columns]

# %%
# %xdel missed_links

# %%
missed_links_detail = (
    missed_pairs
        .merge(
            df_ops.compute(census_2030_piked[census_2030_piked.record_id.isin(list(missed_pairs.record_id_census))])
                .rename(columns={"record_id": "record_id_census", "middle_initial": "middle_name"}),
            on="record_id_census",
        )
        .merge(
            df_ops.compute(reference_file[reference_file.record_id.isin(missed_pairs.record_id_reference_file)])
                .rename(columns=lambda c: c.replace('mailing_address_', ''))
                .rename(columns={"record_id": "record_id_reference_file"}),
            on="record_id_reference_file",
            suffixes=("_census", "_reference_file"),
        )
)

# %%
for simulant in simulants_missed:
    print(simulant)
    display(missed_links_detail[missed_links_detail.simulant_id == simulant][['simulant_id'] + flatten([(f'{c}_census', f'{c}_reference_file') for c in comparison_cols])])
# Out:
# 446_413479
#   simulant_id first_name_census first_name_reference_file middle_name_census  \
# 0  446_413479          Jennifer                  Jennifer                  D
# 1  446_413479          Jennifer                  Jennifer                  D
# 2  446_413479          Jennifer                  Jennifer                  D
# 3  446_413479          Jennifer                  Jennifer                  D
#
#   middle_name_reference_file last_name_census last_name_reference_file  \
# 0                       Dana           Hunter                   Hunter
# 1                       Dana           Hunter                   Hunter
# 2                       Dana           Hunter                   Hunter
# 3                       Dana           Hunter                   Hunter
#
#   date_of_birth_census date_of_birth_reference_file street_number_census  \
# 0           08/15/1968                         <NA>                 2307
# 1           08/15/1968                         <NA>                 2307
# 2           08/15/1968                         <NA>                 2307
# 3           08/15/1968                         <NA>                 2307
#
#   street_number_reference_file street_name_census street_name_reference_file  \
# 0                         1607  ne jack london st          NE JACK LONDON ST
# 1                         <NA>  ne jack london st                       <NA>
# 2                         2307  ne jack london st          NE JACK LONDON ST
# 3                         2307  ne jack london st          NE JACK LONDON ST
#
#   unit_number_census unit_number_reference_file city_census  \
# 0               <NA>                       <NA>   pawtucket
# 1               <NA>                       <NA>   pawtucket
# 2               <NA>                       <NA>   pawtucket
# 3               <NA>                       <NA>   pawtucket
#
#   city_reference_file state_census state_reference_file
# 0           PAWTUCKET           RI                   RI
# 1                <NA>           RI                 <NA>
# 2           PAWTUCKET           RI                   OH
# 3           PAWTUCKET           RI                   RI
# 1219_176298
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 4  1219_176298              Ella                      Ella                  J
# 5  1219_176298              Ella                      Ella                  J
#
#   middle_name_reference_file last_name_census last_name_reference_file  \
# 4                     Jordan            Lopez                    Lopez
# 5                     Jordan            Lopez                    Lopez
#
#   date_of_birth_census date_of_birth_reference_file street_number_census  \
# 4           06/18/1989                     20120903                  509
# 5           06/18/1989                     20120903                  509
#
#   street_number_reference_file street_name_census street_name_reference_file  \
# 4                         <NA>       meigs street                       <NA>
# 5                          509       meigs street               MEIGS STREET
#
#   unit_number_census unit_number_reference_file   city_census  \
# 4             lot 3r                       <NA>  narragansett
# 5             lot 3r                     LOT 3R  narragansett
#
#   city_reference_file state_census state_reference_file
# 4                <NA>           RI                 <NA>
# 5        NARRAGANSETT           RI                   RI
# 2863_430981
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 6  2863_430981           Michael                   Michael                  R
# 7  2863_430981           Michael                   Michael                  R
# 8  2863_430981           Michael                   Michael                  R
#
#   middle_name_reference_file last_name_census last_name_reference_file  \
# 6                    Roberto             Wong                     Wong
# 7                    Roberto             Wong                     Wong
# 8                    Roberto             Wong                     Wong
#
#   date_of_birth_census date_of_birth_reference_file street_number_census  \
# 6           04/30/1983                     19610611                10802
# 7           04/30/1983                     19610611                10802
# 8           04/30/1983                     19610611                10802
#
#   street_number_reference_file   street_name_census  \
# 6                        10802  spring mountain way
# 7                         <NA>  spring mountain way
# 8                        10802  spring mountain way
#
#   street_name_reference_file unit_number_census unit_number_reference_file  \
# 6        SPRING MOUNTAIN WAY               <NA>                       <NA>
# 7                       <NA>               <NA>                       <NA>
# 8        SPRING MOUNTAIN WAY               <NA>                       <NA>
#
#   city_census city_reference_file state_census state_reference_file
# 6  barrington          BARRINGTON           RI                   RI
# 7  barrington                <NA>           RI                 <NA>
# 8  barrington         BARAHINGTON           RI                   RI
# 3298_854796
#     simulant_id first_name_census first_name_reference_file  \
# 9   3298_854796          Sharlene                  Sharlene
# 10  3298_854796          Sharlene                  Sharlene
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 9                                          Angel        A Royster
# 10                                         Angel        A Royster
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 9                   Royster           03/06/1981                     19810306
# 10                  Royster           03/06/1981                     19810306
#
#    street_number_census street_number_reference_file street_name_census  \
# 9                  1410                         <NA>           pansy rd
# 10                 1410                         1410           pansy rd
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 9                        <NA>               <NA>                       <NA>
# 10                   PANSY RD               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 9   portsmouth                <NA>           RI                 <NA>
# 10  portsmouth          PORTSMOUTH           RI                   RI
# 4561_608363
#     simulant_id first_name_census first_name_reference_file  \
# 11  4561_608363            Kaylee                      <NA>
# 12  4561_608363            Kaylee                      <NA>
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 11               <NA>                     Angela            James
# 12               <NA>                     Angela            James
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 11                    James           02/28/1985                     19850228
# 12                    James           02/28/1985                     19850228
#
#    street_number_census street_number_reference_file street_name_census  \
# 11                 <NA>                          145     e hawthorne st
# 12                 <NA>                         <NA>     e hawthorne st
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 11             E HAWTHORNE ST              # 368                      # 368
# 12                       <NA>              # 368                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 11    westerly            WESTERLY           RI                   RI
# 12    westerly                <NA>           RI                 <NA>
# 3528_397660
#     simulant_id first_name_census first_name_reference_file  \
# 13  3528_397660            Nathan                    Nathan
# 14  3528_397660            Nathan                    Nathan
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 13                  Q                          Q              Loh
# 14                  Q                          Q              Loh
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 13                     Lope           03/30/1995                         <NA>
# 14                     Lope           03/30/1995                         <NA>
#
#    street_number_census street_number_reference_file street_name_census  \
# 13                 4763                         <NA>              mdw l
# 14                 4763                         4763              mdw l
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 13                       <NA>               <NA>                       <NA>
# 14                      MDW L               <NA>                       <NA>
#
#       city_census city_reference_file state_census state_reference_file
# 13  central falls                <NA>           RI                 <NA>
# 14  central falls       CENTRAL FALLS           RI                 <NA>
# 5812_765316
#     simulant_id first_name_census first_name_reference_file  \
# 15  5812_765316          Campbell                       Cam
# 16  5812_765316          Campbell                       Cam
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 15                  E                     Evelyn             King
# 16                  E                     Evelyn             King
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 15                     King           03/30/2006                         <NA>
# 16                     King           03/30/2006                         <NA>
#
#    street_number_census street_number_reference_file street_name_census  \
# 15                 1833                         <NA>          john stre
# 16                 1833                         1833          john stre
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 15                       <NA>               <NA>                       <NA>
# 16                  JOHN STRE               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 15  providence                <NA>           RI                 <NA>
# 16  providence          PROVIDENCE           RI                   RI
# 6991_86918
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 17  6991_86918           Maureen                   Maureen                  S
# 18  6991_86918           Maureen                   Maureen                  S
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 17                    Shelley           Barnes                   Barnes
# 18                    Shelley           Barnes                   Barnes
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 17           07/12/1964                     19641207                   20
# 18           07/12/1964                     19641207                   20
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 17                           20     mayflower road             MAYFLOWER ROAD
# 18                         <NA>     mayflower road                       <NA>
#
#    unit_number_census unit_number_reference_file city_census  \
# 17               <NA>                       <NA>    cranston
# 18               <NA>                       <NA>    cranston
#
#    city_reference_file state_census state_reference_file
# 17            CRANSTON           RI                   RI
# 18                <NA>           RI                 <NA>
# 4344_401701
#     simulant_id first_name_census first_name_reference_file  \
# 19  4344_401701           Phillip                   Phillip
# 20  4344_401701           Phillip                   Phillip
# 21  4344_401701           Phillip                   Phillip
# 22  4344_401701           Phillip                   Phillip
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 19                  G                      Glenn           Ostlie
# 20                  G                      Glenn           Ostlie
# 21                  G                      Glenn           Ostlie
# 22                  G                      Glenn           Ostlie
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 19                   Ostlie           07/13/1980                     19800713
# 20                   Ostlie           07/13/1980                     19800713
# 21                   Ostlie           07/13/1980                     19800713
# 22                   Ostlie           07/13/1980                     19800713
#
#    street_number_census street_number_reference_file  \
# 19                 5524                         5524
# 20                 5524                         5524
# 21                 5524                         <NA>
# 22                 5524                         5524
#
#            street_name_census street_name_reference_file unit_number_census  \
# 19  cedar crest village drive  CEDAR CREST VILLAGE DRIVE               <NA>
# 20  cedar crest village drive  CEDAR CREST VILLAGE DRIVE               <NA>
# 21  cedar crest village drive                       <NA>               <NA>
# 22  cedar crest village drive  CEDAR CREST VILLAGE DRIVE               <NA>
#
#    unit_number_reference_file city_census city_reference_file state_census  \
# 19                       <NA>    johnston            JOHNSTON           RI
# 20                       <NA>    johnston            JOHNSTON           RI
# 21                       <NA>    johnston                <NA>           RI
# 22                       <NA>    johnston            JOHNSTON           RI
#
#    state_reference_file
# 19                   RI
# 20                 <NA>
# 21                 <NA>
# 22                   RI
# 5188_162962
#     simulant_id first_name_census first_name_reference_file  \
# 23  5188_162962            Justin                  Jonathan
# 24  5188_162962            Justin                  Jonathan
# 25  5188_162962            Justin                  Jonathan
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 23                  J                     Justin           Morgan
# 24                  J                     Justin           Morgan
# 25                  J                     Justin           Morgan
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 23                   Morgan                 <NA>                     20031028
# 24                   Morgan                 <NA>                     20031028
# 25                   Morgan                 <NA>                     20031028
#
#    street_number_census street_number_reference_file street_name_census  \
# 23                 1953                         1953       lincoln raod
# 24                 1953                         <NA>       lincoln raod
# 25                 1953                         1953       lincoln raod
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 23               LINCOLN RAOD               <NA>                       <NA>
# 24                       <NA>               <NA>                       <NA>
# 25               LINCOLN RAOD               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 23  portsmouth          PORTSMOUTH           RI                   RI
# 24  portsmouth                <NA>           RI                 <NA>
# 25  portsmouth          PORTSMOUTH           RI                   RI
# 1832_850867
#     simulant_id first_name_census first_name_reference_file  \
# 26  1832_850867           Heather                   Heather
# 27  1832_850867           Heather                   Heather
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 26                  H                     Hailey            Syeil
# 27                  H                     Hailey            Syeil
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 26                    Shell           07/30/2006                     20060730
# 27                    Shell           07/30/2006                     20060730
#
#    street_number_census street_number_reference_file street_name_census  \
# 26                 7304                         <NA>       ventura blvd
# 27                 7304                         <NA>       ventura blvd
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 26                       <NA>               <NA>                       <NA>
# 27                       <NA>               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 26     lincoln                <NA>           RI                 <NA>
# 27     lincoln                <NA>           RI                 <NA>
# 2277_153565
#     simulant_id first_name_census first_name_reference_file  \
# 28  2277_153565             Keith                     Keith
# 29  2277_153565             Keith                     Keith
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 28                  R                    Roberto           Thomas
# 29                  R                    Roberto           Thomas
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 28                   Thomas           01/05/1964                     19640105
# 29                   Thomas           01/05/1964                     19640105
#
#    street_number_census street_number_reference_file street_name_census  \
# 28                  502                          502          hunter ln
# 29                  502                         <NA>          hunter ln
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 28                  HUNTER LN               <NA>                       <NA>
# 29                       <NA>               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 28     warwick             WARWICK           RI                   RI
# 29     warwick                <NA>           RI                 <NA>
# 3357_333795
#     simulant_id first_name_census first_name_reference_file  \
# 30  3357_333795         Alexandra                 Alexandra
# 31  3357_333795         Alexandra                 Alexandra
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 30                  A                    Abigail              Coh
# 31                  A                    Abigail              Coh
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 30                     Keel           06/10/2025                     20150610
# 31                     Keel           06/10/2025                     20150610
#
#    street_number_census street_number_reference_file street_name_census  \
# 30                 <NA>                         <NA>           short st
# 31                 <NA>                         <NA>           short st
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 30                       <NA>               <NA>                       <NA>
# 31                   SHORT ST               <NA>                       <NA>
#
#          city_census city_reference_file state_census state_reference_file
# 30  north providence                <NA>           RI                 <NA>
# 31  north providence    NORTH PROVIDENCE           RI                   RI
# 5628_98457
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 32  5628_98457              <NA>                     Mitch                  C
# 33  5628_98457              <NA>                     Mitch                  C
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 32                     Connor            Boyer                    Boyer
# 33                     Connor            Boyer                    Boyer
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 32           04/09/1996                         <NA>                 1724
# 33           04/09/1996                         <NA>                 1724
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 32                         1724     s westwood ave             S WESTWOOD AVE
# 33                         <NA>     s westwood ave                       <NA>
#
#    unit_number_census unit_number_reference_file city_census  \
# 32               <NA>                       <NA>   hopkinton
# 33               <NA>                       <NA>   hopkinton
#
#    city_reference_file state_census state_reference_file
# 32           HOPKINTON           RI                   RI
# 33                <NA>           RI                 <NA>
# 6520_109176
#     simulant_id first_name_census first_name_reference_file  \
# 34  6520_109176           Destiny                      <NA>
# 35  6520_109176           Destiny                      <NA>
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 34                  E                      Emily           Vargas
# 35                  E                      Emily           Vargas
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 34                   Vargas           03/18/2010                     20100318
# 35                   Vargas           03/18/2010                     20100318
#
#    street_number_census street_number_reference_file street_name_census  \
# 34                 3501                         <NA>           e 5675 s
# 35                 3501                         <NA>           e 5675 s
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 34                       <NA>               <NA>                       <NA>
# 35                       <NA>               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 34    cranston                <NA>           RI                 <NA>
# 35    cranston          PROVIDENCE           RI                   RI
# 4621_579210
#     simulant_id first_name_census first_name_reference_file  \
# 36  4621_579210               Jon                       Jon
# 37  4621_579210               Jon                       Jon
# 38  4621_579210               Jon                       Jon
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 36                  L                      Larry            Rooks
# 37                  L                      Larry            Rooks
# 38                  L                      Larry            Rooks
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 36                    Rooks           01/03/1950                     19461214
# 37                    Rooks           01/03/1950                     19461214
# 38                    Rooks           01/03/1950                     19461214
#
#    street_number_census street_number_reference_file street_name_census  \
# 36                  350                          350       adams avenue
# 37                  350                          350       adams avenue
# 38                  350                         <NA>       adams avenue
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 36               ADAMS AVENUE             unit f                     UNIT F
# 37               ADAMZ AVENUE             unit f                     UNIT F
# 38                       <NA>             unit f                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 36      warren              WARREN           RI                   RI
# 37      warren              WARREN           RI                   RI
# 38      warren                <NA>           RI                 <NA>
# 7817_985124
#     simulant_id first_name_census first_name_reference_file  \
# 39  7817_985124              Nyla                      Nyla
# 40  7817_985124              Nyla                      Nyla
# 41  7817_985124              Nyla                      Nyla
# 42  7817_985124              Nyla                      Nyla
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 39                  M                      Maria           Nardin
# 40                  M                      Maria           Nardin
# 41                  M                      Maria           Nardin
# 42                  M                      Maria           Nardin
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 39                   Nardin           04/04/1997                     19630719
# 40                   Nardin           04/04/1997                     19630719
# 41                   Nardin           04/04/1997                     19630719
# 42                   Nardin           04/04/1997                     19630719
#
#    street_number_census street_number_reference_file street_name_census  \
# 39                    7                            7       state street
# 40                    7                            7       state street
# 41                    7                         <NA>       state street
# 42                    7                            7       state street
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 39               STATE STREET               <NA>                       <NA>
# 40               STATE STRFET               <NA>                       <NA>
# 41                       <NA>               <NA>                       <NA>
# 42               STATE STREET               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 39  providence          PROVIDENCE           RI                   RI
# 40  providence          PROVIDENCE           RI                   RI
# 41  providence                <NA>           RI                 <NA>
# 42  providence          PROVIDENCE           RI                   RI
# 9159_1174439
#      simulant_id first_name_census first_name_reference_file  \
# 43  9159_1174439            August                    August
# 44  9159_1174439            August                    August
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 43                  S                  Sebastian            Dante
# 44                  S                  Sebastian            Dante
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 43                    Dante           10/31/2029                     20281207
# 44                    Dante           10/31/2029                     20281207
#
#    street_number_census street_number_reference_file street_name_census  \
# 43                 5581                         5581      e lincoln ave
# 44                 5581                         <NA>      e lincoln ave
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 43              E LINCOLN AVE               <NA>                       <NA>
# 44                       <NA>               <NA>                       <NA>
#
#      city_census city_reference_file state_census state_reference_file
# 43  burrillville        BURRILLVILLE           RI                   RI
# 44  burrillville                <NA>           RI                 <NA>
# 3723_959309
#     simulant_id first_name_census first_name_reference_file  \
# 45  3723_959309              Lily                      Lily
# 46  3723_959309              Lily                      Lily
# 47  3723_959309              Lily                      Lily
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 45                  R                       Riya             Mula
# 46                  R                       Riya             Mula
# 47                  R                       Riya             Mula
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 45                     Mula           08/12/2006                     20061208
# 46                     Mula           08/12/2006                     20061208
# 47                     Mula           08/12/2006                     20061208
#
#    street_number_census street_number_reference_file street_name_census  \
# 45                  602                          602     tumbleweed way
# 46                  602                          602     tumbleweed way
# 47                  602                         <NA>     tumbleweed way
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 45             TUMBLEWEED WAY               <NA>                       <NA>
# 46             TUMBLEWEED WAY               <NA>                       <NA>
# 47                       <NA>               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 45     newport             NEWPORT           RI                   RI
# 46     newport             NEWPORT           RI                   SC
# 47     newport                <NA>           RI                 <NA>
# 4941_1189209
#      simulant_id first_name_census first_name_reference_file  \
# 48  4941_1189209           Abigail                   Abigail
# 49  4941_1189209           Abigail                   Abigail
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 48                  D                     Deanna            White
# 49                  D                     Deanna            White
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 48                    White           10/04/2029                     20050711
# 49                    White           10/04/2029                     20050711
#
#    street_number_census street_number_reference_file street_name_census  \
# 48                15542                         <NA>        stafford rd
# 49                15542                         <NA>        stafford rd
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 48                       <NA>               <NA>                       <NA>
# 49                       <NA>               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 48  smithfield                <NA>           RI                 <NA>
# 49  smithfield                <NA>           RI                 <NA>
# 5628_60718
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 50  5628_60718          Elizabet                 Elizabeth                  S
# 51  5628_60718          Elizabet                 Elizabeth                  S
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 50                    Shannon            Davis                    Davis
# 51                    Shannon            Davis                    Davis
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 50                 <NA>                     19970818                  212
# 51                 <NA>                     19970818                  212
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 50                         <NA>     n westlawn ave                       <NA>
# 51                         <NA>     n westlawn ave                       <NA>
#
#    unit_number_census unit_number_reference_file city_census  \
# 50               <NA>                       <NA>    richmond
# 51               <NA>                       <NA>    richmond
#
#    city_reference_file state_census state_reference_file
# 50              EXETER           RI                   RI
# 51                <NA>           RI                 <NA>
# 6539_1178939
#      simulant_id first_name_census first_name_reference_file  \
# 52  6539_1178939        Benjamin A                  Benjamin
# 53  6539_1178939        Benjamin A                  Benjamin
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 52                                     Augustine            Mitro
# 53                                     Augustine            Mitro
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 52                    Mitro           03/16/2129                     20290316
# 53                    Mitro           03/16/2129                     20290316
#
#    street_number_census street_number_reference_file street_name_census  \
# 52                   69                         <NA>       targee stree
# 53                   69                         <NA>       targee stree
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 52                       <NA>               <NA>                       <NA>
# 53                       <NA>               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 52  providence                <NA>           RI                 <NA>
# 53  providence                <NA>           RI                 <NA>
# 8305_416
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 54    8305_416           Brittny                   Brittny                  J
# 55    8305_416           Brittny                   Brittny                  J
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 54                          J    Llamas Jacobs                     Llam
# 55                          J    Llamas Jacobs                     Llam
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 54           12/15/1990                         <NA>                12730
# 55           12/15/1990                         <NA>                12730
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 54                         <NA>         airport rd                       <NA>
# 55                        12730         airport rd                 AIRPORT RD
#
#    unit_number_census unit_number_reference_file city_census  \
# 54               <NA>                       <NA>    cranston
# 55               <NA>                       <NA>    cranston
#
#    city_reference_file state_census state_reference_file
# 54                <NA>           RI                 <NA>
# 55            CRANSTON           RI                   RI
# 99_73298
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 56    99_73298             Carol                     Carol                  K
# 57    99_73298             Carol                     Carol                  K
# 58    99_73298             Carol                    Carrie                  K
# 59    99_73298             Carol                    Carrie                  K
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 56                          K             Oena                     Pena
# 57                          K             Oena                     Pena
# 58                          K             Oena                     Pena
# 59                          K             Oena                     Pena
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 56           10/01/1959                         <NA>                 1525
# 57           10/01/1959                         <NA>                 1525
# 58           10/01/1959                         <NA>                 1525
# 59           10/01/1959                         <NA>                 1525
#
#    street_number_reference_file  street_name_census  \
# 56                         1525  west howard street
# 57                         <NA>  west howard street
# 58                         <NA>  west howard street
# 59                         1525  west howard street
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 56         WEST HOWARD STREET               <NA>                       <NA>
# 57                       <NA>               <NA>                       <NA>
# 58                       <NA>               <NA>                       <NA>
# 59         WEST HOWARD STREET               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 56    westerly            WESTERLY           RI                   RI
# 57    westerly                <NA>           RI                 <NA>
# 58    westerly                <NA>           RI                 <NA>
# 59    westerly            WESTERLY           RI                   RI
# 682_49973
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 60   682_49973            Samuel                    Samuel                  C
# 61   682_49973            Samuel                    Samuel                  C
# 62   682_49973            Samuel                    Samuel                  C
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 60                  Christian          Vangent                  Vangent
# 61                  Christian          Vangent                  Vangent
# 62                  Christian          Vangent                  Vangent
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 60           10/07/1991                     19960710                  506
# 61           10/07/1991                     19960710                  506
# 62           10/07/1991                     19960710                  506
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 60                          506       93rd blvd ne               93RD BLVD NE
# 61                          506       93rd blvd ne               93RD BLVD NE
# 62                         <NA>       93rd blvd ne                       <NA>
#
#    unit_number_census unit_number_reference_file city_census  \
# 60               <NA>                       <NA>  cumberland
# 61               <NA>                       <NA>  cumberland
# 62               <NA>                       <NA>  cumberland
#
#    city_reference_file state_census state_reference_file
# 60         KUMBERLEAND           RI                   RI
# 61          CUMBERLAND           RI                   RI
# 62                <NA>           RI                 <NA>
# 7179_1069048
#      simulant_id first_name_census first_name_reference_file  \
# 63  7179_1069048              Maia                      Maia
# 64  7179_1069048              Maia                      Maia
# 65  7179_1069048              Maia                      Maia
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 63                  L                    Lilyana            Henry
# 64                  L                    Lilyana            Henry
# 65                  L                    Lilyana            Henry
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 63                    Henry           07/21/1964                     20221216
# 64                    Henry           07/21/1964                     20221216
# 65                    Henry           07/21/1964                     20221216
#
#    street_number_census street_number_reference_file street_name_census  \
# 63                 2509                         <NA>        westwood dr
# 64                 2509                         2509        westwood dr
# 65                 2509                         2509        westwood dr
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 63                       <NA>               <NA>                       <NA>
# 64                WESTWOOD DR               <NA>                       <NA>
# 65                WESTWOOD DR               <NA>                       <NA>
#
#        city_census city_reference_file state_census state_reference_file
# 63  little compton                <NA>           NH                 <NA>
# 64  little compton     LITTLE CORNPTON           NH                   RI
# 65  little compton      LITTLE COMPTON           NH                   RI
# 1597_1188844
#      simulant_id first_name_census first_name_reference_file  \
# 66  1597_1188844                 G                       Dan
# 67  1597_1188844                 G                       Dan
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 66                  C                     Connor       Abramowitz
# 67                  C                     Connor       Abramowitz
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 66               Abramowitz           09/25/2029                     20290925
# 67               Abramowitz           09/25/2029                     20290925
#
#    street_number_census street_number_reference_file street_name_census  \
# 66                 7003                         <NA>       sherwlod ave
# 67                 7003                         7003       sherwlod ave
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 66                       <NA>               <NA>                       <NA>
# 67               SHERWOOD AVE               <NA>                       <NA>
#
#      city_census city_reference_file state_census state_reference_file
# 66  block island                <NA>           RI                 <NA>
# 67  block island        BLOCK ISLAND           RI                   RI
# 3624_119898
#     simulant_id first_name_census first_name_reference_file  \
# 68  3624_119898              Erin                      Erin
# 69  3624_119898              Erin                      Erin
# 70  3624_119898              Erin                      Erin
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 68                  E                      Erica            Alley
# 69                  E                      Erica            Alley
# 70                  E                      Erica            Alley
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 68                    Alley           10/17/1992                     20261112
# 69                    Alley           10/17/1992                     20261112
# 70                    Alley           10/17/1992                     20261112
#
#    street_number_census street_number_reference_file street_name_census  \
# 68                  186                          186          paxton st
# 69                  186                         <NA>          paxton st
# 70                  186                          186          paxton st
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 68                  PAXTON ST               <NA>                       <NA>
# 69                       <NA>               <NA>                       <NA>
# 70                  PAXTON ST               <NA>                       <NA>
#
#      city_census city_reference_file state_census state_reference_file
# 68  west warwick        WEST WARWICK           RI                   RI
# 69  west warwick                <NA>           RI                 <NA>
# 70  west warwick        WEST WARWICK           RI                   RI
# 7344_892187
#     simulant_id first_name_census first_name_reference_file  \
# 71  7344_892187            Robert                    Robert
# 72  7344_892187            Robert                    Robert
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 71                  S                       Sean              Kim
# 72                  S                       Sean              Kim
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 71                 Of House           02/14/2604                     20040214
# 72                 Of House           02/14/2604                     20040214
#
#    street_number_census street_number_reference_file street_name_census  \
# 71                    5                         <NA>     delaware avenu
# 72                    5                            5     delaware avenu
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 71                       <NA>               <NA>                       <NA>
# 72             DELAWARE AVENU               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 71      exeter                <NA>           RI                 <NA>
# 72      exeter              EXETER           RI                   RI
# 9772_621190
#     simulant_id first_name_census first_name_reference_file  \
# 73  9772_621190              Lynn                      Lynn
# 74  9772_621190              Lynn                      Lynn
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 73                  K                   Kathleen          Farrell
# 74                  K                   Kathleen          Farrell
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 73                  Farrell           02/18/1959                     19590608
# 74                  Farrell           02/18/1959                     19590608
#
#    street_number_census street_number_reference_file street_name_census  \
# 73                24831                        24831         s avenue h
# 74                24831                         <NA>         s avenue h
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 73                 S AVENUE H      apartment 469              APARTMENT 469
# 74                       <NA>      apartment 469                       <NA>
#
#         city_census city_reference_file state_census state_reference_file
# 73  north kingstown     NORTH KINGSTOWN           RI                   RI
# 74  north kingstown                <NA>           RI                 <NA>
# 2721_917949
#     simulant_id first_name_census first_name_reference_file  \
# 75  2721_917949             Gavin                     Gavin
# 76  2721_917949             Gavin                     Gavin
# 77  2721_917949             Gavin                     Gavin
# 78  2721_917949             Gavin                     Gavin
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 75                  J                    Justice           Moreno
# 76                  J                    Justice           Moreno
# 77                  J                    Justice           Moreno
# 78                  J                    Justice           Moreno
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 75                   Moreno           12/04/2002                     20020412
# 76                   Moreno           12/04/2002                     20020412
# 77                   Moreno           12/04/2002                     20020412
# 78                   Moreno           12/04/2002                     20020412
#
#    street_number_census street_number_reference_file street_name_census  \
# 75                 5530                         5530           e lee st
# 76                 5530                         <NA>           e lee st
# 77                 5530                         5530           e lee st
# 78                 5530                         5530           e lee st
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 75                   E LEE ST               <NA>                       <NA>
# 76                       <NA>               <NA>                       <NA>
# 77                   E LEE ST               <NA>                       <NA>
# 78                   E LEE ST               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 75  portsmouth                <NA>           RI                   RI
# 76  portsmouth                <NA>           RI                 <NA>
# 77  portsmouth          PORTSMOUTH           RI                   RI
# 78  portsmouth          PORTSMOUTH           RI                   RI
# 3298_1082703
#      simulant_id first_name_census first_name_reference_file  \
# 79  3298_1082703         Genevieve                 Genevieve
# 80  3298_1082703         Genevieve                 Genevieve
# 81  3298_1082703         Genevieve                 Genevieve
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 79                  Z                        Zoe          Mahoney
# 80                  Z                        Zoe          Mahoney
# 81                  Z                        Zoe          Mahoney
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 79                  Mahoney           09/10/2023                     20231009
# 80                  Mahoney           09/10/2023                     20231009
# 81                  Mahoney           09/10/2023                     20231009
#
#    street_number_census street_number_reference_file street_name_census  \
# 79                 1410                         1410           pansy rd
# 80                 1410                         <NA>           pansy rd
# 81                 1410                         1410           pansy rd
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 79                   PANSY RD               <NA>                       <NA>
# 80                       <NA>               <NA>                       <NA>
# 81                   PANSY RD               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 79  portsmouth          PORTSMOUTH           RI                   RI
# 80  portsmouth                <NA>           RI                 <NA>
# 81  portsmouth          PODTWMOUTH           RI                   RI
# 9740_924180
#     simulant_id first_name_census first_name_reference_file  \
# 82  9740_924180             Lucia                     Lucia
# 83  9740_924180             Lucia                     Lucia
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 82                  R                     Rhonda            Duffy
# 83                  R                     Rhonda            Duffy
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 82                The House           11/26/1961                         <NA>
# 83                The House           11/26/1961                         <NA>
#
#    street_number_census street_number_reference_file street_name_census  \
# 82                11460                         <NA>        larimer ave
# 83                11460                         <NA>        larimer ave
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 82                       <NA>               <NA>                       <NA>
# 83                       <NA>               <NA>                       <NA>
#
#     city_census city_reference_file state_census state_reference_file
# 82  charlestown             NEWPORT           RI                   RI
# 83  charlestown                <NA>           RI                 <NA>
# 5875_557972
#     simulant_id first_name_census first_name_reference_file  \
# 84  5875_557972                 L                  Penelope
# 85  5875_557972                 L                  Penelope
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 84           Penelope                       Lily            Smith
# 85           Penelope                       Lily            Smith
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 84                    Smith           01/13/2017                     20170113
# 85                    Smith           01/13/2017                     20170113
#
#    street_number_census street_number_reference_file street_name_census  \
# 84                   39                           39     gate house trl
# 85                   39                         <NA>     gate house trl
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 84             GATE HOUSE TRL               <NA>                       <NA>
# 85                       <NA>               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 84    cranston            CRANSTON           RI                   RI
# 85    cranston                <NA>           RI                 <NA>
# 9526_137552
#     simulant_id first_name_census first_name_reference_file  \
# 86  9526_137552           Juanita                   Juanita
# 87  9526_137552           Juanita                   Juanita
# 88  9526_137552           Juanita                   Juanita
# 89  9526_137552           Juanita                   Juanita
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 86                  T                      Tammy           Joseph
# 87                  T                      Tammy           Joseph
# 88                  T                      Tammy           Joseph
# 89                  T                      Tammy           Joseph
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 86                   Joseph           03/08/2027                     19690713
# 87                   Joseph           03/08/2027                     19690713
# 88                   Joseph           03/08/2027                     19690713
# 89                   Joseph           03/08/2027                     19690713
#
#    street_number_census street_number_reference_file street_name_census  \
# 86                 9877                         9877            burt st
# 87                 9877                         <NA>            burt st
# 88                 9877                         9877            burt st
# 89                 9877                         <NA>            burt st
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 86                    BURT ST               <NA>                       <NA>
# 87                    BURT ST               <NA>                       <NA>
# 88                    BURT ST               <NA>                       <NA>
# 89                       <NA>               <NA>                       <NA>
#
#         city_census city_reference_file state_census state_reference_file
# 86  south kingstown     SOUTH KINGSTOWN           RI                   RI
# 87  south kingstown     SOUTH KINGSTOWN           RI                   NH
# 88  south kingstown     SOUTH KINGSTOWN           RI                   RI
# 89  south kingstown                <NA>           RI                 <NA>
# 3621_1148314
#      simulant_id first_name_census first_name_reference_file  \
# 90  3621_1148314              Bree                      Bree
# 91  3621_1148314              Bree                      Bree
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 90                  S                    Shannon       Touchstone
# 91                  S                    Shannon       Touchstone
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 90               Touchstone           08/10/1985                     19820217
# 91               Touchstone           08/10/1985                     19820217
#
#    street_number_census street_number_reference_file street_name_census  \
# 90                  850                          850               <NA>
# 91                  850                         <NA>               <NA>
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 90           ARLINGTON AVENUE               <NA>                       <NA>
# 91                       <NA>               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 90  middletown          MIDDLETOWN           RI                   RI
# 91  middletown                <NA>           RI                 <NA>
# 4802_1177756
#      simulant_id first_name_census first_name_reference_file  \
# 92  4802_1177756            Nephew                   Zachary
# 93  4802_1177756            Nephew                   Zachary
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 92                  A                       Alan              Cox
# 93                  A                       Alan              Cox
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 92                      Cox           03/22/2005                     20020622
# 93                      Cox           03/22/2005                     20020622
#
#    street_number_census street_number_reference_file street_name_census  \
# 92                 <NA>                         <NA>           saner rd
# 93                 <NA>                         <NA>           saner rd
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 92                   SANER RD               <NA>                       <NA>
# 93                       <NA>               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 92  cumberland          CUMBERLAND           RI                   RI
# 93  cumberland                <NA>           RI                 <NA>
# 8291_1049376
#      simulant_id first_name_census first_name_reference_file  \
# 94  8291_1049376            Daniel                    Daniel
# 95  8291_1049376            Daniel                    Daniel
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 94                  J                    Jeffrey             <NA>
# 95                  J                    Jeffrey             <NA>
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 94                  Landini           02/13/1974                     19700213
# 95                  Landini           02/13/1974                     19700213
#
#    street_number_census street_number_reference_file street_name_census  \
# 94                  438                         <NA>         drayton rd
# 95                  438                          438         drayton rd
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 94                       <NA>               <NA>                       <NA>
# 95                 DRAYTON RD               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 94    tiverton                <NA>          NaN                 <NA>
# 95    tiverton            TIVERTON          NaN                   RI
# 440_1076142
#      simulant_id first_name_census first_name_reference_file  \
# 96   440_1076142            Hudson                    Hudsog
# 97   440_1076142            Hudson                    Hudsog
# 98   440_1076142            Hudson                    Hudsog
# 99   440_1076142            Hudson                    Hudsog
# 100  440_1076142            Hudson                    Hudsog
#
#     middle_name_census middle_name_reference_file last_name_census  \
# 96                   N                      Nolan         Kemmerer
# 97                   N                      Nolan         Kemmerer
# 98                   N                      Nolan         Kemmerer
# 99                   N                      Nolan         Kemmerer
# 100                  N                      Nolan         Kemmerer
#
#     last_name_reference_file date_of_birth_census  \
# 96                  Kemmerer                 <NA>
# 97                  Kemmerer                 <NA>
# 98                  Kemmerer                 <NA>
# 99                  Kemmerer                 <NA>
# 100                 Kemmerer                 <NA>
#
#     date_of_birth_reference_file street_number_census  \
# 96                      20230430                  580
# 97                      20230430                  580
# 98                      20230430                  580
# 99                      20230430                  580
# 100                     20230430                  580
#
#     street_number_reference_file street_name_census  \
# 96                           580          school st
# 97                           580          school st
# 98                           580          school st
# 99                           580          school st
# 100                         <NA>          school st
#
#     street_name_reference_file unit_number_census unit_number_reference_file  \
# 96                   SCHOOL ST               <NA>                       <NA>
# 97                   SCHOOL ST               <NA>                       <NA>
# 98                   ACHIOL ST               <NA>                       <NA>
# 99                   SCHOOL ST               <NA>                       <NA>
# 100                       <NA>               <NA>                       <NA>
#
#     city_census city_reference_file state_census state_reference_file
# 96     johnston            JOHNSTON           RI                   ND
# 97     johnston            JOHNSYOH           RI                   RI
# 98     johnston            JOHNSTON           RI                   RI
# 99     johnston            JOHNSTON           RI                   RI
# 100    johnston                <NA>           RI                 <NA>

# %% [markdown]
# # Simulated PIK statistics
#
# Here we inspect the accuracy and characteristics of the PIKs assigned,
# leveraging our knowledge of ground truth from pseudopeople.
#
# It wouldn't be possible to do the ground truth part with the real PVS, but
# Layne, Wagner, and Rothhaas did something similar by redacting SSN from real records,
# sending them through PVS without the SSN, and then using the true SSN
# as ground truth.
# The health care records they used are probably quite different from a CUF,
# but they found a **very** good overall PIK accuracy (see cell below).

# %%
# Query planning is now on by default, but it has some rough edges.
# See https://github.com/dask/dask/issues/10995 for general discussion
# and https://github.com/dask/dask-expr/issues/1060 for the particular
# issue I ran into.
import dask
dask.config.set({"dataframe.query-planning": False})

# %%
import datetime, os, time

from vivarium_research_prl import distributed_compute, utils
from IPython.display import display

# %%
print(datetime.datetime.now())
# Out:
# 2024-05-24 07:26:32.677296

# %%
# DO NOT EDIT if this notebook is not called ground_truth_accuracy.ipynb!
# This notebook is designed to be run with papermill; this cell is tagged 'parameters'
data_to_use = 'small_sample'
simulated_data_output_dir = 'output/generate_simulated_data'
case_study_output_dir = 'output'

# The "compute engine" is what we use on the Python side
# for our case-study-specific operations,
# as opposed to the Splink engine
compute_engine = 'pandas'
# Only matter if using a distributed compute engine
compute_engine_num_jobs = 3
compute_engine_cpus_per_job = 2
compute_engine_memory_per_job = "5GB"
queue = "long.q"
local_directory = f"/tmp/{os.environ['USER']}_{int(time.time())}_dask"

# %%
# Parameters
data_to_use = "usa"
simulated_data_output_dir = "/mnt/team/simulation_science/priv/users/zmbc/prl/person_linkage_case_study/generate_simulated_data/"
case_study_output_dir = "/mnt/team/simulation_science/priv/users/zmbc/prl/person_linkage_case_study/results/"
compute_engine = "dask"
compute_engine_num_jobs = 50
compute_engine_memory_per_job = "120GB"
compute_engine_cpus_per_job = 2
local_directory = "/mnt/team/simulation_science/priv/users/zmbc/prl/person_linkage_case_study_tmp/dask/"

# %%
if compute_engine == 'dask':
    utils.ensure_empty(local_directory)

# %%
case_study_output_dir = f'{case_study_output_dir}/{data_to_use}'
simulated_data_output_dir = f'{simulated_data_output_dir}/{data_to_use}'

# %%
df_ops, pd = distributed_compute.start_compute_engine(
    compute_engine,
    num_jobs=compute_engine_num_jobs,
    cpus_per_job=compute_engine_cpus_per_job,
    memory_per_job=compute_engine_memory_per_job,
    queue=queue,
    local_directory=local_directory,
)
# Out:
# <Client: 'tcp://10.158.111.40:41733' processes=50 threads=50, memory=5.46 TiB>

# %%
census_2030_piked = df_ops.read_parquet(f'{case_study_output_dir}/census_2030_piked.parquet')
confirmed_piks_with_ground_truth = df_ops.read_parquet(f'{case_study_output_dir}/confirmed_piks.parquet')

# %%
piked_proportion = df_ops.compute(census_2030_piked.pik.notnull().mean())
# Compare with 90.28% of input records PIKed in the 2010 CUF,
# as reported in Wagner and Layne, Table 2, p. 18 
print(f'{piked_proportion:.2%} of the input records were PIKed')
# Out:
# 89.49% of the input records were PIKed

# %%
# Multiple Census rows assigned the same PIK, indicating the model thinks they are duplicates in Census
pik_sizes = df_ops.persist(df_ops.groupby_agg_small_groups(census_2030_piked, by='pik', agg_func=lambda x: x.size()))
df_ops.compute(pik_sizes.value_counts())
# Out:
# 1    305481683
# 2       704594
# 3          914
# 4           13
# Name: count, dtype: int64

# %%
# Interesting: in pseudopeople, sometimes siblings are assigned the same (common) first name, making them almost identical.
# The only giveaway is their age and DOB.
# Presumably, this tends not to happen in real life.
duplicate_piks = pik_sizes.rename('pik_size').reset_index().pipe(lambda df: df[df.pik_size > 1])

df_ops.head(census_2030_piked.merge(duplicate_piks, on="pik").sort_values('pik'))
# Out:
#      household_id first_name middle_initial    last_name age date_of_birth  \
# 2716  3632_492800       Amir              M  Lopez Ponce   2    0|/1G/2028
# 2731  3632_492800     Amanda              M  Lopez Ponce  26    01/16/2028
# 404    3978_12573        Sam              D     Thompson  57    09/21/1941
# 3853   3978_12573       Carl              D     Thompson  88    09/21/1941
# 1792   3465_41355     Samara              N       Cooley  12    09/19/2017
# 2455   3465_41355   Gretchen              N       Cooley  50    09/19/2017
# 1083  7817_307328      Dylan              E       Gaines  12    06/17/2017
# 2582  7817_535954      Dylan              E       Gaines  12    06/17/2017
# 2003  5548_619778    Richard              D     Martinez  75    04/19/1954
# 3992  2965_369050    Richard              D     Martinez  75    04/19/1954
#
#      street_number      street_name unit_number         city state zipcode  \
# 2716          7323     s pleasant 2        <NA>    hillsboro    OR   97058
# 2731          7323     s pleasant 2        <NA>    hillsboro    OR   97058
# 404             19     beryl street        <NA>     new york    NY   11236
# 3853            19     beryl street        <NA>     new york    NY   11236
# 1792          5014      242nd st sw   flat 5204      burbank    CA   94589
# 2455          5014      242nd st sw   flat 5204      burbank    CA   94589
# 1083          <NA>       fox bnd ct        <NA>  grand blanc    MI   49657
# 2582           615        sisson st        <NA>           fw   NaN   46268
# 2003           122    sea forest dr        <NA>       albany    NY   14845
# 3992         11561  highland avenue        <NA>         <NA>    OR   97333
#
#      housing_type relationship_to_reference_person     sex race_ethnicity  \
# 2716    Household                 Biological child    Male         Latino
# 2731    Household                 Reference person  Female         Latino
# 404     Household                   Other relative    Male          Black
# 3853    Household                 Reference person    Male          Black
# 1792    Household                 Biological child  Female         Latino
# 2455    Household              Opposite-sex spouse  Female         Latino
# 1083    Household                          Sibling    Male          White
# 2582    Household                   Other relative    Male          White
# 2003    Household                 Reference person    Male         Latino
# 3992    Household                 Reference person    Male         Latino
#
#       year                          record_id           pik  pik_size
# 2716  2030   simulated_census_2030_125_986313  100_10000288         2
# 2731  2030   simulated_census_2030_125_776710  100_10000288         2
# 404   2030    simulated_census_2030_137_26611  100_10000733         2
# 3853  2030    simulated_census_2030_137_26608  100_10000733         2
# 1792  2030    simulated_census_2030_111_86813  100_10001394         2
# 2455  2030    simulated_census_2030_111_86810  100_10001394         2
# 1083  2030   simulated_census_2030_266_644676  100_10001446         2
# 2582  2030  simulated_census_2030_266_1025393  100_10001446         2
# 2003  2030   simulated_census_2030_185_229434  100_10001642         2
# 3992  2030    simulated_census_2030_91_774182  100_10001642         2

# %% [markdown]
# ## Ground truth statistics

# %%
census_2030_ground_truth = df_ops.persist(
    df_ops.read_parquet(f'{simulated_data_output_dir}/simulated_census_2030_ground_truth.parquet')
)

# %%
# In this version of pseudopeople, there are no actual duplicates in Census,
# which means all of the duplicates identified above are wrong.
assert len(census_2030_ground_truth) == len(df_ops.drop_duplicates(census_2030_ground_truth))

# %%
reference_files_ground_truth = df_ops.persist(df_ops.concat([
    df_ops.read_parquet(f'{simulated_data_output_dir}/simulated_geobase_reference_file_ground_truth.parquet').drop(columns=['n_unique_simulants']),
    df_ops.read_parquet(f'{simulated_data_output_dir}/simulated_name_dob_reference_file_ground_truth.parquet').drop(columns=['n_unique_simulants']),
], ignore_index=True))
# Out:
# Imbalanced dataframe: too_few=False, too_many=True, too_large=False
# count    8.720000e+02
# mean     4.181848e+07
# std      5.982166e+04
# min      4.164159e+07
# 25%      4.177921e+07
# 50%      4.182007e+07
# 75%      4.185967e+07
# max      4.199184e+07
# dtype: float64
# Creating partitions of 729MB

# %%
# However, there can be reference file records that correspond to multiple simulants,
# due to errors in the reference file construction by SSN
n_unique_simulants = df_ops.persist(df_ops.groupby_agg_small_groups(reference_files_ground_truth, by='record_id', agg_func=lambda x: x.simulant_id.nunique()).rename('n_unique_simulants').reset_index())
df_ops.compute(n_unique_simulants.n_unique_simulants.value_counts())
# Out:
# n_unique_simulants
# 1    1229004194
# 2      59018942
# 3       1771457
# 4        102373
# 5          6077
# 6           351
# 7            16
# 8             1
# 9             1
# Name: count, dtype: int64

# %%
reference_files_ground_truth = df_ops.persist(reference_files_ground_truth.merge(
    n_unique_simulants,
    on='record_id',
    how='left',
))
reference_files_ground_truth.head(n=100)
# Out:
#                                      record_id   simulant_id  \
# 0   simulated_geobase_reference_file_0_1010897    1559_19394
# 1   simulated_geobase_reference_file_0_1021693   6203_718056
# 2   simulated_geobase_reference_file_0_1028097   6793_444873
# 3   simulated_geobase_reference_file_0_1047685   6554_270819
# 4   simulated_geobase_reference_file_0_1057134   9495_189946
# ..                                         ...           ...
# 95  simulated_geobase_reference_file_0_2452588  2808_1138496
# 96   simulated_geobase_reference_file_0_246654   5831_663211
# 97  simulated_geobase_reference_file_0_2568436   6090_393091
# 98   simulated_geobase_reference_file_0_258644   4922_953730
# 99  simulated_geobase_reference_file_0_2590431   8641_787350
#
#     n_unique_simulants
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    2
# ..                 ...
# 95                   1
# 96                   1
# 97                   1
# 98                   1
# 99                   3
#
# [100 rows x 3 columns]

# %%
df_ops.head(reference_files_ground_truth[reference_files_ground_truth.n_unique_simulants == df_ops.compute(reference_files_ground_truth.n_unique_simulants.max())])
# Out:
#                                             record_id simulant_id  \
# 2185016  simulated_geobase_reference_file_102_1340703  6554_95394
# 2185017  simulated_geobase_reference_file_102_1340703  6554_95393
# 2185018  simulated_geobase_reference_file_102_1340703  6554_95397
# 2185019  simulated_geobase_reference_file_102_1340703  6554_95403
# 2185020  simulated_geobase_reference_file_102_1340703  6554_95389
# 2185021  simulated_geobase_reference_file_102_1340703  6554_95392
# 2185022  simulated_geobase_reference_file_102_1340703  6554_95396
# 2185023  simulated_geobase_reference_file_102_1340703  6554_95395
# 2185024  simulated_geobase_reference_file_102_1340703  6554_95406
#
#          n_unique_simulants
# 2185016                   9
# 2185017                   9
# 2185018                   9
# 2185019                   9
# 2185020                   9
# 2185021                   9
# 2185022                   9
# 2185023                   9
# 2185024                   9

# %%
census_2030_ground_truth = df_ops.persist(census_2030_ground_truth.merge(
    df_ops.drop_duplicates(reference_files_ground_truth[['simulant_id']]).assign(possible_to_pik=1),
    on='simulant_id',
    how='left',
).assign(possible_to_pik=lambda df: df.possible_to_pik.fillna(0)))
possible_to_pik_proportion = df_ops.compute(census_2030_ground_truth.possible_to_pik.mean())
print(
    f'{(1 - possible_to_pik_proportion):.2%} of the input records are '
    'impossible to PIK correctly, since they are not in any reference files'
)
# Out:
# 0.43% of the input records are impossible to PIK correctly, since they are not in any reference files

# %%
print(
    f'Assigned PIKs to {(piked_proportion / possible_to_pik_proportion):.2%} of PIK-able records'
)
# Out:
# Assigned PIKs to 89.87% of PIK-able records

# %%
reference_file = df_ops.concat([
    df_ops.read_parquet(
        f'{simulated_data_output_dir}/simulated_geobase_reference_file.parquet',
    ),
    df_ops.read_parquet(
        f'{simulated_data_output_dir}/simulated_name_dob_reference_file.parquet',
    ),
], ignore_index=True)

# %%
reference_file_piks = df_ops.persist(reference_file[['record_id', 'pik']])
reference_file_piks
# Out:
# Dask DataFrame Structure:
#                 record_id     pik
# npartitions=358
#                    string  string
#                       ...     ...
# ...                   ...     ...
#                       ...     ...
#                       ...     ...
# Dask Name: getitem, 1 graph layer

# %%
assert len(reference_file_piks) == len(df_ops.drop_duplicates(reference_file_piks[['record_id']]))

# %%
pik_simulant_pairs = df_ops.persist(df_ops.drop_duplicates(reference_files_ground_truth.merge(reference_file_piks, on='record_id')[['pik', 'simulant_id']]))

# %%
# However, there can be PIKs that correspond to multiple simulants,
# due to errors in the reference file construction by SSN
n_unique_simulants = df_ops.persist(df_ops.groupby_agg_small_groups(pik_simulant_pairs, by='pik', agg_func=lambda x: x.simulant_id.nunique()).rename('n_unique_simulants').reset_index())
df_ops.compute(n_unique_simulants.n_unique_simulants.value_counts())
# Out:
# n_unique_simulants
# 1      353923759
# 2       41184067
# 3        3257802
# 4         225179
# 5          14963
#          ...
# 144            1
# 246            1
# 133            1
# 141            1
# 217            1
# Name: count, Length: 335, dtype: int64

# %%
pik_simulant_pairs = df_ops.persist(pik_simulant_pairs.merge(
    n_unique_simulants,
    on='pik',
    how='left',
))
pik_simulant_pairs
# Out:
# Dask DataFrame Structure:
#                     pik simulant_id n_unique_simulants
# npartitions=740
#                  string      string              int64
#                     ...         ...                ...
# ...                 ...         ...                ...
#                     ...         ...                ...
#                     ...         ...                ...
# Dask Name: hash-join, 1 graph layer

# %%
df_ops.head(pik_simulant_pairs[pik_simulant_pairs.n_unique_simulants == df_ops.compute(pik_simulant_pairs.n_unique_simulants.max())])
# Out:
#                pik  simulant_id  n_unique_simulants
# 552933  93_9726622  1655_508547                 335
# 552934  93_9726622  7264_376391                 335
# 552935  93_9726622  4123_481173                 335
# 552936  93_9726622  6520_143952                 335
# 552937  93_9726622  1282_490678                 335
# 552938  93_9726622  7850_493685                 335
# 552939  93_9726622  6144_432000                 335
# 552940  93_9726622  3377_480936                 335
# 552941  93_9726622  8997_280916                 335
# 552942  93_9726622  1897_265557                 335

# %% [markdown]
# ## Definitions of accuracy
#
# 1. (most strict) Assigning any PIK with multiple simulants is incorrect
# 2. Assigning a PIK with multiple simulants is neither incorrect nor correct (excluded from denominator)
# 3. (most lenient) Assigning a PIK with multiple simulants is correct, as long as at least one of those simulants matches the truth

# %%
# All modules, Medicare database, calculated from Layne, Wagner, and Rothhaas Table 1 (p. 15)
real_life_pvs_accuracy = 1 - (2_585 + 60_709 + 129_480 + 89_094) / (52_406_981 + 5_170_924 + 49_374_794 + 50_327_034)
f'{real_life_pvs_accuracy:.5%}'
# Out:
# '99.82079%'

# %% [markdown]
# ### Definition 1

# %%
piks_assigned = df_ops.compute(census_2030_piked.pik.notnull().sum())
piks_assigned
# Out:
# 306893665

# %%
df_ops.head(pik_simulant_pairs[pik_simulant_pairs.n_unique_simulants > 1])
# Out:
#              pik   simulant_id  n_unique_simulants
# 4   100_10001131   1299_577845                   2
# 5   100_10001131   7344_252780                   2
# 12  100_10005841   2787_347774                   2
# 13  100_10005841   2787_692084                   2
# 14  100_10006089  8869_1057428                   2
# 15  100_10006089   8869_714641                   2
# 25  100_10013375  3984_1041763                   2
# 26  100_10013375   3984_271827                   2
# 77  100_10044433   3465_567846                   2
# 78  100_10044433  8134_1070213                   2

# %%
single_sim_piks_correct = df_ops.compute(
    census_2030_piked[['record_id', 'pik']].merge(pik_simulant_pairs, on='pik').merge(census_2030_ground_truth, on='record_id')
        .pipe(lambda df: (df.simulant_id_x == df.simulant_id_y) & (df.n_unique_simulants == 1))
        .sum()
)
single_sim_piks_correct
# Out:
# 270242236

# %%
# Overall accuracy, treating it as a black box
(
    single_sim_piks_correct / piks_assigned
)
# Out:
# 0.8805728720402228

# %%
assert len(confirmed_piks_with_ground_truth) == piks_assigned

# %%
df_ops.head(census_2030_ground_truth.rename(columns={'record_id': 'record_id_census_2030'}))
# Out:
#           record_id_census_2030 simulant_id  possible_to_pik
# 0   simulated_census_2030_0_428      28_512              1.0
# 1  simulated_census_2030_0_1517     28_1781              1.0
# 2  simulated_census_2030_0_2703     28_3203              1.0
# 3  simulated_census_2030_0_3657     28_4338              1.0
# 4  simulated_census_2030_0_4661     28_5528              1.0
# 5  simulated_census_2030_0_4773     28_5659              1.0
# 6  simulated_census_2030_0_4791     28_5679              1.0
# 7  simulated_census_2030_0_5737     28_6800              1.0
# 8  simulated_census_2030_0_6401     28_7571              1.0
# 9  simulated_census_2030_0_6800     28_8045              1.0

# %%
# Looking at whether the exact *record* linked was from the same simulant
single_sim_record_links_correct = df_ops.compute(
    confirmed_piks_with_ground_truth
        .merge(
            census_2030_ground_truth.rename(columns={'record_id': 'record_id_raw_input_file'}),
            on='record_id_raw_input_file',
        )
        .merge(
            reference_files_ground_truth.rename(columns={'record_id': 'record_id_reference_file'}),
            on='record_id_reference_file',
        )
        .pipe(lambda df: (df.simulant_id_x == df.simulant_id_y) & (df.n_unique_simulants == 1))
        .sum()
)
single_sim_record_links_correct
# Out:
# 287197731

# %%
(
    single_sim_record_links_correct / piks_assigned
)
# Out:
# 0.9358216338548403

# %% [markdown]
# ### Definition 2

# %%
single_sim_piks_assigned = len(census_2030_piked[['record_id', 'pik']].merge(pik_simulant_pairs[pik_simulant_pairs.n_unique_simulants == 1][['pik', 'simulant_id']]))
single_sim_piks_assigned
# Out:
# 270448733

# %%
# Overall accuracy, treating it as a black box
(
    single_sim_piks_correct / single_sim_piks_assigned
)
# Out:
# 0.9992364652712202

# %%
# Looking at whether the exact *record* linked was from the same simulant
single_sim_record_links_assigned = df_ops.compute(
    (confirmed_piks_with_ground_truth
        .merge(
            reference_files_ground_truth.rename(columns={'record_id': 'record_id_reference_file'}),
            on='record_id_reference_file',
        )
        .n_unique_simulants == 1).sum()
)
single_sim_record_links_assigned
# Out:
# 287419292

# %%
(
    single_sim_record_links_correct / single_sim_record_links_assigned
)
# Out:
# 0.9992291366440357

# %% [markdown]
# ### Definition 3

# %%
pik_simulant_pairs
# Out:
# Dask DataFrame Structure:
#                     pik simulant_id n_unique_simulants
# npartitions=740
#                  string      string              int64
#                     ...         ...                ...
# ...                 ...         ...                ...
#                     ...         ...                ...
#                     ...         ...                ...
# Dask Name: hash-join, 1 graph layer

# %%
piks_at_least_partially_correct = df_ops.persist(
    census_2030_piked[['record_id', 'pik']].merge(pik_simulant_pairs, on='pik').merge(census_2030_ground_truth, on='record_id')
        .pipe(df_ops.drop_duplicates)
        .assign(correct=lambda df: df.simulant_id_x == df.simulant_id_y)
        .pipe(df_ops.groupby_agg_small_groups, by=["record_id", "pik"], agg_func=lambda x: x.correct.any())
        .reset_index()
)
piks_at_least_partially_correct
# Out:
# Imbalanced dataframe: too_few=False, too_many=True, too_large=False
# count    1.480000e+03
# mean     2.654147e+07
# std      4.395391e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.454150e+04
# 75%      2.244691e+07
# max      2.658089e+08
# dtype: float64
# Creating partitions of 786MB
# Dask DataFrame Structure:
#                record_id     pik        correct
# npartitions=54
#                   string  string  bool[pyarrow]
#                      ...     ...            ...
# ...                  ...     ...            ...
#                      ...     ...            ...
#                      ...     ...            ...
# Dask Name: reset_index, 1 graph layer

# %%
# Overall accuracy, treating it as a black box
piks_correct_proportion = (df_ops.compute(piks_at_least_partially_correct.correct.sum()) / piks_assigned)
piks_correct_proportion
# Out:
# 0.9992483976493943

# %%
print(f'{piks_correct_proportion:.5%} of the PIKs assigned were correct; compare with {real_life_pvs_accuracy:.5%} in real life')
# Out:
# 99.92484% of the PIKs assigned were correct; compare with 99.82079% in real life

# %%
# Looking at whether the exact *record* linked was from the same simulant
sim_record_links_at_least_partially_correct = df_ops.persist(
    confirmed_piks_with_ground_truth
        .merge(
            census_2030_ground_truth.rename(columns={'record_id': 'record_id_raw_input_file'}),
            on='record_id_raw_input_file',
        )
        .merge(
            reference_files_ground_truth.rename(columns={'record_id': 'record_id_reference_file'}),
            on='record_id_reference_file',
        )
        .assign(correct=lambda df: df.simulant_id_x == df.simulant_id_y)
        .pipe(df_ops.groupby_agg_small_groups, by=["record_id_raw_input_file", "record_id_reference_file", "pik", "module_name", "pass_name"], agg_func=lambda x: x.correct.any())
        .reset_index()
)
sim_record_links_at_least_partially_correct
# Out:
# Dask DataFrame Structure:
#                 record_id_raw_input_file record_id_reference_file     pik module_name pass_name        correct
# npartitions=849
#                                   string                   string  string      string    string  bool[pyarrow]
#                                      ...                      ...     ...         ...       ...            ...
# ...                                  ...                      ...     ...         ...       ...            ...
#                                      ...                      ...     ...         ...       ...            ...
#                                      ...                      ...     ...         ...       ...            ...
# Dask Name: reset_index, 1 graph layer

# %%
len(sim_record_links_at_least_partially_correct)
# Out:
# 306893665

# %%
len(df_ops.drop_duplicates(sim_record_links_at_least_partially_correct[['record_id_raw_input_file', 'record_id_reference_file']]))
# Out:
# Imbalanced dataframe: too_few=False, too_many=True, too_large=False
# count    1.698000e+03
# mean     1.641192e+07
# std      2.845312e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.113800e+04
# 75%      1.022008e+07
# max      1.561296e+08
# dtype: float64
# Creating partitions of 557MB
# 306893665

# %%
(
    df_ops.compute(sim_record_links_at_least_partially_correct.correct.sum()) / piks_assigned
)
# Out:
# 0.9992451685178969

# %%
assert df_ops.compute((df_ops.groupby_agg_small_groups(confirmed_piks_with_ground_truth, by='record_id_raw_input_file', agg_func=lambda x: x.record_id_reference_file.nunique()) <= 1).all())

# %%
# Using definition 3 -- at the PIK level
piks_at_least_partially_correct = df_ops.persist(
    piks_at_least_partially_correct
        .rename(columns={'record_id': 'record_id_raw_input_file'})
        .merge(confirmed_piks_with_ground_truth[['record_id_raw_input_file', 'module_name', 'pass_name']], on='record_id_raw_input_file')
)
piks_at_least_partially_correct
# Out:
# Dask DataFrame Structure:
#                 record_id_raw_input_file     pik        correct module_name pass_name
# npartitions=849
#                                   string  string  bool[pyarrow]      string    string
#                                      ...     ...            ...         ...       ...
# ...                                  ...     ...            ...         ...       ...
#                                      ...     ...            ...         ...       ...
#                                      ...     ...            ...         ...       ...
# Dask Name: hash-join, 1 graph layer

# %%
# Accuracy by module -- note that this shows the opposite pattern (with the sample data)
# relative to the results of Layne et al., who found GeoSearch was much *more* accurate
df_ops.compute(piks_at_least_partially_correct.groupby("module_name").correct.agg(["mean", "size"]).sort_values("mean"))
# Out:
#                   mean       size
# module_name
# dobsearch     0.995207     157934
# namesearch    0.997353   18703967
# geosearch     0.999372  287235940
# hhcompsearch  0.999913     795824

# %%
# Accuracy by pass -- could be used to tune pass-specific cutoffs, but
# this might not be too informative while we are still using the sample data.
df_ops.compute(piks_at_least_partially_correct.groupby(["module_name", "pass_name"]).correct.agg(["mean", "size"]).sort_values("mean"))
# Out:
#                                                                    mean  \
# module_name  pass_name
# dobsearch    initials name switch                              0.995207
# namesearch   DOB and NYSIIS of name                            0.997353
# geosearch    geokey name switch                                0.998792
# namesearch   DOB and initials                                  0.999002
# geosearch    geokey                                            0.999266
# hhcompsearch year of birth                                     0.999865
# geosearch    house number and street name Soundex name switch  0.999957
# hhcompsearch initials                                          0.999962
# geosearch    some name and DOB information                     0.999974
#              house number and street name Soundex              0.999975
#
#                                                                     size
# module_name  pass_name
# dobsearch    initials name switch                                 157934
# namesearch   DOB and NYSIIS of name                             18701962
# geosearch    geokey name switch                                   899891
# namesearch   DOB and initials                                       2005
# geosearch    geokey                                            242653619
# hhcompsearch year of birth                                        400996
# geosearch    house number and street name Soundex name switch      46424
# hhcompsearch initials                                             394828
# geosearch    some name and DOB information                      30018460
#              house number and street name Soundex               13617546

# %%
# Using definition 3 -- at the link level
df_ops.compute(sim_record_links_at_least_partially_correct.groupby("module_name").correct.agg(["mean", "size"]).sort_values("mean"))
# Out:
#                   mean       size
# module_name
# dobsearch     0.995207     157934
# namesearch    0.997353   18703967
# geosearch     0.999369  287235940
# hhcompsearch  0.999912     795824

# %%
df_ops.compute(sim_record_links_at_least_partially_correct.groupby(["module_name", "pass_name"]).correct.agg(["mean", "size"]).sort_values("mean"))
# Out:
#                                                                    mean  \
# module_name  pass_name
# dobsearch    initials name switch                              0.995207
# namesearch   DOB and NYSIIS of name                            0.997353
# geosearch    geokey name switch                                0.998789
# namesearch   DOB and initials                                  0.999002
# geosearch    geokey                                            0.999262
# hhcompsearch year of birth                                     0.999865
# geosearch    house number and street name Soundex name switch  0.999957
# hhcompsearch initials                                          0.999959
# geosearch    some name and DOB information                     0.999974
#              house number and street name Soundex              0.999974
#
#                                                                     size
# module_name  pass_name
# dobsearch    initials name switch                                 157934
# namesearch   DOB and NYSIIS of name                             18701962
# geosearch    geokey name switch                                   899891
# namesearch   DOB and initials                                       2005
# geosearch    geokey                                            242653619
# hhcompsearch year of birth                                        400996
# geosearch    house number and street name Soundex name switch      46424
# hhcompsearch initials                                             394828
# geosearch    some name and DOB information                      30018460
#              house number and street name Soundex               13617546

# %%
df_ops.compute(sim_record_links_at_least_partially_correct[~sim_record_links_at_least_partially_correct.correct].groupby(["module_name", "pass_name"]).size()).sort_values()
# Out:
# module_name   pass_name
# namesearch    DOB and initials                                         2
# geosearch     house number and street name Soundex name switch         2
# hhcompsearch  initials                                                16
#               year of birth                                           54
# geosearch     house number and street name Soundex                   352
# dobsearch     initials name switch                                   757
# geosearch     some name and DOB information                          788
#               geokey name switch                                    1090
# namesearch    DOB and NYSIIS of name                               49509
# geosearch     geokey                                              179083
# dtype: int64

# %% [markdown]
# ### Incorrect and missed PIKs

# %%
incorrectly_linked_pairs = df_ops.persist(df_ops.drop_duplicates(
    sim_record_links_at_least_partially_correct[~sim_record_links_at_least_partially_correct.correct]
        [["record_id_raw_input_file", "record_id_reference_file"]]
))
incorrectly_linked_pairs
# Out:
# Imbalanced dataframe: too_few=False, too_many=True, too_large=False
# count     1698.000000
# mean     12469.694935
# std      12490.898424
# min          0.000000
# 25%          0.000000
# 50%       9535.500000
# 75%      24951.250000
# max      28393.000000
# dtype: float64
# Creating partitions of 100MB
# Dask DataFrame Structure:
#               record_id_raw_input_file record_id_reference_file
# npartitions=1
#                                 string                   string
#                                    ...                      ...
# Dask Name: repartition, 1 graph layer

# %%
len(incorrectly_linked_pairs)
# Out:
# 231653

# %%
incorrect_links = df_ops.head(incorrectly_linked_pairs, n=100)
incorrect_links
# Out:
#            record_id_raw_input_file  \
# 0   simulated_census_2030_0_1000428
# 1   simulated_census_2030_0_1000771
# 2   simulated_census_2030_0_1000862
# 3   simulated_census_2030_0_1001175
# 4   simulated_census_2030_0_1001701
# ..                              ...
# 95   simulated_census_2030_0_151396
# 96   simulated_census_2030_0_151692
# 97    simulated_census_2030_0_15224
# 98   simulated_census_2030_0_152813
# 99     simulated_census_2030_0_1544
#
#                         record_id_reference_file
# 0   simulated_geobase_reference_file_179_1002396
# 1   simulated_geobase_reference_file_183_1468335
# 2   simulated_geobase_reference_file_147_3743026
# 3   simulated_name_dob_reference_file_17_7088846
# 4    simulated_geobase_reference_file_21_2470024
# ..                                           ...
# 95    simulated_geobase_reference_file_151_74598
# 96   simulated_geobase_reference_file_108_794912
# 97  simulated_geobase_reference_file_197_4064041
# 98  simulated_name_dob_reference_file_17_4241690
# 99  simulated_geobase_reference_file_133_3008139
#
# [100 rows x 2 columns]

# %%
# %xdel incorrectly_linked_pairs

# %%
comparison_cols = [
    "first_name",
    "middle_name",
    "last_name",
    "date_of_birth",
    "street_number",
    "street_name",
    "unit_number",
    "city",
    "state",
]

incorrect_links_detail = (
    incorrect_links
        .merge(
            df_ops.compute(census_2030_piked[census_2030_piked.record_id.isin(incorrect_links.record_id_raw_input_file)])
                .rename(columns={"record_id": "record_id_raw_input_file", "middle_initial": "middle_name"})
                [["record_id_raw_input_file"] + comparison_cols],
            on="record_id_raw_input_file",
            how="left",
        )
        .merge(
            df_ops.compute(reference_file[reference_file.record_id.isin(incorrect_links.record_id_reference_file)])
                .rename(columns={"record_id": "record_id_reference_file"})
                .rename(columns=lambda c: c.replace('mailing_address_', ''))
                [["record_id_reference_file"] + comparison_cols],
            on="record_id_reference_file",
            how="left",
            suffixes=("_census", "_reference_file"),
        )
)
def flatten(xss):
    return [x for xs in xss for x in xs]

incorrect_links_detail[flatten([(f'{c}_census', f'{c}_reference_file') for c in comparison_cols])]
# Out:
#    first_name_census first_name_reference_file middle_name_census  \
# 0             Aurora                      Dean                  G
# 1             Aurora                       Luz                  L
# 2               <NA>                  Benjamin                  R
# 3               Mila                      Mila                  G
# 4              Alaia                    Martin                  A
# ..               ...                       ...                ...
# 95           Zachary                   Michele                  J
# 96              Kash                    Carter                  M
# 97             Grant                      Chad                  B
# 98           Jackson                   Jackson                  B
# 99              Juan                      <NA>                  M
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 0                     Gabriel           Harmon                   Harmon
# 1                       Linda             Devi                     Devi
# 2                       David           Gatian                   Gatian
# 3                         Gia           Garcia                   Garcia
# 4                   Alexander            Reitz                    Reitz
# ..                        ...              ...                      ...
# 95                      Julie          Goldsby                  Goldsby
# 96                     Man Of           Waters                   Waters
# 97                       <NA>           Nijjar                   Nijjar
# 98                      Bodhi           Willis                   Willis
# 99                     Harper            Smith                    Smith
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 0            08/29/2028                     20280829                 5543
# 1            11/14/2022                     20221114                 2140
# 2            07/25/2024                     20240725                  606
# 3            10/07/2028                     20281007                  503
# 4            10/12/2028                     20281012                 6100
# ..                  ...                          ...                  ...
# 95           07/27/1966                     19660727          17823-17835
# 96           02/24/2009                     20090224                 4243
# 97           08/01/1943                     19430801                 1561
# 98           12/04/2018                     20181204                  620
# 99           10/03/2018                     20181003                 3099
#
#    street_number_reference_file   street_name_census  \
# 0                          5543          highway 413
# 1                          2140             hwy 88 w
# 2                           606  lincoln woods drive
# 3                          <NA>           n villa st
# 4                          6100       burdette drive
# ..                          ...                  ...
# 95                  17823-17835           polo pk dr
# 96                         4243         appian way w
# 97                         1561          hannalei pl
# 98                         <NA>        picketts cove
# 99                         3099     blue ridge av ne
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 0                 HIGHWAY 413               <NA>                       <NA>
# 1                    HWY 88 W               <NA>                       <NA>
# 2         LINCOLN WOODS DRIVE               <NA>                       <NA>
# 3                        <NA>               <NA>                       <NA>
# 4              BURDETTE DRIVE               <NA>                       <NA>
# ..                        ...                ...                        ...
# 95                 POLO PK DR               <NA>                       <NA>
# 96               APPIAN WAY W               <NA>                       <NA>
# 97                HANNALEI PL               <NA>                       <NA>
# 98                       <NA>  fl # 1 apt # 1010                       <NA>
# 99           BLUE RIDGE AV NE               <NA>                       <NA>
#
#       city_census city_reference_file state_census state_reference_file
# 0        richmond            RICHMOND           VA                   VA
# 1     winter park         WINTER PARK           FL                   FL
# 2         norfolk             NORFOLK           VA                   VA
# 3         sanford                <NA>           ME                 <NA>
# 4         chicago             CHICAGO           IL                   IL
# ..            ...                 ...          ...                  ...
# 95    east peoria         EAST PEORIA           IL                   IL
# 96     ridgefield          RIDGEFIELD           NJ                   NJ
# 97       martinez            MARTINEZ           CA                   CA
# 98    pine valley                <NA>           TX                 <NA>
# 99  commerce city       COMMERCE CITY           CO                   CO
#
# [100 rows x 18 columns]

# %%
missed_links = df_ops.persist(
    census_2030_piked[census_2030_piked.pik.isnull()][["record_id"]]
        .merge(census_2030_ground_truth, on="record_id")
        .merge(reference_files_ground_truth[reference_files_ground_truth.n_unique_simulants == 1], on="simulant_id", suffixes=("_census", "_reference_file"))
)

# %%
len(missed_links)
# Out:
# 107488068

# %%
simulants_missed = df_ops.head(missed_links[['simulant_id']], n=100).simulant_id.unique()
simulants_missed
# Out:
# <ArrowStringArray>
# [  '352_205030', '3454_1055553',  '1282_803576', '1482_1106062',
#  '1648_1145213',  '8612_598382',  '9696_241917',   '440_818214',
#  '5831_1163158',  '9643_779883', '2298_1157048',  '682_1102032',
#   '9804_323231',  '4649_635246', '9911_1133450',   '278_343671',
#   '7938_532559',  '6144_683864',  '9901_575637',   '6760_71186',
#   '3142_100881',   '107_178364', '4950_1032017',  '1182_579036',
#   '8869_544928', '9840_1053660',  '9740_349524',    '93_180423',
#  '3607_1151651', '8425_1183995']
# Length: 30, dtype: string

# %%
missed_pairs = df_ops.compute(missed_links[missed_links.simulant_id.isin(list(simulants_missed))])
missed_pairs
# Out:
#                       record_id_census   simulant_id  possible_to_pik  \
# 0      simulated_census_2030_11_172699    352_205030              1.0
# 1      simulated_census_2030_11_172699    352_205030              1.0
# 2      simulated_census_2030_11_172699    352_205030              1.0
# 3     simulated_census_2030_110_892085  3454_1055553              1.0
# 4     simulated_census_2030_110_892085  3454_1055553              1.0
# ..                                 ...           ...              ...
# 96      simulated_census_2030_2_152033     93_180423              1.0
# 97    simulated_census_2030_122_979888  3607_1151651              1.0
# 98    simulated_census_2030_122_979888  3607_1151651              1.0
# 99   simulated_census_2030_281_1010739  8425_1183995              1.0
# 100  simulated_census_2030_281_1010739  8425_1183995              1.0
#
#                          record_id_reference_file  n_unique_simulants
# 0     simulated_geobase_reference_file_35_3252330                   1
# 1    simulated_name_dob_reference_file_41_1554120                   1
# 2     simulated_geobase_reference_file_35_3252331                   1
# 3     simulated_geobase_reference_file_55_2082491                   1
# 4    simulated_name_dob_reference_file_26_3222629                   1
# ..                                            ...                 ...
# 96   simulated_name_dob_reference_file_10_4494978                   1
# 97    simulated_geobase_reference_file_86_2343454                   1
# 98   simulated_name_dob_reference_file_29_5413790                   1
# 99   simulated_name_dob_reference_file_42_1276576                   1
# 100  simulated_geobase_reference_file_200_3344039                   1
#
# [101 rows x 5 columns]

# %%
# %xdel missed_links

# %%
missed_links_detail = (
    missed_pairs
        .merge(
            df_ops.compute(census_2030_piked[census_2030_piked.record_id.isin(list(missed_pairs.record_id_census))])
                .rename(columns={"record_id": "record_id_census", "middle_initial": "middle_name"}),
            on="record_id_census",
        )
        .merge(
            df_ops.compute(reference_file[reference_file.record_id.isin(missed_pairs.record_id_reference_file)])
                .rename(columns=lambda c: c.replace('mailing_address_', ''))
                .rename(columns={"record_id": "record_id_reference_file"}),
            on="record_id_reference_file",
            suffixes=("_census", "_reference_file"),
        )
)

# %%
for simulant in simulants_missed:
    print(simulant)
    display(missed_links_detail[missed_links_detail.simulant_id == simulant][['simulant_id'] + flatten([(f'{c}_census', f'{c}_reference_file') for c in comparison_cols])])
# Out:
# 352_205030
#   simulant_id first_name_census first_name_reference_file middle_name_census  \
# 0  352_205030           Shlomie                      <NA>                  D
# 1  352_205030           Shlomie                      <NA>                  D
# 2  352_205030           Shlomie                      <NA>                  D
#
#   middle_name_reference_file last_name_census last_name_reference_file  \
# 0                     Desean        Smallwood                Smallwood
# 1                     Desean        Smallwood                Smallwood
# 2                     Desean        Smallwood                Smallwood
#
#   date_of_birth_census date_of_birth_reference_file street_number_census  \
# 0           22/10/1995                     19951022                14308
# 1           22/10/1995                     19951022                14308
# 2           22/10/1995                     19951022                14308
#
#   street_number_reference_file street_name_census street_name_reference_file  \
# 0                        14308           colby dr                       <NA>
# 1                         <NA>           colby dr                       <NA>
# 2                        14308           colby dr                   COLBY DR
#
#   unit_number_census unit_number_reference_file city_census  \
# 0               <NA>                       <NA>   watertown
# 1               <NA>                       <NA>   watertown
# 2               <NA>                       <NA>   watertown
#
#   city_reference_file state_census state_reference_file
# 0           WATERTOWN           CT                   CT
# 1                <NA>           CT                 <NA>
# 2           WATERTOWN           CT                   CT
# 3454_1055553
#     simulant_id first_name_census first_name_reference_file  \
# 3  3454_1055553         Knowledge                 Knowledge
# 4  3454_1055553         Knowledge                 Knowledge
#
#   middle_name_census middle_name_reference_file last_name_census  \
# 3                  B                        Mrs             Bach
# 4                  B                        Mrs             Bach
#
#   last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 3                     Bach           03/18/2022                     20261803
# 4                     Bach           03/18/2022                     20261803
#
#   street_number_census street_number_reference_file street_name_census  \
# 3                 <NA>                         <NA>         logans run
# 4                 <NA>                         <NA>         logans run
#
#   street_name_reference_file unit_number_census unit_number_reference_file  \
# 3                 LOGANS RUN               <NA>                       <NA>
# 4                       <NA>               <NA>                       <NA>
#
#   city_census city_reference_file state_census state_reference_file
# 3       rhome               RHOME           TX                   TX
# 4       rhome                <NA>           TX                 <NA>
# 1282_803576
#     simulant_id first_name_census first_name_reference_file  \
# 5   1282_803576           Jeffrey                   Jeffrey
# 6   1282_803576           Jeffrey                   Jeffrey
# 7   1282_803576           Jeffrey                   Jeffrey
# 8   1282_803576           Jeffrey                   Jeffrey
# 9   1282_803576           Jeffrey                   Jeffrey
# 10  1282_803576           Jeffrey                   Jeffrey
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 5                   T                     Thomas           Wilson
# 6                   T                     Thomas           Wilson
# 7                   T                     Thomas           Wilson
# 8                   T                     Thomas           Wilson
# 9                   T                     Thomas           Wilson
# 10                  T                     Thomas           Wilson
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 5                    Wilson           10/19/1990                     19901019
# 6                    Wilson           10/19/1990                     19901019
# 7                    Wilson           10/19/1990                     19901019
# 8                    Wilson           10/19/1990                     19901019
# 9                    Wilson           10/19/1990                     19901019
# 10                   Wilson           10/19/1990                     19901019
#
#    street_number_census street_number_reference_file street_name_census  \
# 5                  2119                        11690      pine ridge rd
# 6                  2119                         2119      pine ridge rd
# 7                  2119                         <NA>      pine ridge rd
# 8                  2119                         6594      pine ridge rd
# 9                  2119                         2119      pine ridge rd
# 10                 2119                         <NA>      pine ridge rd
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 5           NE TOMAHAWK ID DR               <NA>                       <NA>
# 6               PINE RIDGE RD               <NA>                       <NA>
# 7                        <NA>               <NA>                       <NA>
# 8                     POOL ST               <NA>                       <NA>
# 9               PINE RIDGE RD               <NA>                       <NA>
# 10              PINE RIDGE RD               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 5   belleville      SAN BERNARDINO           IL                   CA
# 6   belleville          BELLEVILLE           IL                 <NA>
# 7   belleville                <NA>           IL                 <NA>
# 8   belleville                  TC           IL                   TX
# 9   belleville          BELLEVILLE           IL                   IL
# 10  belleville          BELLEVILLE           IL                   IL
# 1482_1106062
#      simulant_id first_name_census first_name_reference_file  \
# 11  1482_1106062            Moriah                    Moriah
# 12  1482_1106062            Moriah                    Moriah
# 13  1482_1106062            Moriah                    Moriah
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 11                  Z                      Zhuri           Butler
# 12                  Z                      Zhuri           Butler
# 13                  Z                      Zhuri           Butler
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 11                   Butler           12/29/2024                         <NA>
# 12                   Butler           12/29/2024                         <NA>
# 13                   Butler           12/29/2024                         <NA>
#
#    street_number_census street_number_reference_file street_name_census  \
# 11                  680                         <NA>     whitehall road
# 12                  680                         <NA>     whitehall road
# 13                  680                          680     whitehall road
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 11                       <NA>               <NA>                       <NA>
# 12             WHITEHALL ROAD               <NA>                       <NA>
# 13             WHITEHALL ROAD               <NA>                       <NA>
#
#      city_census city_reference_file state_census state_reference_file
# 11  philadelphia                <NA>           PA                 <NA>
# 12  philadelphia        PHILADELPHIA           PA                   PA
# 13  philadelphia        PHILADELPHIA           PA                   PA
# 1648_1145213
#      simulant_id first_name_census first_name_reference_file  \
# 14  1648_1145213           Winston                   Winston
# 15  1648_1145213           Winston                   Winston
# 16  1648_1145213           Winston                   Winston
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 14                  L                      Logan           Gilpin
# 15                  L                      Logan           Gilpin
# 16                  L                      Logan           Gilpin
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 14                   Gilpin           04/16/2027                     20290402
# 15                   Gilpin           04/16/2027                     20290402
# 16                   Gilpin           04/16/2027                     20290402
#
#    street_number_census street_number_reference_file street_name_census  \
# 14                 1629                          385   hargis creek trl
# 15                 1629                         <NA>   hargis creek trl
# 16                 1629                         1629   hargis creek trl
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 14               LINDA VSTA R               <NA>                       <NA>
# 15                       <NA>               <NA>                       <NA>
# 16           HARGIS CREEK TRL               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 14     lynwood          WASHINGTON           IL                   DC
# 15     lynwood                <NA>           IL                 <NA>
# 16     lynwood             LYNWOOD           IL                   IL
# 8612_598382
#     simulant_id first_name_census first_name_reference_file  \
# 17  8612_598382           Susanne                   Susanne
# 18  8612_598382           Susanne                   Susanne
# 19  8612_598382           Susanne                   Susanne
# 20  8612_598382           Susanne                   Susanne
# 21  8612_598382           Susanne                   Susanne
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 17                  A                     Amanda       Tuberville
# 18                  A                     Amanda       Tuberville
# 19                  A                     Amanda       Tuberville
# 20                  A                     Amanda       Tuberville
# 21                  A                     Amanda       Tuberville
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 17               Tuberville           12/18/1999                     19850505
# 18               Tuberville           12/18/1999                     19850505
# 19               Tuberville           12/18/1999                     19850505
# 20               Tuberville           12/18/1999                     19850505
# 21               Tuberville           12/18/1999                     19850505
#
#    street_number_census street_number_reference_file street_name_census  \
# 17                   55                           55               <NA>
# 18                   55                           55               <NA>
# 19                   55                         3931               <NA>
# 20                   55                         <NA>               <NA>
# 21                   55                         <NA>               <NA>
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 17                   BRYAN LN               <NA>                       <NA>
# 18                   BRYAN LN               <NA>                       <NA>
# 19             MORSE OAKS CIR               <NA>                       <NA>
# 20                       <NA>               <NA>                       <NA>
# 21                   BRYAN LN               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 17       wayne               WAYNE           NJ                 <NA>
# 18       wayne               WAYNE           NJ                   NJ
# 19       wayne        WEST VINCENT           NJ                   PA
# 20       wayne                <NA>           NJ                 <NA>
# 21       wayne               WAYNE           NJ                   NJ
# 9696_241917
#     simulant_id first_name_census first_name_reference_file  \
# 22  9696_241917           Abigail                   Abigail
# 23  9696_241917           Abigail                   Abigail
# 24  9696_241917           Abigail                   Abigail
# 25  9696_241917           Abigail                   Abigail
# 26  9696_241917           Abigail                   Abigail
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 22                  C                    Cynthia            Stull
# 23                  C                    Cynthia            Stull
# 24                  C                    Cynthia            Stull
# 25                  C                    Cynthia            Stull
# 26                  C                    Cynthia            Stull
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 22                    Stull           11/09/6005                     20051109
# 23                    Stull           11/09/6005                     20051109
# 24                    Stull           11/09/6005                     20051109
# 25                    Stull           11/09/6005                     20051109
# 26                    Stull           11/09/6005                     20051109
#
#    street_number_census street_number_reference_file street_name_census  \
# 22                 2812                         2812    rainbow ht road
# 23                 2812                         2812    rainbow ht road
# 24                 2812                         2812    rainbow ht road
# 25                 2812                         <NA>    rainbow ht road
# 26                 2812                         2812    rainbow ht road
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 22            RAINBOW HT ROAD               <NA>                       <NA>
# 23            RAINBOW HT ROAD               <NA>                       <NA>
# 24            RAINBOW HT ROAD               <NA>                       <NA>
# 25                       <NA>               <NA>                       <NA>
# 26            RA:NBOW HT ROAD               <NA>                       <NA>
#
#      city_census city_reference_file state_census state_reference_file
# 22  floyds knobs        FLOVDS KNOBS           IN                   IN
# 23  floyds knobs        FLOYDS KNOBS           IN                   DC
# 24  floyds knobs        FLOYDS KNOBS           IN                   IN
# 25  floyds knobs                <NA>           IN                 <NA>
# 26  floyds knobs        FLOYDS KNOBS           IN                   IN
# 440_818214
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 27  440_818214              Sara                      Sara                  M
# 28  440_818214              Sara                      Sara                  M
# 29  440_818214              Sara                      Sara                  M
# 30  440_818214              Sara                      Sara                  M
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 27                          M         Declined                   Ingram
# 28                          M         Declined                     Ingr
# 29                          M         Declined                   Ingram
# 30                          M         Declined                     Ingr
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 27           04/14/1976                         <NA>                  543
# 28           04/14/1976                         <NA>                  543
# 29           04/14/1976                         <NA>                  543
# 30           04/14/1976                         <NA>                  543
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 27                         <NA>       grandview rd                       <NA>
# 28                         <NA>       grandview rd                       <NA>
# 29                          543       grandview rd               GRANDVIEW RD
# 30                          543       grandview rd               GRANDVIEW RD
#
#    unit_number_census unit_number_reference_file city_census  \
# 27               <NA>                       <NA>      topeka
# 28               <NA>                       <NA>      topeka
# 29               <NA>                       <NA>      topeka
# 30               <NA>                       <NA>      topeka
#
#    city_reference_file state_census state_reference_file
# 27                <NA>           KS                 <NA>
# 28                <NA>           KS                 <NA>
# 29              TOPEKA           KS                   KS
# 30              TOPEKA           KS                   KS
# 5831_1163158
#      simulant_id first_name_census first_name_reference_file  \
# 31  5831_1163158             Aylin                     Aylin
# 32  5831_1163158             Aylin                     Aylin
#
#    middle_name_census middle_name_reference_file  last_name_census  \
# 31                  A                          N  Pellecer-Ramirez
# 32                  A                          N  Pellecer-Ramirez
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 31         Pellecer-Ramirez           04/24/2028                     19870117
# 32         Pellecer-Ramirez           04/24/2028                     19870117
#
#    street_number_census street_number_reference_file street_name_census  \
# 31                 1557                         <NA>          second st
# 32                 1557                         1557          second st
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 31                       <NA>               <NA>                       <NA>
# 32                  SECOND ST               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 31     pacoima                <NA>           CA                 <NA>
# 32     pacoima             PACOIMA           CA                   CA
# 9643_779883
#     simulant_id first_name_census first_name_reference_file  \
# 33  9643_779883             James                     James
# 34  9643_779883             James                     James
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 33                  D                          D         Bautista
# 34                  D                          D         Bautista
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 33                     Baut           02/19/1959                         <NA>
# 34                     Baut           02/19/1959                         <NA>
#
#    street_number_census street_number_reference_file street_name_census  \
# 33                   81                         <NA>           cr 6022b
# 34                   81                           81           cr 6022b
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 33                       <NA>               <NA>                       <NA>
# 34                   CR 6022B               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 33   elizabeth                <NA>           NJ                 <NA>
# 34   elizabeth           ELIZABETH           NJ                   NJ
# 2298_1157048
#      simulant_id first_name_census first_name_reference_file  \
# 35  2298_1157048             Elias                     Elias
# 36  2298_1157048             Elias                     Elias
# 37  2298_1157048             Elias                     Elias
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 35                  M                          M           Larson
# 36                  M                          M           Larson
# 37                  M                          M           Larson
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 35                   Larson           08/16/2003                         <NA>
# 36                   Larson           08/16/2003                         <NA>
# 37                   Larson           08/16/2003                         <NA>
#
#    street_number_census street_number_reference_file street_name_census  \
# 35                  223                         <NA>   farmington place
# 36                  223                          223   farmington place
# 37                  223                          223   farmington place
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 35                       <NA>               <NA>                       <NA>
# 36           FARMINGTON PLACE               <NA>                       <NA>
# 37           FARMINGGON PLACE               <NA>                       <NA>
#
#     city_census city_reference_file state_census state_reference_file
# 35  saint louis                <NA>           MO                 <NA>
# 36  saint louis         SAINT LOUIS           MO                   MO
# 37  saint louis         SAINT LOUIS           MO                   MO
# 682_1102032
#     simulant_id first_name_census first_name_reference_file  \
# 38  682_1102032          Nicholas                  Nicholas
# 39  682_1102032          Nicholas                  Nicholas
# 40  682_1102032          Nicholas                  Nicholas
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 38                  M                       Milo           Holden
# 39                  M                       Milo           Holden
# 40                  M                       Milo           Holden
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 38                   Holden                 <NA>                     20241106
# 39                   Holden                 <NA>                     20241106
# 40                   Holden                 <NA>                     20241106
#
#    street_number_census street_number_reference_file street_name_census  \
# 38                 1150                         1150            dwns rd
# 39                 1150                         1414            dwns rd
# 40                 1150                         <NA>            dwns rd
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 38                       <NA>               <NA>                       <NA>
# 39             EISENHOWER AVN               <NA>                       <NA>
# 40                       <NA>               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 38      taylor              TAYLOR           MI                   MI
# 39      taylor              MOBILE           MI                   AL
# 40      taylor                <NA>           MI                 <NA>
# 9804_323231
#     simulant_id first_name_census first_name_reference_file  \
# 41  9804_323231                 A                    Olivia
# 42  9804_323231                 A                    Olivia
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 41              Aboud                        Amy           Olivia
# 42              Aboud                        Amy           Olivia
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 41                    Aboud           11/30/2017                     20171130
# 42                    Aboud           11/30/2017                     20171130
#
#    street_number_census street_number_reference_file street_name_census  \
# 41                  940                          940       colby street
# 42                  940                         <NA>       colby street
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 41               COLBY STREET               <NA>                       <NA>
# 42                       <NA>               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 41  montgomery          MONTGOMERY           AL                   AL
# 42  montgomery                <NA>           AL                 <NA>
# 4649_635246
#     simulant_id first_name_census first_name_reference_file  \
# 43  4649_635246            Connie                    Connie
# 44  4649_635246            Connie                    Connie
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 43                  A                       Anna        Kurniawan
# 44                  A                       Anna        Kurniawan
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 43                Kurniawan           04/10/1976                     19761004
# 44                Kurniawan           04/10/1976                     19761004
#
#    street_number_census street_number_reference_file street_name_census  \
# 43                 1992                         <NA>         jerald ave
# 44                 1992                         1992         jerald ave
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 43                       <NA>               <NA>                       <NA>
# 44                 JERALD AVE               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 43    st louis                <NA>           MO                 <NA>
# 44    st louis            ST LOUIS           MO                   MO
# 9911_1133450
#      simulant_id first_name_census first_name_reference_file  \
# 45  9911_1133450           Horacio                   Horacio
# 46  9911_1133450           Horacio                   Horacio
# 47  9911_1133450           Horacio                   Horacio
# 48  9911_1133450           Horacio                   Horacio
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 45                  T                          T         Varghese
# 46                  T                          T         Varghese
# 47                  T                          T         Varghese
# 48                  T                          T         Varghese
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 45                 Varghese           09/04/1974                         <NA>
# 46                     Varg           09/04/1974                         <NA>
# 47                 Varghese           09/04/1974                         <NA>
# 48                     Varg           09/04/1974                         <NA>
#
#    street_number_census street_number_reference_file street_name_census  \
# 45                  134                         <NA>       s wasatch dr
# 46                  134                          134       s wasatch dr
# 47                  134                          134       s wasatch dr
# 48                  134                         <NA>       s wasatch dr
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 45                       <NA>               <NA>                       <NA>
# 46               S WASATCH DR               <NA>                       <NA>
# 47               S WASATCH DR               <NA>                       <NA>
# 48                       <NA>               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 45     chatham                <NA>           NJ                 <NA>
# 46     chatham             CHATHAM           NJ                   NJ
# 47     chatham             CHATHAM           NJ                   NJ
# 48     chatham                <NA>           NJ                 <NA>
# 278_343671
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 49  278_343671             Robin                     Robin                  K
# 50  278_343671             Robin                     Robin                  K
# 51  278_343671             Robin                     Robin                  K
# 52  278_343671             Robin                     Robin                  K
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 49                      Kaela            Whall                    Whall
# 50                      Kaela            Whall                    Whall
# 51                      Kaela            Whall                    Whall
# 52                      Kaela            Whall                    Whall
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 49           04/15/1891                     19910415                  189
# 50           04/15/1891                     19910415                  189
# 51           04/15/1891                     19910415                  189
# 52           04/15/1891                     19910415                  189
#
#    street_number_reference_file     street_name_census  \
# 49                          189  northeast faloma road
# 50                         4469  northeast faloma road
# 51                         <NA>  northeast faloma road
# 52                         4469  northeast faloma road
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 49      NORTHEAST FALOMA ROAD               <NA>                       <NA>
# 50                W BUTLER ST               <NA>                       <NA>
# 51                       <NA>               <NA>                       <NA>
# 52                W BUTLER ST               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 49     lincoln             LINCOLN           NE                   NE
# 50     lincoln             MEMPHIS           NE                   TN
# 51     lincoln                <NA>           NE                 <NA>
# 52     lincoln             MEMPHIS           NE                   TN
# 7938_532559
#     simulant_id first_name_census first_name_reference_file  \
# 53  7938_532559                 J                   Lillian
# 54  7938_532559                 J                   Lillian
# 55  7938_532559                 J                   Lillian
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 53            Lillian                    Jessica           Alfaro
# 54            Lillian                    Jessica           Alfaro
# 55            Lillian                    Jessica           Alfaro
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 53                   Alfaro           10/21/2003                     20031021
# 54                   Alfaro           10/21/2003                     20031021
# 55                   Alfaro           10/21/2003                     20031021
#
#    street_number_census street_number_reference_file street_name_census  \
# 53                  980                          980   e movie ranch rd
# 54                  980                         <NA>   e movie ranch rd
# 55                  980                         9418   e movie ranch rd
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 53           E MOVIE RANCH RD               <NA>                       <NA>
# 54                       <NA>               <NA>                       <NA>
# 55                 PAYETTE DR               <NA>                       <NA>
#
#      city_census city_reference_file state_census state_reference_file
# 53  murfreesboro        MURFREESBORO           TN                   TN
# 54  murfreesboro                <NA>           TN                 <NA>
# 55  murfreesboro       HYDETOWN BORO           TN                   PA
# 6144_683864
#     simulant_id first_name_census first_name_reference_file  \
# 56  6144_683864           Charles                   Charles
# 57  6144_683864           Charles                   Charles
# 58  6144_683864           Charles                   Charles
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 56                  C                       Cruz            Ortiz
# 57                  C                       Cruz            Ortiz
# 58                  C                       Cruz            Ortiz
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 56                    Ortiz                 <NA>                     20150811
# 57                    Ortiz                 <NA>                     20150811
# 58                    Ortiz                 <NA>                     20150811
#
#    street_number_census street_number_reference_file street_name_census  \
# 56                 5516                         <NA>     provincial way
# 57                 5516                         7195     provincial way
# 58                 5516                         7195     provincial way
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 56                       <NA>               <NA>                       <NA>
# 57               SW ALGER AVE               <NA>                APRT # 51 E
# 58               SW ALGER AVE               <NA>                APRT # 51 E
#
#       city_census city_reference_file state_census state_reference_file
# 56  east brainerd                <NA>           TN                 <NA>
# 57  east brainerd          CAPE CORAL           TN                   FL
# 58  east brainerd          CAPE CORAL           TN                   FL
# 9901_575637
#     simulant_id first_name_census first_name_reference_file  \
# 59  9901_575637             Simon                     Simon
# 60  9901_575637             Simon                     Simon
# 61  9901_575637             Simon                     Simon
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 59                  M                    Matthew          Perillo
# 60                  M                    Matthew          Perillo
# 61                  M                    Matthew          Perillo
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 59                  Perillo           04/01/1962                     20160907
# 60                  Perillo           04/01/1962                     20160907
# 61                  Perillo           04/01/1962                     20160907
#
#    street_number_census street_number_reference_file street_name_census  \
# 59                  609                         <NA>             ivy wy
# 60                  609                          609             ivy wy
# 61                  609                          609             ivy wy
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 59                       <NA>               <NA>                       <NA>
# 60                     IVY WY               <NA>                       <NA>
# 61                     IVY WY               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 59        mesa                <NA>           AZ                 <NA>
# 60        mesa                MESA           AZ                   AZ
# 61        mesa                MESA           AZ                   CT
# 6760_71186
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 62  6760_71186           Heather                   Heather                  T
# 63  6760_71186           Heather                   Heather                  T
# 64  6760_71186           Heather                   Heather                  T
# 65  6760_71186           Heather                   Heather                  T
# 66  6760_71186           Heather                   Heather                  T
# 67  6760_71186           Heather                   Heather                  T
# 68  6760_71186           Heather                   Heather                  T
# 69  6760_71186           Heather                   Heather                  T
# 70  6760_71186           Heather                   Heather                  T
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 62                          T           Pachco                     Pach
# 63                          T           Pachco                  Pacheco
# 64                          T           Pachco                  Pacheco
# 65                          T           Pachco                     Pach
# 66                          T           Pachco                     Girl
# 67                          T           Pachco                  Pacheco
# 68                          T           Pachco                     Girl
# 69                          T           Pachco                     Pach
# 70                          T           Pachco                     Girl
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 62           04/17/1992                         <NA>                 1020
# 63           04/17/1992                         <NA>                 1020
# 64           04/17/1992                         <NA>                 1020
# 65           04/17/1992                         <NA>                 1020
# 66           04/17/1992                         <NA>                 1020
# 67           04/17/1992                         <NA>                 1020
# 68           04/17/1992                         <NA>                 1020
# 69           04/17/1992                         <NA>                 1020
# 70           04/17/1992                         <NA>                 1020
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 62                         <NA>     park bluff way                       <NA>
# 63                         <NA>     park bluff way                       <NA>
# 64                         1020     park bluff way             PARK BLUFF WAY
# 65                         10Z0     park bluff way             PARK BLUFF WAY
# 66                         10Z0     park bluff way             PARK BLUFF WAY
# 67                         10Z0     park bluff way             PARK BLUFF WAY
# 68                         1020     park bluff way             PARK BLUFF WAY
# 69                         1020     park bluff way             PARK BLUFF WAY
# 70                         <NA>     park bluff way                       <NA>
#
#    unit_number_census unit_number_reference_file  city_census  \
# 62               <NA>                       <NA>  bakersfield
# 63               <NA>                       <NA>  bakersfield
# 64               <NA>                       <NA>  bakersfield
# 65               <NA>                       <NA>  bakersfield
# 66               <NA>                       <NA>  bakersfield
# 67               <NA>                       <NA>  bakersfield
# 68               <NA>                       <NA>  bakersfield
# 69               <NA>                       <NA>  bakersfield
# 70               <NA>                       <NA>  bakersfield
#
#    city_reference_file state_census state_reference_file
# 62                <NA>           CA                 <NA>
# 63                <NA>           CA                 <NA>
# 64         BAKERSFIELD           CA                   CA
# 65         BAKERSFIELD           CA                   CA
# 66         BAKERSFIELD           CA                   CA
# 67         BAKERSFIELD           CA                   CA
# 68         BAKERSFIELD           CA                   CA
# 69         BAKERSFIELD           CA                   CA
# 70                <NA>           CA                 <NA>
# 3142_100881
#     simulant_id first_name_census first_name_reference_file  \
# 71  3142_100881             Molly                     Molly
# 72  3142_100881             Molly                     Molly
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 71                  C                          C           Norton
# 72                  C                          C           Norton
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 71                     Nort           02/10/1978                         <NA>
# 72                     Nort           02/10/1978                         <NA>
#
#    street_number_census street_number_reference_file street_name_census  \
# 71                 2214                         <NA>        bocaw place
# 72                 2214                         2214        bocaw place
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 71                       <NA>               <NA>                       <NA>
# 72                BOCAW PLACE               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 71   san diego                <NA>           CA                 <NA>
# 72   san diego           SAN DIEGO           CA                   CA
# 107_178364
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 73  107_178364          Brigette                  Brigette                  S
# 74  107_178364          Brigette                  Brigette                  S
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 73                    Savanna              Ito                      Ito
# 74                    Savanna              Ito                      Ito
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 73           05/03/2014                     50120503                    6
# 74           05/03/2014                     50120503                    6
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 73                         <NA>          frayne dr                       <NA>
# 74                         <NA>          frayne dr                       <NA>
#
#    unit_number_census unit_number_reference_file city_census  \
# 73               <NA>                       <NA>    san jose
# 74               <NA>                       <NA>    san jose
#
#    city_reference_file state_census state_reference_file
# 73            GLENDALE           CA                   CA
# 74                <NA>           CA                 <NA>
# 4950_1032017
#      simulant_id first_name_census first_name_reference_file  \
# 75  4950_1032017           Madison                   Madison
# 76  4950_1032017           Madison                   Madison
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 75                  C                          C        Nagarajan
# 76                  C                          C        Nagarajan
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 75                     Naga           08/10/1989                         <NA>
# 76                     Naga           08/10/1989                         <NA>
#
#    street_number_census street_number_reference_file    street_name_census  \
# 75                  215                           18  heatherfield east dr
# 76                  215                         <NA>  heatherfield east dr
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 75              E HAMPTON AVE               <NA>                       <NA>
# 76                       <NA>               <NA>                       <NA>
#
#    city_census   city_reference_file state_census state_reference_file
# 75     croghan  SPRING CREEK HOUSING           NY                   NV
# 76     croghan                  <NA>           NY                 <NA>
# 1182_579036
#     simulant_id first_name_census first_name_reference_file  \
# 77  1182_579036            Mirian                      <NA>
# 78  1182_579036            Mirian                      <NA>
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 77                  L                       Leah          Stewart
# 78                  L                       Leah          Stewart
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 77                  Stewart           07/07/2002                     20020707
# 78                  Stewart           07/07/2002                     20020707
#
#    street_number_census street_number_reference_file street_name_census  \
# 77                  105                         4010      sweetwater rd
# 78                  105                         <NA>      sweetwater rd
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 77         S BOLD FORBES BLVD               <NA>                       <NA>
# 78                       <NA>               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 77   rochester              DEMING           NY                   WA
# 78   rochester                <NA>           NY                 <NA>
# 8869_544928
#     simulant_id first_name_census first_name_reference_file  \
# 79  8869_544928             Shawn                     Shawn
# 80  8869_544928             Shawn                     Shawn
# 81  8869_544928             Shawn                     Shawn
# 82  8869_544928             Shawn                     Shawn
# 83  8869_544928             Shawn                     Shawn
# 84  8869_544928             Shawn                     Shawn
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 79                  G                          G             <NA>
# 80                  G                          G             <NA>
# 81                  G                          G             <NA>
# 82                  G                          G             <NA>
# 83                  G                          G             <NA>
# 84                  G                          G             <NA>
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 79                Mcclaskey           11/26/1984                         <NA>
# 80                     Mccl           11/26/1984                         <NA>
# 81                     Mccl           11/26/1984                         <NA>
# 82                Mcclaskey           11/26/1984                         <NA>
# 83                Mcclaskey           11/26/1984                         <NA>
# 84                     Mccl           11/26/1984                         <NA>
#
#    street_number_census street_number_reference_file street_name_census  \
# 79                 2525                         2525      mccall bri rd
# 80                 2525                         2525      mccall bri rd
# 81                 2525                         2525      mccall bri rd
# 82                 2525                         2525      mccall bri rd
# 83                 2525                         <NA>      mccall bri rd
# 84                 2525                         <NA>      mccall bri rd
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 79              MCCALL BRI RD               <NA>                       <NA>
# 80              MCCALL BRI RD               <NA>                       <NA>
# 81              MCCALL BRI RD               <NA>                       <NA>
# 82              MCCALL BRI RD               <NA>                       <NA>
# 83                       <NA>               <NA>                       <NA>
# 84                       <NA>               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 79  e st louis          E ST LOUIS           IL                   IL
# 80  e st louis          E ST LOUIS           IL                   IL
# 81  e st louis          E ST LOUIS           IL                   IL
# 82  e st louis          E ST LOUIS           IL                   IL
# 83  e st louis                <NA>           IL                 <NA>
# 84  e st louis                <NA>           IL                 <NA>
# 9840_1053660
#      simulant_id first_name_census first_name_reference_file  \
# 85  9840_1053660           Rosalva                   Rosalva
# 86  9840_1053660           Rosalva                   Rosalva
# 87  9840_1053660           Rosalva                   Rosalva
# 88  9840_1053660           Rosalva                   Rosalva
# 89  9840_1053660           Rosalva                   Rosalva
# 90  9840_1053660           Rosalva                   Rosalva
# 91  9840_1053660           Rosalva                   Rosalva
# 92  9840_1053660           Rosalva                   Rosalva
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 85                  D                          D           Daniel
# 86                  D                          D           Daniel
# 87                  D                          D           Daniel
# 88                  D                          D           Daniel
# 89                  D                          D           Daniel
# 90                  D                          D           Daniel
# 91                  D                          D           Daniel
# 92                  D                          D           Daniel
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 85                   Daniel           11/17/2000                         <NA>
# 86                   Daniel           11/17/2000                         <NA>
# 87                   Daniel           11/17/2000                         <NA>
# 88                     Dani           11/17/2000                         <NA>
# 89                     Dani           11/17/2000                         <NA>
# 90                   Daniel           11/17/2000                         <NA>
# 91                     Dani           11/17/2000                         <NA>
# 92                   Daniel           11/17/2000                         <NA>
#
#    street_number_census street_number_reference_file street_name_census  \
# 85                 <NA>                         <NA>        hillside rd
# 86                 <NA>                         <NA>        hillside rd
# 87                 <NA>                         2532        hillside rd
# 88                 <NA>                         2532        hillside rd
# 89                 <NA>                         <NA>        hillside rd
# 90                 <NA>                         <NA>        hillside rd
# 91                 <NA>                         <NA>        hillside rd
# 92                 <NA>                         <NA>        hillside rd
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 85                       <NA>               <NA>                       <NA>
# 86                HILLSIDE RD               <NA>                       <NA>
# 87                N ARMOUR ST               <NA>                       <NA>
# 88                N ARMOUR ST               <NA>                       <NA>
# 89                HILLSIDE RD               <NA>                       <NA>
# 90                HILLSIDE RD               <NA>                       <NA>
# 91                       <NA>               <NA>                       <NA>
# 92                       <NA>               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 85      duarte                <NA>           CA                 <NA>
# 86      duarte              DUARTE           CA                   CA
# 87      duarte        CHESTERFIELD           CA                   MO
# 88      duarte        CHESTERFIELD           CA                   MO
# 89      duarte              DUARTE           CA                   CA
# 90      duarte              DUARTE           CA                   CA
# 91      duarte                <NA>           CA                 <NA>
# 92      duarte                <NA>           CA                 <NA>
# 9740_349524
#     simulant_id first_name_census first_name_reference_file  \
# 93  9740_349524             Jacob             Lady Of House
# 94  9740_349524             Jacob             Lady Of House
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 93                  C                     Calvin              Zak
# 94                  C                     Calvin              Zak
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 93                      Zak           10/35/1984                     19841031
# 94                      Zak           10/35/1984                     19841031
#
#    street_number_census street_number_reference_file street_name_census  \
# 93                43524                         <NA>          krouse ct
# 94                43524                        43524          krouse ct
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 93                       <NA>               <NA>                       <NA>
# 94                  KROUSE CT               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 93       plano                <NA>           TX                 <NA>
# 94       plano               PLANO           TX                   TX
# 93_180423
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 95   93_180423          Quanesha                  Quanesha                  Z
# 96   93_180423          Quanesha                  Quanesha                  Z
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 95                        Zoe            Lloyd                     Lbyd
# 96                        Zoe            Lloyd                     Lbyd
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 95           10/05/1991                     19911005                 2201
# 96           10/05/1991                     19911005                 2201
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 95                         2201     wildwood drive             WILDWOOD DRIVE
# 96                         <NA>     wildwood drive                       <NA>
#
#    unit_number_census unit_number_reference_file city_census  \
# 95               <NA>                       <NA>     wbarton
# 96               <NA>                       <NA>     wbarton
#
#    city_reference_file state_census state_reference_file
# 95             WHARTON           TX                   TX
# 96                <NA>           TX                 <NA>
# 3607_1151651
#      simulant_id first_name_census first_name_reference_file  \
# 97  3607_1151651                 G                      Owen
# 98  3607_1151651                 G                      Owen
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 97          Natarajan                   Giovanni             Owen
# 98          Natarajan                   Giovanni             Owen
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 97                Natarajan           08/03/2027                     20270803
# 98                Natarajan           08/03/2027                     20270803
#
#    street_number_census street_number_reference_file street_name_census  \
# 97                 2575                         2575           co rd 16
# 98                 2575                         <NA>           co rd 16
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 97                   CO RD 16               <NA>                       <NA>
# 98                       <NA>               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 97    pukalani            PUKALANI           HI                   HI
# 98    pukalani                <NA>           HI                 <NA>
# 8425_1183995
#       simulant_id first_name_census first_name_reference_file  \
# 99   8425_1183995            Harper                    Harper
# 100  8425_1183995            Harper                    Harper
#
#     middle_name_census middle_name_reference_file last_name_census  \
# 99                   H                     Harper          Decotis
# 100                  H                     Harper          Decotis
#
#     last_name_reference_file date_of_birth_census  \
# 99                   Decotis          053/08/2017
# 100                  Decotis          053/08/2017
#
#     date_of_birth_reference_file street_number_census  \
# 99                      20170308                 1065
# 100                     20170308                 1065
#
#     street_number_reference_file street_name_census  \
# 99                          <NA>        hillside av
# 100                         5065        hillside av
#
#     street_name_reference_file unit_number_census unit_number_reference_file  \
# 99                        <NA>               <NA>                       <NA>
# 100                HILLSIDE AV               <NA>                       <NA>
#
#     city_census city_reference_file state_census state_reference_file
# 99       norman                <NA>           OK                 <NA>
# 100      norman              NORMAN           OK                   OK

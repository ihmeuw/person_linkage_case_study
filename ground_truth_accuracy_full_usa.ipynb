# %% [markdown]
# # Simulated PIK statistics
#
# Here we inspect the accuracy and characteristics of the PIKs assigned,
# leveraging our knowledge of ground truth from pseudopeople.
#
# It wouldn't be possible to do the ground truth part with the real PVS, but
# Layne, Wagner, and Rothhaas did something similar by redacting SSN from real records,
# sending them through PVS without the SSN, and then using the true SSN
# as ground truth.
# The health care records they used are probably quite different from a CUF,
# but they found a **very** good overall PIK accuracy (see cell below).

# %%
# Query planning is now on by default, but it has some rough edges.
# See https://github.com/dask/dask/issues/10995 for general discussion
# and https://github.com/dask/dask-expr/issues/1060 for the particular
# issue I ran into.
import dask
dask.config.set({"dataframe.query-planning": False})

# %%
import datetime, os

from vivarium_research_prl import distributed_compute, utils
from IPython.display import display

# %%
print(datetime.datetime.now())
# Out:
# 2024-05-13 11:02:49.856938

# %%
# DO NOT EDIT if this notebook is not called ground_truth_accuracy.ipynb!
# This notebook is designed to be run with papermill; this cell is tagged 'parameters'
data_to_use = 'small_sample'
simulated_data_output_dir = 'output/generate_simulated_data'
case_study_output_dir = 'output'

# The "compute engine" is what we use on the Python side
# for our case-study-specific operations,
# as opposed to the Splink engine
compute_engine = 'pandas'
# Only matter if using a distributed compute engine
compute_engine_num_jobs = 3
compute_engine_cpus_per_job = 2
compute_engine_memory_per_job = "5GB"
queue = "long.q"
local_directory = f"/tmp/{os.environ['USER']}_dask"

# %%
# Parameters
data_to_use = "usa"
simulated_data_output_dir = "/mnt/team/simulation_science/priv/users/zmbc/prl/person_linkage_case_study/generate_simulated_data/"
case_study_output_dir = "/mnt/team/simulation_science/priv/users/zmbc/prl/person_linkage_case_study/person_linkage_case_study/"
compute_engine = "dask"
compute_engine_num_jobs = 50
compute_engine_memory_per_job = "40GB"
compute_engine_cpus_per_job = 2
local_directory = "/mnt/team/simulation_science/priv/users/zmbc/prl/person_linkage_case_study_tmp/dask_local_run/dask_local"

# %%
# Parameters for a USA run
# data_to_use = "usa"
# simulated_data_output_dir = "/ihme/scratch/users/zmbc/person_linkage_case_study/generate_simulated_data"
# case_study_output_dir = "/ihme/scratch/users/zmbc/person_linkage_case_study/person_linkage_case_study"

# compute_engine = 'dask'
# compute_engine_num_jobs = 50
# compute_engine_memory_per_job = "120GB"
# compute_engine_cpus_per_job = 2

# %%
case_study_output_dir = f'{case_study_output_dir}/{data_to_use}'
simulated_data_output_dir = f'{simulated_data_output_dir}/{data_to_use}'

# %%
df_ops, pd = distributed_compute.start_compute_engine(
    compute_engine,
    num_jobs=compute_engine_num_jobs,
    cpus_per_job=compute_engine_cpus_per_job,
    memory_per_job=compute_engine_memory_per_job,
    queue=queue,
    local_directory=local_directory,
)
# Out:
# /mnt/share/homes/zmbc/mambaforge/envs/person_linkage_case_study_20240423/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 45801 instead
#   warnings.warn(
# <Client: 'tcp://10.158.111.9:41223' processes=50 threads=50, memory=1.82 TiB>

# %%
census_2030_piked = df_ops.read_parquet(f'{case_study_output_dir}/census_2030_piked.parquet')
confirmed_piks_with_ground_truth = df_ops.read_parquet(f'{case_study_output_dir}/confirmed_piks.parquet')

# %%
piked_proportion = df_ops.compute(census_2030_piked.pik.notnull().mean())
# Compare with 90.28% of input records PIKed in the 2010 CUF,
# as reported in Wagner and Layne, Table 2, p. 18 
print(f'{piked_proportion:.2%} of the input records were PIKed')
# Out:
# 88.62% of the input records were PIKed

# %%
# Multiple Census rows assigned the same PIK, indicating the model thinks they are duplicates in Census
pik_sizes = df_ops.persist(df_ops.groupby_agg_small_groups(census_2030_piked, by='pik', agg_func=lambda x: x.size()))
df_ops.compute(pik_sizes.value_counts())
# Out:
# 1    302545510
# 2       684065
# 3          668
# 4            4
# Name: count, dtype: int64

# %%
# Interesting: in pseudopeople, sometimes siblings are assigned the same (common) first name, making them almost identical.
# The only giveaway is their age and DOB.
# Presumably, this tends not to happen in real life.
duplicate_piks = pik_sizes.rename('pik_size').reset_index().pipe(lambda df: df[df.pik_size > 1])

df_ops.head(census_2030_piked.merge(duplicate_piks, on="pik").sort_values('pik'))
# Out:
#      household_id first_name middle_initial last_name age date_of_birth  \
# 2009    93_411256     Austin              L   Carroll  11    12/04/2018
# 2705     93_59123     Austin              L   Carroll  11    12/04/2018
# 1413  6800_184521     Kinley              M    Murray  16    03/11/2014
# 3004  6800_487914     Kinley              M    Murray  16    03/11/2014
# 1431  6790_298700      David              J   Barrick  68    10/24/1961
# 3685  6790_298700      James              J   Barrick  36    10/24/1961
# 3753  8527_376719      Jacob              J    Tapley  17    04/20/2012
# 3957  8527_571898      Jacob              J    Tapley  17    04/20/2012
# 1000       1362_3      Emily              S    Elwell  21    12/17/2008
# 3748   1362_22687      Emily              S    Elwell  21    12/17/2008
#
#      street_number      street_name unit_number            city state zipcode  \
# 2009          3701    albemarle dri        <NA>  pleasant grove    AL   35654
# 2705          1252       w 72nd ave        <NA>       rochester    NY   10075
# 1413         12801        park plza        <NA>      st. peters    MO   63115
# 3004           671      new hope rd        <NA>       englewood    CO   80916
# 1431           345    iefferson ave        <NA>            <NA>    MO   65441
# 3685           345    jefferson ave        <NA>  jefferson city    MO   65441
# 3753          1810   a st southeast        <NA>        fairborn    OH   45417
# 3957           314  hicks hill road        <NA>      florissant    MO   64068
# 1000           505          e gn st        <NA>       elk point    SD   57029
# 3748           127           tri st        <NA>         addison    IL   60555
#
#      housing_type                relationship_to_reference_person     sex  \
# 2009    Household                                  Other relative    Male
# 2705    Household                                Reference person    Male
# 1413    Household                                Biological child  Female
# 3004    Household                                  Other relative  Female
# 1431    Household                             Opposite-sex spouse    Male
# 3685    Household                                   Adopted child    Male
# 3753    Household                               Other nonrelative    Male
# 3957    Household                                  Other relative    Male
# 1000      College  Noninstitutionalized group quarters population  Female
# 3748    Household                                  Other relative  Female
#
#      race_ethnicity  year                          record_id        pik  \
# 2009          White  2030    simulated_census_2030_2_1025398  0_1000309
# 2705          White  2030     simulated_census_2030_2_124106  0_1000309
# 1413          White  2030   simulated_census_2030_233_388109    0_10005
# 3004          White  2030  simulated_census_2030_233_1027806    0_10005
# 1431          White  2030   simulated_census_2030_231_627034  0_1000919
# 3685          White  2030   simulated_census_2030_231_627035  0_1000919
# 3753          White  2030   simulated_census_2030_285_789162  0_1001605
# 3957          White  2030  simulated_census_2030_285_1025935  0_1001605
# 1000          Black  2030     simulated_census_2030_46_47324  0_1001652
# 3748          Black  2030   simulated_census_2030_46_1025428  0_1001652
#
#       pik_size
# 2009         2
# 2705         2
# 1413         2
# 3004         2
# 1431         2
# 3685         2
# 3753         2
# 3957         2
# 1000         2
# 3748         2

# %% [markdown]
# ## Ground truth statistics

# %%
census_2030_ground_truth = df_ops.persist(
    df_ops.read_parquet(f'{simulated_data_output_dir}/simulated_census_2030_ground_truth.parquet')
)

# %%
# In this version of pseudopeople, there are no actual duplicates in Census,
# which means all of the duplicates identified above are wrong.
assert len(census_2030_ground_truth) == len(df_ops.drop_duplicates(census_2030_ground_truth))

# %%
reference_files_ground_truth = df_ops.persist(df_ops.concat([
    df_ops.read_parquet(f'{simulated_data_output_dir}/simulated_geobase_reference_file_ground_truth.parquet').drop(columns=['n_unique_simulants']),
    df_ops.read_parquet(f'{simulated_data_output_dir}/simulated_name_dob_reference_file_ground_truth.parquet').drop(columns=['n_unique_simulants']),
], ignore_index=True))
# Out:
# Imbalanced dataframe: too_few=False, too_many=True, too_large=False
# count    8.720000e+02
# mean     1.215106e+08
# std      4.555555e+07
# min      7.575983e+07
# 25%      7.598293e+07
# 50%      1.214460e+08
# 75%      1.670462e+08
# max      1.673512e+08
# dtype: float64
# Creating partitions of 2,119MB

# %%
# However, there can be reference file records that correspond to multiple simulants,
# due to errors in the reference file construction by SSN
n_unique_simulants = df_ops.persist(df_ops.groupby_agg_small_groups(reference_files_ground_truth, by='record_id', agg_func=lambda x: x.simulant_id.nunique()).rename('n_unique_simulants').reset_index())
df_ops.compute(n_unique_simulants.n_unique_simulants.value_counts())
# Out:
# n_unique_simulants
# 1    1229041214
# 2      59021232
# 3       1771663
# 4        102952
# 5          6057
# 6           355
# 7            28
# 9             1
# Name: count, dtype: int64

# %%
reference_files_ground_truth = df_ops.persist(reference_files_ground_truth.merge(
    n_unique_simulants,
    on='record_id',
    how='left',
))
reference_files_ground_truth.head(n=100)
# Out:
#                                      record_id   simulant_id  \
# 0   simulated_geobase_reference_file_0_1007416    3202_98373
# 1   simulated_geobase_reference_file_0_1009259  2416_1130696
# 2    simulated_geobase_reference_file_0_101754   6539_783854
# 3   simulated_geobase_reference_file_0_1030795    9272_24332
# 4   simulated_geobase_reference_file_0_1059381  5698_1116162
# ..                                         ...           ...
# 95   simulated_geobase_reference_file_0_486819    1753_69067
# 96   simulated_geobase_reference_file_0_499302   5949_192171
# 97   simulated_geobase_reference_file_0_499302   4344_791440
# 98   simulated_geobase_reference_file_0_531999   2047_838586
# 99   simulated_geobase_reference_file_0_544572   8869_723642
#
#     n_unique_simulants
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1
# ..                 ...
# 95                   1
# 96                   2
# 97                   2
# 98                   1
# 99                   1
#
# [100 rows x 3 columns]

# %%
df_ops.head(reference_files_ground_truth[reference_files_ground_truth.n_unique_simulants == df_ops.compute(reference_files_ground_truth.n_unique_simulants.max())])
# Out:
#                                              record_id simulant_id  \
# 12778090  simulated_geobase_reference_file_369_1409656  6554_95393
# 12778091  simulated_geobase_reference_file_369_1409656  6554_95397
# 12778092  simulated_geobase_reference_file_369_1409656  6554_95392
# 12778093  simulated_geobase_reference_file_369_1409656  6554_95390
# 12778094  simulated_geobase_reference_file_369_1409656  6554_95396
# 12778095  simulated_geobase_reference_file_369_1409656  6554_95389
# 12778096  simulated_geobase_reference_file_369_1409656  6554_95403
# 12778097  simulated_geobase_reference_file_369_1409656  6554_95406
# 12778098  simulated_geobase_reference_file_369_1409656  6554_95395
#
#           n_unique_simulants
# 12778090                   9
# 12778091                   9
# 12778092                   9
# 12778093                   9
# 12778094                   9
# 12778095                   9
# 12778096                   9
# 12778097                   9
# 12778098                   9

# %%
census_2030_ground_truth = df_ops.persist(census_2030_ground_truth.merge(
    df_ops.drop_duplicates(reference_files_ground_truth[['simulant_id']]).assign(possible_to_pik=1),
    on='simulant_id',
    how='left',
).assign(possible_to_pik=lambda df: df.possible_to_pik.fillna(0)))
possible_to_pik_proportion = df_ops.compute(census_2030_ground_truth.possible_to_pik.mean())
print(
    f'{(1 - possible_to_pik_proportion):.2%} of the input records are '
    'impossible to PIK correctly, since they are not in any reference files'
)
# Out:
# 0.43% of the input records are impossible to PIK correctly, since they are not in any reference files

# %%
print(
    f'Assigned PIKs to {(piked_proportion / possible_to_pik_proportion):.2%} of PIK-able records'
)
# Out:
# Assigned PIKs to 89.00% of PIK-able records

# %%
reference_file = df_ops.concat([
    df_ops.read_parquet(
        f'{simulated_data_output_dir}/simulated_geobase_reference_file.parquet',
    ),
    df_ops.read_parquet(
        f'{simulated_data_output_dir}/simulated_name_dob_reference_file.parquet',
    ),
], ignore_index=True)
# Out:
# Imbalanced dataframe: too_few=False, too_many=True, too_large=False
# count    7.700000e+02
# mean     3.880555e+08
# std      1.573591e+08
# min      2.302881e+08
# 25%      2.308000e+08
# 50%      3.859436e+08
# 75%      5.455854e+08
# max      5.482611e+08
# dtype: float64
# Creating partitions of 5,976MB

# %%
reference_file_piks = df_ops.persist(reference_file[['record_id', 'pik']])
reference_file_piks
# Out:
# Dask DataFrame Structure:
#                record_id     pik
# npartitions=54
#                   string  string
#                      ...     ...
# ...                  ...     ...
#                      ...     ...
#                      ...     ...
# Dask Name: getitem, 1 graph layer

# %%
assert len(reference_file_piks) == len(df_ops.drop_duplicates(reference_file_piks[['record_id']]))

# %%
pik_simulant_pairs = df_ops.persist(df_ops.drop_duplicates(reference_files_ground_truth.merge(reference_file_piks, on='record_id')[['pik', 'simulant_id']]))

# %%
# However, there can be PIKs that correspond to multiple simulants,
# due to errors in the reference file construction by SSN
n_unique_simulants = df_ops.persist(df_ops.groupby_agg_small_groups(pik_simulant_pairs, by='pik', agg_func=lambda x: x.simulant_id.nunique()).rename('n_unique_simulants').reset_index())
df_ops.compute(n_unique_simulants.n_unique_simulants.value_counts())
# Out:
# n_unique_simulants
# 1      353924439
# 2       41181290
# 3        3259303
# 4         225868
# 5          14701
#          ...
# 247            1
# 216            1
# 205            1
# 55             1
# 157            1
# Name: count, Length: 334, dtype: int64

# %%
pik_simulant_pairs = df_ops.persist(pik_simulant_pairs.merge(
    n_unique_simulants,
    on='pik',
    how='left',
))
pik_simulant_pairs
# Out:
# Dask DataFrame Structure:
#                     pik simulant_id n_unique_simulants
# npartitions=108
#                  string      string              int64
#                     ...         ...                ...
# ...                 ...         ...                ...
#                     ...         ...                ...
#                     ...         ...                ...
# Dask Name: hash-join, 1 graph layer

# %%
df_ops.head(pik_simulant_pairs[pik_simulant_pairs.n_unique_simulants == df_ops.compute(pik_simulant_pairs.n_unique_simulants.max())])
# Out:
#                pik   simulant_id  n_unique_simulants
# 3155742  44_705631  9526_1151086                 334
# 3155743  44_705631    2787_14227                 334
# 3155744  44_705631   3374_167624                 334
# 3155745  44_705631  4950_1033583                 334
# 3155746  44_705631  3713_1038605                 334
# 3155747  44_705631    4203_64253                 334
# 3155748  44_705631  3984_1095858                 334
# 3155749  44_705631    8221_85308                 334
# 3155750  44_705631  9723_1146759                 334
# 3155751  44_705631    315_103299                 334

# %% [markdown]
# ## Definitions of accuracy
#
# 1. (most strict) Assigning any PIK with multiple simulants is incorrect
# 2. Assigning a PIK with multiple simulants is neither incorrect nor correct (excluded from denominator)
# 3. (most lenient) Assigning a PIK with multiple simulants is correct, as long as at least one of those simulants matches the truth

# %%
# All modules, Medicare database, calculated from Layne, Wagner, and Rothhaas Table 1 (p. 15)
real_life_pvs_accuracy = 1 - (2_585 + 60_709 + 129_480 + 89_094) / (52_406_981 + 5_170_924 + 49_374_794 + 50_327_034)
f'{real_life_pvs_accuracy:.5%}'
# Out:
# '99.82079%'

# %% [markdown]
# ### Definition 1

# %%
piks_assigned = df_ops.compute(census_2030_piked.pik.notnull().sum())
piks_assigned
# Out:
# 303915660

# %%
df_ops.head(pik_simulant_pairs[pik_simulant_pairs.n_unique_simulants > 1])
# Out:
#           pik   simulant_id  n_unique_simulants
# 4   0_1000242   3528_680562                   2
# 5   0_1000242   3528_234421                   2
# 13  0_1001101  1219_1068536                   2
# 14  0_1001101    1219_24209                   2
# 18  0_1001592   9776_900062                   2
# 19  0_1001592   7107_889225                   2
# 28  0_1002408   5860_796821                   2
# 29  0_1002408   5969_787903                   2
# 30  0_1002504   1232_155899                   2
# 31  0_1002504    1232_44116                   2

# %%
single_sim_piks_correct = df_ops.compute(
    census_2030_piked[['record_id', 'pik']].merge(pik_simulant_pairs, on='pik').merge(census_2030_ground_truth, on='record_id')
        .pipe(lambda df: (df.simulant_id_x == df.simulant_id_y) & (df.n_unique_simulants == 1))
        .sum()
)
single_sim_piks_correct
# Out:
# 267617405

# %%
# Overall accuracy, treating it as a black box
(
    single_sim_piks_correct / piks_assigned
)
# Out:
# 0.8805647099593354

# %%
assert len(confirmed_piks_with_ground_truth) == piks_assigned

# %%
df_ops.head(census_2030_ground_truth.rename(columns={'record_id': 'record_id_census_2030'}))
# Out:
#           record_id_census_2030 simulant_id  possible_to_pik
# 0    simulated_census_2030_0_37       28_44              1.0
# 1   simulated_census_2030_0_311      28_365              1.0
# 2   simulated_census_2030_0_314      28_370              1.0
# 3   simulated_census_2030_0_349      28_414              1.0
# 4   simulated_census_2030_0_680      28_804              1.0
# 5   simulated_census_2030_0_738      28_867              1.0
# 6  simulated_census_2030_0_1129     28_1312              1.0
# 7  simulated_census_2030_0_1197     28_1388              1.0
# 8  simulated_census_2030_0_1626     28_1892              1.0
# 9  simulated_census_2030_0_1642     28_1912              1.0

# %%
# Looking at whether the exact *record* linked was from the same simulant
single_sim_record_links_correct = df_ops.compute(
    confirmed_piks_with_ground_truth
        .merge(
            census_2030_ground_truth.rename(columns={'record_id': 'record_id_raw_input_file'}),
            on='record_id_raw_input_file',
        )
        .merge(
            reference_files_ground_truth.rename(columns={'record_id': 'record_id_reference_file'}),
            on='record_id_reference_file',
        )
        .pipe(lambda df: (df.simulant_id_x == df.simulant_id_y) & (df.n_unique_simulants == 1))
        .sum()
)
single_sim_record_links_correct
# Out:
# 284389384

# %%
(
    single_sim_record_links_correct / piks_assigned
)
# Out:
# 0.9357510040779077

# %% [markdown]
# ### Definition 2

# %%
single_sim_piks_assigned = len(census_2030_piked[['record_id', 'pik']].merge(pik_simulant_pairs[pik_simulant_pairs.n_unique_simulants == 1][['pik', 'simulant_id']]))
single_sim_piks_assigned
# Out:
# 267814885

# %%
# Overall accuracy, treating it as a black box
(
    single_sim_piks_correct / single_sim_piks_assigned
)
# Out:
# 0.9992626250030875

# %%
# Looking at whether the exact *record* linked was from the same simulant
single_sim_record_links_assigned = df_ops.compute(
    (confirmed_piks_with_ground_truth
        .merge(
            reference_files_ground_truth.rename(columns={'record_id': 'record_id_reference_file'}),
            on='record_id_reference_file',
        )
        .n_unique_simulants == 1).sum()
)
single_sim_record_links_assigned
# Out:
# 284600979

# %%
(
    single_sim_record_links_correct / single_sim_record_links_assigned
)
# Out:
# 0.9992565204773944

# %% [markdown]
# ### Definition 3

# %%
pik_simulant_pairs
# Out:
# Dask DataFrame Structure:
#                     pik simulant_id n_unique_simulants
# npartitions=108
#                  string      string              int64
#                     ...         ...                ...
# ...                 ...         ...                ...
#                     ...         ...                ...
#                     ...         ...                ...
# Dask Name: hash-join, 1 graph layer

# %%
piks_at_least_partially_correct = df_ops.persist(
    census_2030_piked[['record_id', 'pik']].merge(pik_simulant_pairs, on='pik').merge(census_2030_ground_truth, on='record_id')
        .pipe(df_ops.drop_duplicates)
        .assign(correct=lambda df: df.simulant_id_x == df.simulant_id_y)
        .pipe(df_ops.groupby_agg_small_groups, by=["record_id", "pik"], agg_func=lambda x: x.correct.any())
        .reset_index()
)
piks_at_least_partially_correct
# Out:
# Dask DataFrame Structure:
#                 record_id     pik        correct
# npartitions=668
#                    string  string  bool[pyarrow]
#                       ...     ...            ...
# ...                   ...     ...            ...
#                       ...     ...            ...
#                       ...     ...            ...
# Dask Name: reset_index, 1 graph layer

# %%
# Overall accuracy, treating it as a black box
piks_correct_proportion = (df_ops.compute(piks_at_least_partially_correct.correct.sum()) / piks_assigned)
piks_correct_proportion
# Out:
# 0.9992742065347998

# %%
print(f'{piks_correct_proportion:.5%} of the PIKs assigned were correct; compare with {real_life_pvs_accuracy:.5%} in real life')
# Out:
# 99.92742% of the PIKs assigned were correct; compare with 99.82079% in real life

# %%
# Looking at whether the exact *record* linked was from the same simulant
sim_record_links_at_least_partially_correct = df_ops.persist(
    confirmed_piks_with_ground_truth
        .merge(
            census_2030_ground_truth.rename(columns={'record_id': 'record_id_raw_input_file'}),
            on='record_id_raw_input_file',
        )
        .merge(
            reference_files_ground_truth.rename(columns={'record_id': 'record_id_reference_file'}),
            on='record_id_reference_file',
        )
        .assign(correct=lambda df: df.simulant_id_x == df.simulant_id_y)
        .pipe(df_ops.groupby_agg_small_groups, by=["record_id_raw_input_file", "record_id_reference_file", "pik", "module_name", "pass_name"], agg_func=lambda x: x.correct.any())
        .reset_index()
)
sim_record_links_at_least_partially_correct
# Out:
# Dask DataFrame Structure:
#                 record_id_raw_input_file record_id_reference_file     pik module_name pass_name        correct
# npartitions=334
#                                   string                   string  string      string    string  bool[pyarrow]
#                                      ...                      ...     ...         ...       ...            ...
# ...                                  ...                      ...     ...         ...       ...            ...
#                                      ...                      ...     ...         ...       ...            ...
#                                      ...                      ...     ...         ...       ...            ...
# Dask Name: reset_index, 1 graph layer

# %%
len(sim_record_links_at_least_partially_correct)
# Out:
# 303915660

# %%
len(df_ops.drop_duplicates(sim_record_links_at_least_partially_correct[['record_id_raw_input_file', 'record_id_reference_file']]))
# Out:
# 303915660

# %%
(
    df_ops.compute(sim_record_links_at_least_partially_correct.correct.sum()) / piks_assigned
)
# Out:
# 0.999271090538737

# %%
assert df_ops.compute((df_ops.groupby_agg_small_groups(confirmed_piks_with_ground_truth, by='record_id_raw_input_file', agg_func=lambda x: x.record_id_reference_file.nunique()) <= 1).all())

# %%
# Using definition 3 -- at the PIK level
piks_at_least_partially_correct = df_ops.persist(
    piks_at_least_partially_correct
        .rename(columns={'record_id': 'record_id_raw_input_file'})
        .merge(confirmed_piks_with_ground_truth[['record_id_raw_input_file', 'module_name', 'pass_name']], on='record_id_raw_input_file')
)
piks_at_least_partially_correct
# Out:
# Dask DataFrame Structure:
#                 record_id_raw_input_file     pik        correct module_name pass_name
# npartitions=668
#                                   string  string  bool[pyarrow]      string    string
#                                      ...     ...            ...         ...       ...
# ...                                  ...     ...            ...         ...       ...
#                                      ...     ...            ...         ...       ...
#                                      ...     ...            ...         ...       ...
# Dask Name: hash-join, 1 graph layer

# %%
# Accuracy by module -- note that this shows the opposite pattern (with the sample data)
# relative to the results of Layne et al., who found GeoSearch was much *more* accurate
df_ops.compute(piks_at_least_partially_correct.groupby("module_name").correct.agg(["mean", "size"]).sort_values("mean"))
# Out:
#                   mean       size
# module_name
# dobsearch     0.996523     154732
# namesearch    0.997646   18325243
# geosearch     0.999379  284705539
# hhcompsearch  0.999899     730146

# %%
# Accuracy by pass -- could be used to tune pass-specific cutoffs, but
# this might not be too informative while we are still using the sample data.
df_ops.compute(piks_at_least_partially_correct.groupby(["module_name", "pass_name"]).correct.agg(["mean", "size"]).sort_values("mean"))
# Out:
#                                                                    mean  \
# module_name  pass_name
# dobsearch    initials name switch                              0.996523
# namesearch   DOB and NYSIIS of name                            0.997645
#              DOB and initials                                   0.99899
# geosearch    geokey name switch                                0.999058
#              geokey                                            0.999272
# hhcompsearch year of birth                                     0.999738
#              initials                                          0.999965
# geosearch    house number and street name Soundex              0.999983
#              some name and DOB information                     0.999992
#              house number and street name Soundex name switch       1.0
#
#                                                                     size
# module_name  pass_name
# dobsearch    initials name switch                                 154732
# namesearch   DOB and NYSIIS of name                             18323262
#              DOB and initials                                       1981
# geosearch    geokey name switch                                   876667
#              geokey                                            240966488
# hhcompsearch year of birth                                        213626
#              initials                                             516520
# geosearch    house number and street name Soundex               13077940
#              some name and DOB information                      29740242
#              house number and street name Soundex name switch      44202

# %%
# Using definition 3 -- at the link level
df_ops.compute(sim_record_links_at_least_partially_correct.groupby("module_name").correct.agg(["mean", "size"]).sort_values("mean"))
# Out:
#                   mean       size
# module_name
# dobsearch     0.996523     154732
# namesearch    0.997646   18325243
# geosearch     0.999376  284705539
# hhcompsearch  0.999899     730146

# %%
df_ops.compute(sim_record_links_at_least_partially_correct.groupby(["module_name", "pass_name"]).correct.agg(["mean", "size"]).sort_values("mean"))
# Out:
#                                                                    mean  \
# module_name  pass_name
# dobsearch    initials name switch                              0.996523
# namesearch   DOB and NYSIIS of name                            0.997645
#              DOB and initials                                   0.99899
# geosearch    geokey name switch                                 0.99905
#              geokey                                            0.999268
# hhcompsearch year of birth                                     0.999738
#              initials                                          0.999965
# geosearch    house number and street name Soundex              0.999983
#              some name and DOB information                     0.999992
#              house number and street name Soundex name switch       1.0
#
#                                                                     size
# module_name  pass_name
# dobsearch    initials name switch                                 154732
# namesearch   DOB and NYSIIS of name                             18323262
#              DOB and initials                                       1981
# geosearch    geokey name switch                                   876667
#              geokey                                            240966488
# hhcompsearch year of birth                                        213626
#              initials                                             516520
# geosearch    house number and street name Soundex               13077940
#              some name and DOB information                      29740242
#              house number and street name Soundex name switch      44202

# %%
df_ops.compute(sim_record_links_at_least_partially_correct[~sim_record_links_at_least_partially_correct.correct].groupby(["module_name", "pass_name"]).size()).sort_values()
# Out:
# module_name   pass_name
# namesearch    DOB and initials                             2
# hhcompsearch  initials                                    18
#               year of birth                               56
# geosearch     house number and street name Soundex       218
#               some name and DOB information              247
# dobsearch     initials name switch                       538
# geosearch     geokey name switch                         833
# namesearch    DOB and NYSIIS of name                   43144
# geosearch     geokey                                  176471
# dtype: int64

# %% [markdown]
# ### Incorrect and missed PIKs

# %%
incorrectly_linked_pairs = df_ops.persist(df_ops.drop_duplicates(
    sim_record_links_at_least_partially_correct[~sim_record_links_at_least_partially_correct.correct]
        [["record_id_raw_input_file", "record_id_reference_file"]]
))
incorrectly_linked_pairs
# Out:
# Dask DataFrame Structure:
#                 record_id_raw_input_file record_id_reference_file
# npartitions=668
#                                   string                   string
#                                      ...                      ...
# ...                                  ...                      ...
#                                      ...                      ...
#                                      ...                      ...
# Dask Name: concat, 1 graph layer

# %%
len(incorrectly_linked_pairs)
# Out:
# 221527

# %%
incorrect_links = df_ops.head(incorrectly_linked_pairs, n=100)
incorrect_links
# Out:
#            record_id_raw_input_file  \
# 0   simulated_census_2030_0_1000425
# 1   simulated_census_2030_0_1000941
# 2   simulated_census_2030_0_1001091
# 3   simulated_census_2030_0_1001617
# 4   simulated_census_2030_0_1001689
# ..                              ...
# 95   simulated_census_2030_0_185313
# 96   simulated_census_2030_0_185604
# 97   simulated_census_2030_0_187817
# 98    simulated_census_2030_0_18943
# 99   simulated_census_2030_0_189731
#
#                         record_id_reference_file
# 0   simulated_geobase_reference_file_284_1703768
# 1     simulated_geobase_reference_file_25_467554
# 2    simulated_geobase_reference_file_200_917055
# 3   simulated_geobase_reference_file_191_1983837
# 4    simulated_geobase_reference_file_247_460345
# ..                                           ...
# 95  simulated_geobase_reference_file_156_1056267
# 96   simulated_geobase_reference_file_343_716434
# 97  simulated_geobase_reference_file_163_1501087
# 98   simulated_geobase_reference_file_16_1773322
# 99    simulated_geobase_reference_file_12_496462
#
# [100 rows x 2 columns]

# %%
# %xdel incorrectly_linked_pairs

# %%
comparison_cols = [
    "first_name",
    "middle_name",
    "last_name",
    "date_of_birth",
    "street_number",
    "street_name",
    "unit_number",
    "city",
    "state",
]

incorrect_links_detail = (
    incorrect_links
        .merge(
            census_2030_piked[census_2030_piked.record_id.isin(incorrect_links.record_id_raw_input_file)]
                .compute()
                .rename(columns={"record_id": "record_id_raw_input_file", "middle_initial": "middle_name"})
                [["record_id_raw_input_file"] + comparison_cols],
            on="record_id_raw_input_file",
            how="left",
        )
        .merge(
            reference_file[reference_file.record_id.isin(incorrect_links.record_id_reference_file)]
                .compute()
                .rename(columns={"record_id": "record_id_reference_file"})
                .rename(columns=lambda c: c.replace('mailing_address_', ''))
                [["record_id_reference_file"] + comparison_cols],
            on="record_id_reference_file",
            how="left",
            suffixes=("_census", "_reference_file"),
        )
)
def flatten(xss):
    return [x for xs in xss for x in xs]

incorrect_links_detail[flatten([(f'{c}_census', f'{c}_reference_file') for c in comparison_cols])]
# Out:
#    first_name_census first_name_reference_file middle_name_census  \
# 0              Penny                      <NA>                  M
# 1             Audrey                      Jade                  G
# 2               <NA>                    Amelia                  O
# 3            Royalty                   Camilla                  E
# 4              Alaia                    Martin                  A
# ..               ...                       ...                ...
# 95           Kristin                   Charles                  E
# 96          Brooklyn                     David                  E
# 97           Michael                  Michelle                  M
# 98              <NA>                   Elliott                  C
# 99         Josephine                     Julio                  E
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 0                     Solomon            Ezell                    Ezell
# 1                        <NA>             Bell                     Bell
# 2                        Abby           Wilson                   Wilson
# 3                      Evelyn         Giordano                 Giordano
# 4                   Alexander            Reitz                    Reitz
# ..                        ...              ...                      ...
# 95                       <NA>           Bewick                   Bewick
# 96                       Eric           Stange                   Stange
# 97                     Marcia          Mcmahan                  Mcmahan
# 98                       Paul          Pacheco                  Pacheco
# 99                   Emiliano          Demonte                  Demonte
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 0            09/15/2028                     20280915                 9639
# 1            03/06/2011                     20110306                  109
# 2            10/23/2028                     20281023                  946
# 3            10/09/2028                     20281009                 9136
# 4            10/12/2028                     20281012                 6100
# ..                  ...                          ...                  ...
# 95           11/15/1963                     19631115                20961
# 96           02/19/2019                     20190219                 6539
# 97           04/06/1963                     19630406                 1114
# 98           11/29/2016                     20161129                  500
# 99           04/30/2008                     20080430                   32
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 0                          9639         givhans rd                 GIVHANS RD
# 1                           109     hubbell street             HUBBELL STREET
# 2                           946       jessica lane               JESSICA LANE
# 3                          9136    pontiac lake rd            PONTIAC LAKE RD
# 4                          6100     burdette drive             BURDETTE DRIVE
# ..                          ...                ...                        ...
# 95                        20961          gebron dr                  GEBRON DR
# 96                         6539           oahu isl                   OAHU ISL
# 97                         1114     s lions spg wy             S LIONS SPG WY
# 98                          500   philadelphia way           PHILADELPHIA WAY
# 99                           32         bartram rd                 BARTRAM RD
#
#    unit_number_census unit_number_reference_file     city_census  \
# 0                <NA>                       <NA>       parkville
# 1                <NA>                       <NA>          lorton
# 2                <NA>                       <NA>         monkton
# 3                <NA>                       <NA>         alameda
# 4                <NA>                       <NA>         chicago
# ..                ...                        ...             ...
# 95               <NA>                       <NA>  salt lake city
# 96               <NA>                       <NA>      litl falls
# 97               <NA>                       <NA>          austin
# 98               <NA>                       <NA>          benton
# 99               <NA>                       <NA>            crow
#
#    city_reference_file state_census state_reference_file
# 0            PARKVILLE           MD                   MD
# 1               LORTON           VA                   VA
# 2              MONKTON           MD                   MD
# 3              ALAMEDA           CA                   CA
# 4              CHICAGO           IL                   IL
# ..                 ...          ...                  ...
# 95      SALT LAKE CITY           UT                   UT
# 96          LITL FALLS           NJ                   NJ
# 97              AUSTIN           TX                   TX
# 98              BENTON           NY                   NY
# 99                CROW           WV                   WV
#
# [100 rows x 18 columns]

# %%
missed_links = df_ops.persist(
    census_2030_piked[census_2030_piked.pik.isnull()][["record_id"]]
        .merge(census_2030_ground_truth, on="record_id")
        .merge(reference_files_ground_truth[reference_files_ground_truth.n_unique_simulants == 1], on="simulant_id", suffixes=("_census", "_reference_file"))
)

# %%
len(missed_links)
# Out:
# 116621923

# %%
simulants_missed = df_ops.head(missed_links[['simulant_id']], n=100).simulant_id.unique()
simulants_missed
# Out:
# <ArrowStringArray>
# [  '28_365249',   '28_623546',   '40_181957',   '40_188899',   '93_545215',
#     '99_95719',   '99_880072',   '99_939969',  '103_100559', '107_1172955',
#   '131_996214', '278_1021948', '315_1154921',  '323_191653',  '323_912938',
#   '352_526740',   '446_78851', '465_1023090',   '478_82913',  '478_194997',
#   '478_230323', '496_1177062',  '539_822093',  '539_953168',  '558_341841',
#   '656_554266',  '656_776297',   '682_73548', '682_1103329',   '771_12558']
# Length: 30, dtype: string

# %%
missed_pairs = missed_links[missed_links.simulant_id.isin(list(simulants_missed))].compute()
missed_pairs
# Out:
#                    record_id_census  simulant_id  possible_to_pik  \
# 0    simulated_census_2030_0_308282    28_365249              1.0
# 1    simulated_census_2030_0_308282    28_365249              1.0
# 2    simulated_census_2030_0_308282    28_365249              1.0
# 3    simulated_census_2030_0_526134    28_623546              1.0
# 4    simulated_census_2030_0_526134    28_623546              1.0
# ..                              ...          ...              ...
# 95   simulated_census_2030_23_61933    682_73548              1.0
# 96  simulated_census_2030_23_934916  682_1103329              1.0
# 97  simulated_census_2030_23_934916  682_1103329              1.0
# 98   simulated_census_2030_25_10574    771_12558              1.0
# 99   simulated_census_2030_25_10574    771_12558              1.0
#
#                         record_id_reference_file  n_unique_simulants
# 0    simulated_geobase_reference_file_380_744864                   1
# 1   simulated_name_dob_reference_file_115_755841                   1
# 2    simulated_geobase_reference_file_380_744865                   1
# 3   simulated_geobase_reference_file_119_1624848                   1
# 4   simulated_geobase_reference_file_119_1624849                   1
# ..                                           ...                 ...
# 95  simulated_name_dob_reference_file_258_774653                   1
# 96  simulated_geobase_reference_file_139_2223854                   1
# 97  simulated_name_dob_reference_file_366_114787                   1
# 98   simulated_geobase_reference_file_232_595644                   1
# 99   simulated_name_dob_reference_file_92_236912                   1
#
# [100 rows x 5 columns]

# %%
# %xdel missed_links

# %%
missed_links_detail = (
    missed_pairs
        .merge(census_2030_piked[census_2030_piked.record_id.isin(list(missed_pairs.record_id_census))].compute().rename(columns={"record_id": "record_id_census", "middle_initial": "middle_name"}), on="record_id_census")
        .merge(reference_file[reference_file.record_id.isin(missed_pairs.record_id_reference_file)].compute().rename(columns=lambda c: c.replace('mailing_address_', '')).rename(columns={"record_id": "record_id_reference_file"}), on="record_id_reference_file", suffixes=("_census", "_reference_file"))
)

# %%
for simulant in simulants_missed:
    print(simulant)
    display(missed_links_detail[missed_links_detail.simulant_id == simulant][['simulant_id'] + flatten([(f'{c}_census', f'{c}_reference_file') for c in comparison_cols])])
# Out:
# 28_365249
#   simulant_id first_name_census first_name_reference_file middle_name_census  \
# 0   28_365249             Louis                     Louis                  R
# 1   28_365249             Louis                     Louis                  R
# 2   28_365249             Louis                     Louis                  R
#
#   middle_name_reference_file last_name_census last_name_reference_file  \
# 0                    Russell           Ansley                   Ansley
# 1                    Russell           Ansley                   Ansley
# 2                    Russell           Ansley                   Ansley
#
#   date_of_birth_census date_of_birth_reference_file street_number_census  \
# 0           10/07/2006                     19681123                  220
# 1           10/07/2006                     19681123                  220
# 2           10/07/2006                     19681123                  220
#
#   street_number_reference_file street_name_census street_name_reference_file  \
# 0                          220         4th ave nw                 4TH AVE NW
# 1                         <NA>         4th ave nw                       <NA>
# 2                          220         4th ave nw                 4TH AVE NW
#
#   unit_number_census unit_number_reference_file city_census  \
# 0               <NA>                       <NA>     visalia
# 1               <NA>                       <NA>     visalia
# 2               <NA>                       <NA>     visalia
#
#   city_reference_file state_census state_reference_file
# 0                <NA>           KY                   CA
# 1                <NA>           KY                 <NA>
# 2             VISALIA           KY                   CA
# 28_623546
#   simulant_id first_name_census first_name_reference_file middle_name_census  \
# 3   28_623546             Scott                   Sceeter                  J
# 4   28_623546             Scott                   Sceeter                  J
# 5   28_623546             Scott                   Sceeter                  J
#
#   middle_name_reference_file last_name_census last_name_reference_file  \
# 3                     Joseph          Justman                  Justman
# 4                     Joseph          Justman                  Justman
# 5                     Joseph          Justman                  Justman
#
#   date_of_birth_census date_of_birth_reference_file street_number_census  \
# 3           09/22/1975                     19750922                 6341
# 4           09/22/1975                     19750922                 6341
# 5           09/22/1975                     19750922                 6341
#
#   street_number_reference_file street_name_census street_name_reference_file  \
# 3                            3               <NA>                 CLEMENT RD
# 4                         6341               <NA>             HUBBERT STREET
# 5                         <NA>               <NA>                       <NA>
#
#   unit_number_census unit_number_reference_file city_census  \
# 3               <NA>                       <NA>    chandler
# 4               <NA>                       <NA>    chandler
# 5               <NA>                       <NA>    chandler
#
#   city_reference_file state_census state_reference_file
# 3           GRANDVIEW           AZ                   MO
# 4            CHANDLER           AZ                   AZ
# 5                <NA>           AZ                 <NA>
# 40_181957
#   simulant_id first_name_census first_name_reference_file middle_name_census  \
# 6   40_181957            Doreen                    Doreen                  K
# 7   40_181957            Doreen                    Doreen                  K
# 8   40_181957            Doreen                    Doreen                  K
#
#   middle_name_reference_file last_name_census last_name_reference_file  \
# 6                   Kimberly          Miranda                  Miranda
# 7                   Kimberly          Miranda                  Miranda
# 8                   Kimberly          Miranda                  Miranda
#
#   date_of_birth_census date_of_birth_reference_file street_number_census  \
# 6           06/26/1982                     19630203                  447
# 7           06/26/1982                     19630203                  447
# 8           06/26/1982                     19630203                  447
#
#   street_number_reference_file street_name_census street_name_reference_file  \
# 6                         <NA>        pease drive                       <NA>
# 7                          447        pease drive                PEASE DRIVE
# 8                          447        pease drive                PEASE DRIVE
#
#   unit_number_census unit_number_reference_file  city_census  \
# 6               <NA>                       <NA>  albuquerque
# 7               <NA>                       <NA>  albuquerque
# 8               <NA>                       <NA>  albuquerque
#
#   city_reference_file state_census state_reference_file
# 6                <NA>           NM                 <NA>
# 7         ALBUQUERQUE           NM                   CO
# 8         ALBUQUERQUE           NM                   NM
# 40_188899
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 9    40_188899            Andrew                     Davis                  D
# 10   40_188899            Andrew                     Davis                  D
# 11   40_188899            Andrew                     Davis                  D
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 9                      Andrew            Davis                   Daniel
# 10                     Andrew            Davis                   Daniel
# 11                     Andrew            Davis                   Daniel
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 9            02/21/2002                     20020221                  503
# 10           02/21/2002                     20020221                  503
# 11           02/21/2002                     20020221                  503
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 9                           503     s windsor blvd             S WINDSOR BLVD
# 10                         4404     s windsor blvd            MIZZENMAST ROAD
# 11                         <NA>     s windsor blvd                       <NA>
#
#    unit_number_census unit_number_reference_file city_census  \
# 9                <NA>                       <NA>     chicago
# 10               <NA>                   APT 223R     chicago
# 11               <NA>                       <NA>     chicago
#
#    city_reference_file state_census state_reference_file
# 9              CHICAGO           IL                   IL
# 10       JUNCTION CITY           IL                   KS
# 11                <NA>           IL                 <NA>
# 93_545215
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 12   93_545215            Steven                    Steven                  A
# 13   93_545215            Steven                    Steven                  A
# 14   93_545215            Steven                    Steven                  A
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 12                      Aaron              Tam                      Tam
# 13                      Aaron              Tam                      Tam
# 14                      Aaron              Tam                      Tam
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 12           02/05/1978                     19411011                 9460
# 13           02/05/1978                     19411011                 9460
# 14           02/05/1978                     19411011                 9460
#
#    street_number_reference_file        street_name_census  \
# 12                         9460  mendelssohn avenue north
# 13                         <NA>  mendelssohn avenue north
# 14                         <NA>  mendelssohn avenue north
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 12   MENDELSSOHN AVENUE NORTH               <NA>                       <NA>
# 13                       <NA>               <NA>                       <NA>
# 14                       <NA>               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 12  round rock          ROUND ROCK           TX                   TX
# 13  round rock              AUSTIN           TX                   TX
# 14  round rock                <NA>           TX                 <NA>
# 99_95719
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 15    99_95719            Thomas                    Thomas                  E
# 16    99_95719            Thomas                    Thomas                  E
# 17    99_95719            Thomas                    Thomas                  E
# 18    99_95719            Thomas                    Thomas                  E
# 19    99_95719            Thomas                    Thomas                  E
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 15                     Edward            Jilek                    Jilek
# 16                     Edward            Jilek                    Jilek
# 17                     Edward            Jilek                    Jilek
# 18                     Edward            Jilek                    Jilek
# 19                     Edward            Jilek                    Jilek
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 15           04/10/1968                     19960506                  729
# 16           04/10/1968                     19960506                  729
# 17           04/10/1968                     19960506                  729
# 18           04/10/1968                     19960506                  729
# 19           04/10/1968                     19960506                  729
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 15                          729           s 1130 w                   S 1130 W
# 16                          729           s 1130 w                   S 1130 W
# 17                         <NA>           s 1130 w                       <NA>
# 18                          729           s 1130 w                       <NA>
# 19                          729           s 1130 w                   S 1130 W
#
#    unit_number_census unit_number_reference_file city_census  \
# 15               <NA>                       <NA>      borger
# 16               <NA>                       <NA>      borger
# 17               <NA>                       <NA>      borger
# 18               <NA>                       <NA>      borger
# 19               <NA>                       <NA>      borger
#
#    city_reference_file state_census state_reference_file
# 15              BORGER           TX                   TX
# 16              BORGER           TX                   TX
# 17                <NA>           TX                 <NA>
# 18              BORGER           TX                   TX
# 19                <NA>           TX                   TX
# 99_880072
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 20   99_880072           Octavia                   Octavia                  T
# 21   99_880072           Octavia                   Octavia                  T
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 20                      Tracy        Rodrigues                Rodrigues
# 21                      Tracy        Rodrigues                Rodrigues
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 20           07/18/|963                     19630718                 1805
# 21           07/18/|963                     19630718                 1805
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 20                         <NA>     morr:s farm rd                       <NA>
# 21                         1805     morr:s farm rd             MORRIS FARM RD
#
#    unit_number_census unit_number_reference_file city_census  \
# 20               <NA>                       <NA>    oak park
# 21               <NA>                       <NA>    oak park
#
#    city_reference_file state_census state_reference_file
# 20                <NA>           IL                 <NA>
# 21            OAK PARK           IL                   IL
# 99_939969
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 22   99_939969           Cynthia                   Cynthia                  M
# 23   99_939969           Cynthia                   Cynthia                  M
# 24   99_939969           Cynthia                   Cynthia                  M
# 25   99_939969           Cynthia                   Cynthia                  M
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 22                   Michelle            Weber                    Weber
# 23                   Michelle            Weber                    Weber
# 24                   Michelle            Weber                    Weber
# 25                   Michelle            Weber                    Weber
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 22           04/05/1969                     19690504                1|918
# 23           04/05/1969                     19690504                1|918
# 24           04/05/1969                     19690504                1|918
# 25           04/05/1969                     19690504                1|918
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 22                         <NA>          gillis st                       <NA>
# 23                        11918          gillis st                  GILLJS ST
# 24                        11918          gillis st                  GILLIS ST
# 25                        11918          gillis st                  GILLIS ST
#
#    unit_number_census unit_number_reference_file city_census  \
# 22               <NA>                       <NA>  pittsburgh
# 23               <NA>                       <NA>  pittsburgh
# 24               <NA>                       <NA>  pittsburgh
# 25               <NA>                       <NA>  pittsburgh
#
#    city_reference_file state_census state_reference_file
# 22                <NA>           PA                 <NA>
# 23          PITTSBURGH           PA                   PA
# 24          PITTSBUR9H           PA                   PA
# 25          PITTSBURGH           PA                   PA
# 103_100559
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 26  103_100559           Diamond                   Diamond                  A
# 27  103_100559           Diamond                   Diamond                  A
# 28  103_100559           Diamond                   Diamond                  A
# 29  103_100559           Diamond                   Diamond                  A
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 26                       Aria          Johnson                  Johnson
# 27                       Aria          Johnson                  Johnson
# 28                       Aria          Johnson                  Johnson
# 29                       Aria          Johnson                  Johnson
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 26           09/14/2005                     20050914                 2134
# 27           09/14/2005                     20050914                 2134
# 28           09/14/2005                     20050914                 2134
# 29           09/14/2005                     20050914                 2134
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 26                         2134    briar forest dr            BRIAR FOREST DR
# 27                         <NA>    briar forest dr                       <NA>
# 28                         2134    briar forest dr            BRIAR FOREST DR
# 29                         2134    briar forest dr            BRIAR FOREST DR
#
#    unit_number_census unit_number_reference_file  city_census  \
# 26               <NA>                       <NA>  los angeles
# 27               <NA>                       <NA>  los angeles
# 28               <NA>                       <NA>  los angeles
# 29               <NA>                       <NA>  los angeles
#
#    city_reference_file state_census state_reference_file
# 26         LOS ANGELES           CA                   MI
# 27                <NA>           CA                 <NA>
# 28         LOS ANGELES           CA                   CA
# 29        LEOS ANKELES           CA                   CA
# 107_1172955
#     simulant_id first_name_census first_name_reference_file  \
# 30  107_1172955        Jacqueline                Jacqueline
# 31  107_1172955        Jacqueline                Jacqueline
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 30                  K                    Kathryn           Rivera
# 31                  K                    Kathryn           Rivera
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 30                   Rivera                 <NA>                     19510418
# 31                   Rivera                 <NA>                     19510418
#
#    street_number_census street_number_reference_file street_name_census  \
# 30                 1258                         <NA>        magnolia dr
# 31                 1258                         <NA>        magnolia dr
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 30                       <NA>               <NA>                       <NA>
# 31                       <NA>               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 30     chicago                <NA>           IL                 <NA>
# 31     chicago                <NA>           IL                 <NA>
# 131_996214
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 32  131_996214           Brandon                   Brandon          Gallacher
# 33  131_996214           Brandon                   Brandon          Gallacher
# 34  131_996214           Brandon                   Brandon          Gallacher
# 35  131_996214           Brandon                   Brandon          Gallacher
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 32                     Howard                H                Gallacher
# 33                     Howard                H                Gallacher
# 34                     Howard                H                Gallacher
# 35                     Howard                H                Gallacher
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 32           01/13/1987                     19870113                13280
# 33           01/13/1987                     19870113                13280
# 34           01/13/1987                     19870113                13280
# 35           01/13/1987                     19870113                13280
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 32                         <NA>             sth 70                       <NA>
# 33                        13280             sth 70                     STH 70
# 34                          740             sth 70         CHRISTENSEN AVENUE
# 35                        13280             sth 70                     STH 70
#
#    unit_number_census unit_number_reference_file      city_census  \
# 32               <NA>                       <NA>  new port richey
# 33               <NA>                       <NA>  new port richey
# 34               <NA>                       <NA>  new port richey
# 35               <NA>                       <NA>  new port richey
#
#    city_reference_file state_census state_reference_file
# 32                <NA>           FL                 <NA>
# 33     NEW PORT RICHEY           FL                   FL
# 34         CLARKSVILLE           FL                   AR
# 35     NEW PORT RICHEY           FL                   FL
# 278_1021948
#     simulant_id first_name_census first_name_reference_file  \
# 36  278_1021948          Katelynn                      Miss
# 37  278_1021948          Katelynn                      Miss
# 38  278_1021948          Katelynn                      Miss
# 39  278_1021948          Katelynn                      Miss
# 40  278_1021948          Katelynn                      Miss
# 41  278_1021948          Katelynn                      Miss
# 42  278_1021948          Katelynn                      Miss
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 36                  E                  Elizabeth              Tom
# 37                  E                  Elizabeth              Tom
# 38                  E                  Elizabeth              Tom
# 39                  E                  Elizabeth              Tom
# 40                  E                  Elizabeth              Tom
# 41                  E                  Elizabeth              Tom
# 42                  E                  Elizabeth              Tom
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 36                      Tom           03/27/1491                     19910327
# 37                      Tom           03/27/1491                     19910327
# 38                      Tom           03/27/1491                     19910327
# 39                      Tom           03/27/1491                     19910327
# 40                      Tom           03/27/1491                     19910327
# 41                      Tom           03/27/1491                     19910327
# 42                      Tom           03/27/1491                     19910327
#
#    street_number_census street_number_reference_file street_name_census  \
# 36                 3879                         3879        main street
# 37                 3879                          965        main street
# 38                 3879                         3879        main street
# 39                 3879                          965        main street
# 40                 3879                         3879        main street
# 41                 3879                         <NA>        main street
# 42                 3879                          965        main street
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 36                MAIN STREET               <NA>                       <NA>
# 37                  E MAIN ST               <NA>                       <NA>
# 38                MAIN STREET               <NA>                       <NA>
# 39                  E MAIN ST               <NA>                       <NA>
# 40                MAIN STREET               <NA>                       <NA>
# 41                       <NA>               <NA>                       <NA>
# 42                  E MAIN ST               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 36       allen               ALLEN           TX                   TX
# 37       allen              SPARKS           TX                 <NA>
# 38       allen               ALLEN           TX                   TX
# 39       allen              SPARKS           TX                   NV
# 40       allen               ALLEN           TX                   NM
# 41       allen                <NA>           TX                 <NA>
# 42       allen              APWRKS           TX                   NV
# 315_1154921
#     simulant_id first_name_census first_name_reference_file  \
# 43  315_1154921              Mark                      Mark
# 44  315_1154921              Mark                      Mark
# 45  315_1154921              Mark                      Mark
# 46  315_1154921              Mark                      Mark
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 43                  C                          C            Krumm
# 44                  C                          C            Krumm
# 45                  C                          C            Krumm
# 46                  C                          C            Krumm
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 43                     Krum           02/22/1979                         <NA>
# 44                    Krumm           02/22/1979                         <NA>
# 45                     Krum           02/22/1979                         <NA>
# 46                    Krumm           02/22/1979                         <NA>
#
#    street_number_census street_number_reference_file street_name_census  \
# 43                 9627                         <NA>               <NA>
# 44                 9627                         9627               <NA>
# 45                 9627                         9627               <NA>
# 46                 9627                         <NA>               <NA>
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 43                       <NA>               <NA>                       <NA>
# 44                    RYAN DR               <NA>                       <NA>
# 45                    RYAN DR               <NA>                       <NA>
# 46                       <NA>               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 43       omaha                <NA>           NE                 <NA>
# 44       omaha               OMAHA           NE                   NE
# 45       omaha               OMAHA           NE                   NE
# 46       omaha                <NA>           NE                 <NA>
# 323_191653
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 47  323_191653              Chad                      Chad                  C
# 48  323_191653              Chad                      Chad                  C
# 49  323_191653              Chad                      Chad                  C
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 47                    Charles  Escalante Gomez          Escalante Gomez
# 48                    Charles  Escalante Gomez          Escalante Gomez
# 49                    Charles  Escalante Gomez          Escalante Gomez
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 47           05/01/1985                     19880825                 <NA>
# 48           05/01/1985                     19880825                 <NA>
# 49           05/01/1985                     19880825                 <NA>
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 47                         <NA>    ne lawrence ave                       <NA>
# 48                         <NA>    ne lawrence ave            NE LAWRENCE AVE
# 49                         <NA>    ne lawrence ave            NE LAWRENCE AVE
#
#    unit_number_census unit_number_reference_file           city_census  \
# 47               <NA>                       <NA>  cherry hill township
# 48               <NA>                       <NA>  cherry hill township
# 49               <NA>                       <NA>  cherry hill township
#
#      city_reference_file state_census state_reference_file
# 47                  <NA>           NJ                 <NA>
# 48  CHERRY HILL TOWNSHIP           NJ                   CT
# 49  CHERRY HILL TOWNSHIP           NJ                   NJ
# 323_912938
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 50  323_912938             Henry                     Henry                  I
# 51  323_912938             Henry                     Henry                  I
# 52  323_912938             Henry                     Henry                  I
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 50                     Israel             Dang                     Dang
# 51                     Israel             Dang                     Dang
# 52                     Israel             Dang                     Dang
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 50           31/08/2009                     20090831                 <NA>
# 51           31/08/2009                     20090831                 <NA>
# 52           31/08/2009                     20090831                 <NA>
#
#    street_number_reference_file  street_name_census  \
# 50                           85  burr oak boulevard
# 51                         <NA>  burr oak boulevard
# 52                         <NA>  burr oak boulevard
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 50               MONTERREY DR               <NA>                       <NA>
# 51         BURR OAK BOULEVARD               <NA>                       <NA>
# 52                       <NA>               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 50  lillington         ALBUQUERQUE           NC                   NM
# 51  lillington          LILLINGTON           NC                   NC
# 52  lillington                <NA>           NC                 <NA>
# 352_526740
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 53  352_526740            Shelly                    Rachel                  R
# 54  352_526740            Shelly                    Rachel                  R
# 55  352_526740            Shelly                    Rachel                  R
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 53                       Remi            Kloss                    Kloss
# 54                       Remi            Kloss                    Kloss
# 55                       Remi            Kloss                    Kloss
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 53           11/15/2018                     20181115                 2150
# 54           11/15/2018                     20181115                 2150
# 55           11/15/2018                     20181115                 2150
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 53                         <NA>      lansdale road                       <NA>
# 54                         <NA>      lansdale road                       <NA>
# 55                         <NA>      lansdale road               SE CATES CIR
#
#    unit_number_census unit_number_reference_file city_census  \
# 53               <NA>                       <NA>  bellflower
# 54               <NA>                       <NA>  bellflower
# 55               <NA>                       <NA>  bellflower
#
#    city_reference_file state_census state_reference_file
# 53                <NA>           CA                 <NA>
# 54           COACHELLA           CA                   CA
# 55        PHILADELPHIA           CA                   PA
# 446_78851
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 56   446_78851           Zachary                   Zachary
# 57   446_78851           Zachary                   Zachary
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 56                      David       D Mckinney                 Mckinney
# 57                      David       D Mckinney                 Mckinney
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 56           01/30/1994                     19940130                  197
# 57           01/30/1994                     19940130                  197
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 56                         <NA>         82nd drive                       <NA>
# 57                          197         82nd drive                 82ND DRIVE
#
#    unit_number_census unit_number_reference_file  city_census  \
# 56               <NA>                       <NA>  summerfield
# 57               <NA>                       <NA>  summerfield
#
#    city_reference_file state_census state_reference_file
# 56                <NA>           NC                 <NA>
# 57         SUMMERFIELD           NC                   NC
# 465_1023090
#     simulant_id first_name_census first_name_reference_file  \
# 58  465_1023090            Kalani                  Scarlett
# 59  465_1023090            Kalani                  Scarlett
# 60  465_1023090            Kalani                  Scarlett
# 61  465_1023090            Kalani                  Scarlett
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 58                  S                     Kalani          Gokhale
# 59                  S                     Kalani          Gokhale
# 60                  S                     Kalani          Gokhale
# 61                  S                     Kalani          Gokhale
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 58               De La Casa           04/28/2020                     20200428
# 59               De La Casa           04/28/2020                     20200428
# 60               De La Casa           04/28/2020                     20200428
# 61               De La Casa           04/28/2020                     20200428
#
#    street_number_census street_number_reference_file street_name_census  \
# 58                  503                          503       sterling cir
# 59                  503                          503       sterling cir
# 60                  503                         <NA>       sterling cir
# 61                  503                          943       sterling cir
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 58               STERLING CIR               <NA>                       <NA>
# 59               STERLING CIR               <NA>                       <NA>
# 60                       <NA>               <NA>                       <NA>
# 61                    47TH ST               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 58      laurel              LAUREL           MD                   AZ
# 59      laurel              LAUREL           MD                   MD
# 60      laurel                <NA>           MD                 <NA>
# 61      laurel          CLEARWATER           MD                   FL
# 478_82913
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 62   478_82913              Lois                      Lois                  L
# 63   478_82913              Lois                      Lois                  L
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 62                      Luann          Roberts                   Refuse
# 63                      Luann          Roberts                   Refuse
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 62           09/29/1961                     19610929                 8329
# 63           09/29/1961                     19610929                 8329
#
#    street_number_reference_file     street_name_census  \
# 62                         <NA>  northwwst ashcreek ln
# 63                         8329  northwwst ashcreek ln
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 62                       <NA>               <NA>                       <NA>
# 63      NORTHWEST ASHCREEK LN               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 62    ferriday                <NA>           LA                 <NA>
# 63    ferriday            FERRIDAY           LA                   LA
# 478_194997
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 64  478_194997           Lyndsey                      <NA>                  S
# 65  478_194997           Lyndsey                      <NA>                  S
# 66  478_194997           Lyndsey                      <NA>                  S
# 67  478_194997           Lyndsey                      <NA>                  S
# 68  478_194997           Lyndsey                      <NA>                  S
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 64                       Sara          Kupstas                  Kupstas
# 65                       Sara          Kupstas                  Kupstas
# 66                       Sara          Kupstas                  Kupstas
# 67                       Sara          Kupstas                  Kupstas
# 68                       Sara          Kupstas                  Kupstas
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 64           27/03/2006                     20060327                 2425
# 65           27/03/2006                     20060327                 2425
# 66           27/03/2006                     20060327                 2425
# 67           27/03/2006                     20060327                 2425
# 68           27/03/2006                     20060327                 2425
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 64                         2425        lakeside dr                LAKESIDE DR
# 65                         7176        lakeside dr             HICKORYNUT CIR
# 66                         <NA>        lakeside dr             HICKORYNUT CIR
# 67                         <NA>        lakeside dr                       <NA>
# 68                         7176        lakeside dr             HICKORYNUT CIR
#
#    unit_number_census unit_number_reference_file   city_census  \
# 64               <NA>                       <NA>  coopersville
# 65               <NA>                       <NA>  coopersville
# 66               <NA>                       <NA>  coopersville
# 67               <NA>                       <NA>  coopersville
# 68               <NA>                       <NA>  coopersville
#
#    city_reference_file state_census state_reference_file
# 64        COOPERSVILLE           MI                   MI
# 65           HITCHCOCK           MI                   TX
# 66           HITCHCOCK           MI                   TX
# 67                <NA>           MI                 <NA>
# 68           HITCHCOCK           MI                   TX
# 478_230323
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 69  478_230323             Jenna                     Jenna                  D
# 70  478_230323             Jenna                     Jenna                  D
# 71  478_230323             Jenna                     Jenna                  D
# 72  478_230323             Jenna                     Jenna                  D
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 69                  Domonique         Harrison                 Harrison
# 70                  Domonique         Harrison                 Harrison
# 71                  Domonique         Harrison                 Harrison
# 72                  Domonique         Harrison                 Harrison
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 69           02/21/2013                     19860214                   15
# 70           02/21/2013                     19860214                   15
# 71           02/21/2013                     19860214                   15
# 72           02/21/2013                     19860214                   15
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 69                         <NA>          81 street                       <NA>
# 70                         <NA>          81 street                       <NA>
# 71                           15          81 street                  81 STREET
# 72                         <NA>          81 street                       <NA>
#
#    unit_number_census unit_number_reference_file  city_census  \
# 69               <NA>                       <NA>  sterling ht
# 70               <NA>                       <NA>  sterling ht
# 71               <NA>                       <NA>  sterling ht
# 72               <NA>                       <NA>  sterling ht
#
#    city_reference_file state_census state_reference_file
# 69                <NA>           MI                 <NA>
# 70               TAMPA           MI                   FL
# 71         STERLING HT           MI                   MI
# 72           LAKE CITY           MI                   IA
# 496_1177062
#     simulant_id first_name_census first_name_reference_file  \
# 73  496_1177062              Leon                      Leon
# 74  496_1177062              Leon                      Leon
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 73                  J                     Jordan           Person
# 74                  J                     Jordan           Person
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 73                 Williams           03/01/2029                     20290301
# 74                 Williams           03/01/2029                     20290301
#
#    street_number_census street_number_reference_file street_name_census  \
# 73                  323                         <NA>           nash ave
# 74                  323                         <NA>           nash ave
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 73                   NASH AVE               <NA>                       <NA>
# 74                       <NA>               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 73       greer               GREER           SC                   SC
# 74       greer                <NA>           SC                 <NA>
# 539_822093
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 75  539_822093          Nicholas                     Nicky                  K
# 76  539_822093          Nicholas                     Nicky                  K
# 77  539_822093          Nicholas                     Nicky                  K
# 78  539_822093          Nicholas                     Nicky                  K
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 75                    Kenneth           Martin                   Martin
# 76                    Kenneth           Martin                   Martin
# 77                    Kenneth           Martin                   Martin
# 78                    Kenneth           Martin                   Martin
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 75           03/05/1985                     19850307                 3073
# 76           03/05/1985                     19850307                 3073
# 77           03/05/1985                     19850307                 3073
# 78           03/05/1985                     19850307                 3073
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 75                         1802     wild timber rd                   KAREN CT
# 76                         3073     wild timber rd             WILD TIMBER RD
# 77                         7550     wild timber rd                  CANAAN RD
# 78                         <NA>     wild timber rd                       <NA>
#
#    unit_number_census unit_number_reference_file city_census  \
# 75               <NA>                       <NA>  montgomery
# 76               <NA>                       <NA>  montgomery
# 77               <NA>                       <NA>  montgomery
# 78               <NA>                       <NA>  montgomery
#
#    city_reference_file state_census state_reference_file
# 75                NEMO           TX                   TX
# 76          MONTGOMERY           TX                   TX
# 77          GREENFIELD           TX                   CA
# 78                <NA>           TX                 <NA>
# 539_953168
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 79  539_953168            Robert                    Robert                  Q
# 80  539_953168            Robert                    Robert                  Q
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 79                    Anthony             <NA>                    Davis
# 80                    Anthony             <NA>                    Davis
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 79           07/07/1984                     19840707                  809
# 80           07/07/1984                     19840707                  809
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 79                          809       old coach rd                       <NA>
# 80                         <NA>       old coach rd                       <NA>
#
#    unit_number_census unit_number_reference_file city_census  \
# 79               <NA>                       <NA>  huntsville
# 80               <NA>                       <NA>  huntsville
#
#    city_reference_file state_census state_reference_file
# 79          HUNTSVILLE           AL                   AL
# 80                <NA>           AL                 <NA>
# 558_341841
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 81  558_341841            Elaine                    Elaine                  M
# 82  558_341841            Elaine                    Elaine                  M
# 83  558_341841            Elaine                    Elaine                  M
# 84  558_341841            Elaine                    Elaine                  M
# 85  558_341841            Elaine                    Elaine                  M
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 81                    Melissa            Hulme                    Hulme
# 82                    Melissa            Hulme                    Hulme
# 83                    Melissa            Hulme                    Hulme
# 84                    Melissa            Hulme                    Hulme
# 85                    Melissa            Hulme                    Hulme
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 81           01/17/1978                     20190303                  305
# 82           01/17/1978                     20190303                  305
# 83           01/17/1978                     20190303                  305
# 84           01/17/1978                     20190303                  305
# 85           01/17/1978                     20190303                  305
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 81                         <NA>          w 15th st              TALBOT STREET
# 82                          305          w 15th st                  W 15TH ST
# 83                         <NA>          w 15th st              TALBOT STREET
# 84                         <NA>          w 15th st                       <NA>
# 85                         <NA>          w 15th st                  W 15TH ST
#
#    unit_number_census unit_number_reference_file city_census  \
# 81               <NA>                       <NA>        saco
# 82               <NA>                       <NA>        saco
# 83               <NA>                       <NA>        saco
# 84               <NA>                       <NA>        saco
# 85               <NA>                       <NA>        saco
#
#    city_reference_file state_census state_reference_file
# 81        UNION VALLEY           ME                   TX
# 82                SACO           ME                   ME
# 83        UNION VALLEY           ME                   TX
# 84                <NA>           ME                 <NA>
# 85                SACO           ME                   ME
# 656_554266
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 86  656_554266          Jennifer                  Jennifer                  J
# 87  656_554266          Jennifer                  Jennifer                  J
# 88  656_554266          Jennifer                  Jennifer                  J
# 89  656_554266          Jennifer                  Jennifer                  J
# 90  656_554266          Jennifer                  Jennifer                  J
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 86                    Jessica          Holland                  Holland
# 87                    Jessica          Holland                  Holland
# 88                    Jessica          Holland                  Holland
# 89                    Jessica          Holland                  Holland
# 90                    Jessica          Holland                  Holland
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 86           11/15/1985                     19851115                 5750
# 87           11/15/1985                     19851115                 5750
# 88           11/15/1985                     19851115                 5750
# 89           11/15/1985                     19851115                 5750
# 90           11/15/1985                     19851115                 5750
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 86                          957        s cntrl ave                 LINDEN AVE
# 87                         <NA>        s cntrl ave                S CNTRL AVE
# 88                         5750        s cntrl ave                S CNTRL AVE
# 89                          951        s cntrl ave                 LINDEN AVE
# 90                         <NA>        s cntrl ave                       <NA>
#
#    unit_number_census unit_number_reference_file city_census  \
# 86               <NA>                       <NA>  southfield
# 87               <NA>                       <NA>  southfield
# 88               <NA>                       <NA>  southfield
# 89               <NA>                       <NA>  southfield
# 90               <NA>                       <NA>  southfield
#
#    city_reference_file state_census state_reference_file
# 86           JONESBORO           MI                   GA
# 87          SOUTHFIELD           MI                   MI
# 88          SOUTHFIELD           MI                   MI
# 89           JONESBORO           MI                   GA
# 90                <NA>           MI                 <NA>
# 656_776297
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 91  656_776297              Todd                      Todd                  B
# 92  656_776297              Todd                      Todd                  B
# 93  656_776297              Todd                      Todd                  B
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 91                     Keller           Keller                  Bradley
# 92                     Keller           Keller                  Bradley
# 93                     Keller           Keller                  Bradley
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 91           09/25/1966                     19660925                15161
# 92           09/25/1966                     19660925                15161
# 93           09/25/1966                     19660925                15161
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 91                        15161        woodmere ln                WOODMERE LN
# 92                         <NA>        woodmere ln                       <NA>
# 93                        15161        woodmere ln                       <NA>
#
#    unit_number_census unit_number_reference_file            city_census  \
# 91               <NA>                       <NA>  city of cottage grove
# 92               <NA>                       <NA>  city of cottage grove
# 93               <NA>                       <NA>  city of cottage grove
#
#       city_reference_file state_census state_reference_file
# 91  CITY OF COTTAGE GROVE           MN                   MN
# 92                   <NA>           MN                 <NA>
# 93  CITY OF COTTAGE GROVE           MN                   MN
# 682_73548
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 94   682_73548              Eric                      Eric                  T
# 95   682_73548              Eric                      Eric                  T
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 94                     Thomas         Villegas                 Villegas
# 95                     Thomas         Villegas                 Villegas
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 94           12/09/1998                     19690309                   65
# 95           12/09/1998                     19690309                   65
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 94                           65     parkwood drive             PARKWOOD DRIVE
# 95                         <NA>     parkwood drive                       <NA>
#
#    unit_number_census unit_number_reference_file city_census  \
# 94               <NA>                       <NA>   frederick
# 95               <NA>                       <NA>   frederick
#
#    city_reference_file state_census state_reference_file
# 94           FREDERICK           CO                   CO
# 95                <NA>           CO                 <NA>
# 682_1103329
#     simulant_id first_name_census first_name_reference_file  \
# 96  682_1103329            Rachel                    Rachel
# 97  682_1103329            Rachel                    Rachel
#
#    middle_name_census middle_name_reference_file last_name_census  \
# 96                  T                          T        Rodriguez
# 97                  T                          T        Rodriguez
#
#    last_name_reference_file date_of_birth_census date_of_birth_reference_file  \
# 96                Rodriguez           11/03/1993                         <NA>
# 97                Rodriguez           11/03/1993                         <NA>
#
#    street_number_census street_number_reference_file street_name_census  \
# 96                  441                            5         belrose rd
# 97                  441                         <NA>         belrose rd
#
#    street_name_reference_file unit_number_census unit_number_reference_file  \
# 96      ROYAL PALM BEACH BLVD               <NA>                       <NA>
# 97                       <NA>               <NA>                       <NA>
#
#    city_census city_reference_file state_census state_reference_file
# 96     s diego           BETHLEHEM           CA                   NY
# 97     s diego                <NA>           CA                 <NA>
# 771_12558
#    simulant_id first_name_census first_name_reference_file middle_name_census  \
# 98   771_12558             Sxott                     Scott                  T
# 99   771_12558             Sxott                     Scott                  T
#
#    middle_name_reference_file last_name_census last_name_reference_file  \
# 98                     Tyrone           Norris                   Norris
# 99                     Tyrone           Norris                   Norris
#
#    date_of_birth_census date_of_birth_reference_file street_number_census  \
# 98           04/30/1974                     19740430                 2215
# 99           04/30/1974                     19740430                 2215
#
#    street_number_reference_file street_name_census street_name_reference_file  \
# 98                         2215     mountainside d             MOUNTAINSIDE D
# 99                         <NA>     mountainside d                       <NA>
#
#    unit_number_census unit_number_reference_file city_census  \
# 98               <NA>                       <NA>     amherst
# 99               <NA>                       <NA>     amherst
#
#    city_reference_file state_census state_reference_file
# 98             AMHERST           NY                   NY
# 99                <NA>           NY                 <NA>
